# %% [markdown]
# # 0. Marking.
#
# **_IMPORTANT_**: Save a copy of this notebook into your Drive before you start.
#
# - Please attempt all the questions marked for your group (Part II ✅ | Part III/MPhil ✅).
# - Continue to part 2 after you are done with this one.
#
# Please submit a zip file, containing both parts, consiting of of:
#
# 1. A text file with a publicly visible link to your notebooks in Google Colab or GitHub.
# 2. A downloaded copy (ipynb) of your notebooks or your zipped cloned GitHub repo. You may treat these as a report: we will not be re-executing the code you used to produce the answers unless required.
#
# If you find yourself enjoying the material, feel free to attempt more! Provide your answers in a new cell below the question cell.

# %% [markdown]
# ## Imports

# %%
import sys
sys.executable
# Out:
# '/Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/bin/python'

# %%
# The simulation component of flower uses RAY under the hood.
# `pip` could produce some errors. Nothing to worry about.
# The execution has been verified; it is working anyway.
! pip install --quiet --upgrade "pip"
! pip uninstall tensorflow --y
! pip install tensorflow==2.15.0
! pip install git+https://github.com/Iacob-Alexandru-Andrei/flower.git@teaching \
    ray=="2.6.3" torch=="2.2.1" torchvision=="0.17.1"  tqdm=="4.67.1" \
    torchsummary=="1.5.1" tensorflow-privacy matplotlib=="3.8.2"
# Out:
# Found existing installation: tensorflow 2.18.0
# Uninstalling tensorflow-2.18.0:
#   Successfully uninstalled tensorflow-2.18.0
# Collecting tensorflow==2.15.0
#   Using cached tensorflow-2.15.0-cp310-cp310-macosx_12_0_arm64.whl.metadata (3.6 kB)
# Collecting tensorflow-macos==2.15.0 (from tensorflow==2.15.0)
#   Using cached tensorflow_macos-2.15.0-cp310-cp310-macosx_12_0_arm64.whl.metadata (4.2 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15.0) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15.0) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15.0) (18.1.1)
# Collecting ml-dtypes~=0.2.0 (from tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Using cached ml_dtypes-0.2.0-cp310-cp310-macosx_10_9_universal2.whl.metadata (20 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15.0) (3.4.0)
# Requirement already satisfied: packaging in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15.0) (22.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15.0) (3.20.3)
# Requirement already satisfied: setuptools in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15.0) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15.0) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/macbook/.local/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15.0) (4.12.2)
# Collecting wrapt<1.15,>=1.11.0 (from tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Downloading wrapt-1.14.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15.0) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15.0) (1.70.0)
# Collecting tensorboard<2.16,>=2.15 (from tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Downloading tensorboard-2.15.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow==2.15.0) (2.15.0)
# Collecting keras<2.16,>=2.15.0 (from tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.15.0->tensorflow==2.15.0) (0.45.1)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Using cached google_auth-2.38.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting google-auth-oauthlib<2,>=0.5 (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Downloading google_auth_oauthlib-1.2.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: markdown>=2.6.8 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0) (3.1.3)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Using cached cachetools-5.5.1-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Using cached pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0) (3.0.2)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow==2.15.0)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Downloading tensorflow-2.15.0-cp310-cp310-macosx_12_0_arm64.whl (2.1 kB)
# Downloading tensorflow_macos-2.15.0-cp310-cp310-macosx_12_0_arm64.whl (208.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.8/208.8 MB 20.2 MB/s eta 0:00:0000:0100:01
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 24.5 MB/s eta 0:00:00
# Downloading ml_dtypes-0.2.0-cp310-cp310-macosx_10_9_universal2.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 6.9 MB/s eta 0:00:00
# Downloading tensorboard-2.15.2-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 23.2 MB/s eta 0:00:00a 0:00:01
# Downloading wrapt-1.14.1-cp310-cp310-macosx_11_0_arm64.whl (35 kB)
# Using cached google_auth-2.38.0-py2.py3-none-any.whl (210 kB)
# Downloading google_auth_oauthlib-1.2.1-py2.py3-none-any.whl (24 kB)
# Using cached cachetools-5.5.1-py3-none-any.whl (9.5 kB)
# Using cached pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Installing collected packages: wrapt, pyasn1, oauthlib, ml-dtypes, keras, cachetools, rsa, requests-oauthlib, pyasn1-modules, google-auth, google-auth-oauthlib, tensorboard, tensorflow-macos, tensorflow
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.17.2
#     Uninstalling wrapt-1.17.2:
#       Successfully uninstalled wrapt-1.17.2
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
#   Attempting uninstall: keras
#     Found existing installation: keras 3.8.0
#     Uninstalling keras-3.8.0:
#       Successfully uninstalled keras-3.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.18.0
#     Uninstalling tensorboard-2.18.0:
#       Successfully uninstalled tensorboard-2.18.0
# Successfully installed cachetools-5.5.1 google-auth-2.38.0 google-auth-oauthlib-1.2.1 keras-2.15.0 ml-dtypes-0.2.0 oauthlib-3.2.2 pyasn1-0.6.1 pyasn1-modules-0.4.1 requests-oauthlib-2.0.0 rsa-4.9 tensorboard-2.15.2 tensorflow-2.15.0 tensorflow-macos-2.15.0 wrapt-1.14.1
# Collecting git+https://github.com/Iacob-Alexandru-Andrei/flower.git@teaching
#   Cloning https://github.com/Iacob-Alexandru-Andrei/flower.git (to revision teaching) to /private/var/folders/6j/51pt41xs611cqzmtybytnss40000gn/T/pip-req-build-h7v_4uky
#   Running command git clone --filter=blob:none --quiet https://github.com/Iacob-Alexandru-Andrei/flower.git /private/var/folders/6j/51pt41xs611cqzmtybytnss40000gn/T/pip-req-build-h7v_4uky
#   Running command git checkout -b teaching --track origin/teaching
#   Switched to a new branch 'teaching'
#   Branch 'teaching' set up to track remote branch 'teaching' from 'origin'.
#   Resolved https://github.com/Iacob-Alexandru-Andrei/flower.git to commit 1c4fcc1d4a6e8022ddf6f94ebedef1b8e70e0fc4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: ray==2.6.3 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (2.6.3)
# Requirement already satisfied: torch==2.2.1 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (2.2.1)
# Requirement already satisfied: torchvision==0.17.1 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (0.17.1)
# Requirement already satisfied: tqdm==4.67.1 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (4.67.1)
# Requirement already satisfied: torchsummary==1.5.1 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (1.5.1)
# Requirement already satisfied: tensorflow-privacy in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (0.9.0)
# Requirement already satisfied: matplotlib==3.8.2 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (3.8.2)
# Requirement already satisfied: click>=7.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from ray==2.6.3) (8.1.8)
# Requirement already satisfied: filelock in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from ray==2.6.3) (3.17.0)
# Requirement already satisfied: jsonschema in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from ray==2.6.3) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from ray==2.6.3) (1.1.0)
# Requirement already satisfied: packaging in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from ray==2.6.3) (22.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from ray==2.6.3) (3.20.3)
# Requirement already satisfied: pyyaml in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from ray==2.6.3) (6.0.2)
# Requirement already satisfied: aiosignal in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from ray==2.6.3) (1.3.2)
# Requirement already satisfied: frozenlist in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from ray==2.6.3) (1.5.0)
# Requirement already satisfied: requests in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from ray==2.6.3) (2.32.3)
# Requirement already satisfied: grpcio>=1.42.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from ray==2.6.3) (1.70.0)
# Requirement already satisfied: numpy>=1.19.3 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from ray==2.6.3) (1.26.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/macbook/.local/lib/python3.10/site-packages (from torch==2.2.1) (4.12.2)
# Requirement already satisfied: sympy in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from torch==2.2.1) (1.13.1)
# Requirement already satisfied: networkx in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from torch==2.2.1) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from torch==2.2.1) (3.1.5)
# Requirement already satisfied: fsspec in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from torch==2.2.1) (2025.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from torchvision==0.17.1) (11.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from matplotlib==3.8.2) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from matplotlib==3.8.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from matplotlib==3.8.2) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from matplotlib==3.8.2) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from matplotlib==3.8.2) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from matplotlib==3.8.2) (2.9.0.post0)
# Requirement already satisfied: cryptography<42.0.0,>=41.0.2 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from flwr==1.7.0) (41.0.7)
# Requirement already satisfied: iterators<0.0.3,>=0.0.2 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from flwr==1.7.0) (0.0.2)
# Requirement already satisfied: pycryptodome<4.0.0,>=3.18.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from flwr==1.7.0) (3.21.0)
# Requirement already satisfied: absl-py==1.*,>=1.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-privacy) (1.4.0)
# Requirement already satisfied: dm-tree==0.1.8 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-privacy) (0.1.8)
# Requirement already satisfied: dp-accounting==0.4.3 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-privacy) (0.4.3)
# Requirement already satisfied: scikit-learn==1.*,>=1.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-privacy) (1.6.1)
# Requirement already satisfied: scipy~=1.9 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-privacy) (1.15.1)
# Requirement already satisfied: tensorflow-estimator~=2.4 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-privacy) (2.15.0)
# Requirement already satisfied: tensorflow-probability~=0.22.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-privacy) (0.22.1)
# Requirement already satisfied: tensorflow~=2.4 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-privacy) (2.15.0)
# Requirement already satisfied: attrs>=22 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from dp-accounting==0.4.3->tensorflow-privacy) (25.1.0)
# Requirement already satisfied: mpmath~=1.2 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from dp-accounting==0.4.3->tensorflow-privacy) (1.3.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from scikit-learn==1.*,>=1.0->tensorflow-privacy) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from scikit-learn==1.*,>=1.0->tensorflow-privacy) (3.5.0)
# Requirement already satisfied: cffi>=1.12 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from cryptography<42.0.0,>=41.0.2->flwr==1.7.0) (1.17.1)
# Requirement already satisfied: six>=1.5 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib==3.8.2) (1.17.0)
# Requirement already satisfied: tensorflow-macos==2.15.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow~=2.4->tensorflow-privacy) (2.15.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow~=2.4->tensorflow-privacy) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow~=2.4->tensorflow-privacy) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow~=2.4->tensorflow-privacy) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow~=2.4->tensorflow-privacy) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow~=2.4->tensorflow-privacy) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow~=2.4->tensorflow-privacy) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow~=2.4->tensorflow-privacy) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow~=2.4->tensorflow-privacy) (3.4.0)
# Requirement already satisfied: setuptools in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow~=2.4->tensorflow-privacy) (75.8.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow~=2.4->tensorflow-privacy) (2.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow~=2.4->tensorflow-privacy) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow~=2.4->tensorflow-privacy) (0.37.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow~=2.4->tensorflow-privacy) (2.15.2)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow~=2.4->tensorflow-privacy) (2.15.0)
# Requirement already satisfied: decorator in /Users/macbook/.local/lib/python3.10/site-packages (from tensorflow-probability~=0.22.0->tensorflow-privacy) (5.1.1)
# Requirement already satisfied: cloudpickle>=1.3 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorflow-probability~=0.22.0->tensorflow-privacy) (3.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from jinja2->torch==2.2.1) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from jsonschema->ray==2.6.3) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from jsonschema->ray==2.6.3) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from jsonschema->ray==2.6.3) (0.22.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from requests->ray==2.6.3) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from requests->ray==2.6.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from requests->ray==2.6.3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from requests->ray==2.6.3) (2025.1.31)
# Requirement already satisfied: pycparser in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from cffi>=1.12->cryptography<42.0.0,>=41.0.2->flwr==1.7.0) (2.22)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.15.0->tensorflow~=2.4->tensorflow-privacy) (0.45.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow~=2.4->tensorflow-privacy) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow~=2.4->tensorflow-privacy) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow~=2.4->tensorflow-privacy) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow~=2.4->tensorflow-privacy) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow~=2.4->tensorflow-privacy) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow~=2.4->tensorflow-privacy) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow~=2.4->tensorflow-privacy) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow~=2.4->tensorflow-privacy) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow~=2.4->tensorflow-privacy) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow~=2.4->tensorflow-privacy) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/macbook/Desktop/L361/L361-Federated-Learning/.conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow~=2.4->tensorflow-privacy) (3.2.2)

# %%
# Imports
import random
from collections.abc import Callable
from copy import deepcopy
from pathlib import Path
from typing import Any
from logging import INFO


import flwr as fl
import numpy as np

import pandas as pd
import torch
from torch import nn
from flwr.common import (
    log,
    MetricsAggregationFn,
)
from flwr.client import Client
from flwr.common.parameter import ndarrays_to_parameters, parameters_to_ndarrays
from flwr.common.typing import NDArrays, Parameters, Scalar
from flwr.server import ServerConfig, History
from flwr.server.server_returns_parameters import ReturnParametersServer as Server
from flwr.server.client_manager import ClientManager
from flwr.server.client_proxy import ClientProxy
from flwr.server.strategy import Strategy
from torch.nn import Module
from torch.utils.data import DataLoader
from enum import IntEnum
from datetime import datetime, timezone
import json

import math


# Add new seeds here for easy autocomplete
class Seeds(IntEnum):
    """Seeds for reproducibility."""

    DEFAULT = 1337


np.random.seed(Seeds.DEFAULT)
random.seed(Seeds.DEFAULT)
torch.manual_seed(Seeds.DEFAULT)
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True

PathType = Path | str | None

# %% [markdown]
# ### Paths

# %%
home_dir = Path.cwd()
dataset_dir: Path = home_dir / "femnist"
data_dir: Path = dataset_dir / "data"
centralized_partition: Path = dataset_dir / "client_data_mappings" / "centralized"
centralized_mapping: Path = dataset_dir / "client_data_mappings" / "centralized" / "0"
federated_partition: Path = dataset_dir / "client_data_mappings" / "fed_natural"

# %% [markdown]
# ### Useful Python functions

# %%
def convert(o: Any) -> int | float:
    """Convert input object to Python numerical if numpy."""
    # type: ignore[reportGeneralTypeIssues]
    if isinstance(o, np.int32 | np.int64):
        return int(o)
    # type: ignore[reportGeneralTypeIssues]
    if isinstance(o, np.float32 | np.float64):
        return float(o)
    raise TypeError


def save_history(hist: History, name: str) -> None:
    """Save history from simulation to file."""
    time = int(datetime.now(timezone.utc).timestamp())
    path = home_dir / "histories"
    path.mkdir(exist_ok=True)
    path = path / f"hist_{time}_{name}.json"
    with open(path, "w", encoding="utf-8") as f:
        json.dump(hist.__dict__, f, ensure_ascii=False, indent=4, default=convert)


def start_seeded_simulation(
    client_fn: Callable[[str], Client],
    num_clients: int,
    config: ServerConfig,
    strategy: Strategy,
    name: str,
    seed: int = Seeds.DEFAULT,
    iteration: int = 0,
    server: Server | None = None,
) -> tuple[list[tuple[int, NDArrays]], History]:
    """Wrap simulation to always seed client selection."""
    np.random.seed(seed ^ iteration)
    torch.manual_seed(seed ^ iteration)
    random.seed(seed ^ iteration)
    parameter_list, hist = fl.simulation.start_simulation_no_ray(
        client_fn=client_fn,
        num_clients=num_clients,
        client_resources={},
        config=config,
        strategy=strategy,
        server=server,
    )
    save_history(hist, name)
    return parameter_list, hist

# %% [markdown]
# ### Dataset

# %%
# Decompress dataset
if not dataset_dir.exists():
    # !tar -xf {str(home_dir)}/femnist.tar.gz -C {str(home_dir)} 2> /dev/null
    log(INFO, f"Dataset extracted in {dataset_dir}")

# %%
from common.client import FlowerClient, get_flower_client_generator
from common.client_manager import CustomClientManager
from common.strategy import DeterministicSampleFedAvg as FedAvgM
from common.client_utils import (
    get_network_generator_cnn,
    get_model_parameters,
    aggregate_weighted_average,
    get_federated_evaluation_function,
    get_default_test_config,
    get_default_train_config,
    get_device,
    DPAdaptiveClipFlagError,
    DPClientNormBitError,
)
from itertools import starmap

# %% [markdown]
# # 1. Introduction.

# %% [markdown]
# Welcome to the fourth lab session in our FL course. Having explored standard FL, data heterogeneity and device heterogeneity, we now focus on one of FL's main selling points: privacy.
#
# The two methods for achieving privacy we will explore are client-level [**Differential Privacy**](https://ieeexplore.ieee.org/abstract/document/9069945) and [**Secure Aggregation**](https://research.google/pubs/pub45808/). Intuitively, the **first** provides statistical guarantees on how distinguishable a single client's pseudo-gradient is compared to the aggregated pseudo-gradient without its contribution.
#
# <!-- a probabilistic bound on how distinct the final model trained using the data of a given client would be from the same model trained without data from that client (thus if a client contains all samples from a given class, it should be difficult for the model to predict that class as it would have to violate DP).  -->
#
# In an ideal privacy scenario, we would prefer it if two global models trained with or without the data of a given client were indistinguishable.
# The **second** is a cryptography-based solution that effectively erases the ability to identify a client during aggregation by encrypting all client model updates to produce the correct aggregate when summed.
#
# As these topics are pretty in-depth, we will not cover them to the same level of detail as previous labs concerning theoretical subjects (such as data heterogeneity in lab 2). This lab will be primarily experimental to test the algorithms put into practice. We will, however, begin with a light introduction. Suppose you are interested in learning more about the subject. In that case, we may recommend the following papers [Deep Learning with Differential Privacy](https://arxiv.org/pdf/1607.00133.pdf) \[1], [Learning Differentially Private Recurrent Language Models](https://arxiv.org/pdf/1710.06963.pdf) \[2] and [Differentially private learning with adaptive clipping](https://arxiv.org/abs/1905.03871) \[3] on the DP front. For secure aggregation consider the original paper [Practical Secure Aggregation for Federated Learning on User-Held Data](https://arxiv.org/pdf/1611.04482.pdf) \[4] and the improved [LightSecAgg](https://arxiv.org/abs/2109.14236) \[5].
#
# Secure aggregation does not harm the model's accuracy and demands only increased communication. Any samples involved in training may still be reconstructed in an attack; however, knowing who contributed the samples will not be possible. Thus, while the implementation is complex, its behaviour is predictable and shall be reserved for the end of the notebook as we are only concerned with measuring communication costs and answering conceptual questions. As such, let us dive into Differential Privacy after the following well-known imports.
#
# > **Important** The entire notebook has been tested in a GPU-enabled Google Colab environment, which runs at around 6 minutes per FL experiment. All experiments require you to vary at most one parameter at a time, so please use a for loop to generate a list of histories rather than trying to manage multiple cells---most experiments rely on one run we create for demonstration purposes to cover one of the desire parameter values. We have purposefully reduced the size of the federated test set significantly and have also reduced the overall number of clients used during FL experimentation. If you are more constrained in your resources (e.g., you have run out of Google accounts that can get a GPU or you get an error peculiar to your exact colab machine), let us know either on Slack or in your submission, and we will either help you set up the code locally, potentially provide you with history objects, or offer take this into account during marking.
#
# Citations:
#
# 1.  Abadi, Martin, et al. "Deep learning with differential privacy." Proceedings of the 2016 ACM SIGSAC conference on computer and communications security. 2016.
# 2.  McMahan, H. Brendan, et al. "Learning differentially private recurrent language models." arXiv preprint arXiv:1710.06963 (2017).
# 3.  Thakkar, Om, Galen Andrew, and H. Brendan McMahan. "Differentially private learning with adaptive clipping." arXiv e-prints (2019): arXiv-1905.
# 4.  Bonawitz, Keith, et al. "Practical secure aggregation for federated learning on user-held data." arXiv preprint arXiv:1611.04482 (2016).
# 5.  So, Jinhyun, et al. "Lightsecagg: a lightweight and versatile design for secure aggregation in federated learning." Proceedings of Machine Learning and Systems 4 (2022): 694-720.

# %% [markdown]
# # 2.Deep Learning With Differential Privacy

# %% [markdown]
# Before diving into a definition of Differential Privacy adapted to an FL context, we shall begin with the first version of DP applied to Deep Learning based on the aforementioned paper.
#
# The authors of the original extension of _DP to Deep Learning_ justify the need for such a privacy mechanism based on the possibility that an attacker may reconstruct specific samples from the data perfectly in a sensitive context, such as facial recognition, while only having **black-box** access to the trained model. However, their algorithm for DP protects against even adversaries with full knowledge of the training procedure, access to the parameters and potential control over parts of the dataset.
#
# Their **definition** of DP is as follows: a randomised mechanism $M: D ⟶ R$ (a neural network training procedure, in our case) satisfies $(ϵ,δ)$-differential privacy for any $S⊆R$ (a subset of outputs in the range $R$) if $Pr[M(d) \in S] \leq e^{\epsilon} Pr[M(d') \in S] + \delta$ holds, where $d∈D$ and $d'∈D$ are adjacent sets (datasets) of the same domain $D$ (set of all the possible datasets), i.e., they differ by only one record (a training sample, in our case). We can **interpret** this as stating that the probability of getting a particular output from our model when not including a specific sample should be close to the probability of getting the same output had we not included the sample. Specifically, when $\epsilon=0$, the two probabilities are equal, and it is impossible to find out if that sample was included in the training set. The bigger $\epsilon$ is the lower protection is. The probability that the model produces different outputs when trained on adjacent datasets increases exponentially with $\epsilon$.
#
# > Importantly, the original definition of DP and the one you may have encountered before only contained the exponential term _without the_ $\delta$; however, this resulted in _very strong requirements_ for not breaking privacy. This new form, $(\epsilon, \delta)$ privacy relaxed the requirement. Informally, it can be interpreted as allowing privacy at a given $\epsilon$ level to be broken with _probability_ $1-\delta$. We do not have the scale of experimentation necessary to consider both in this lab, as such we will focus on $\epsilon$ values at the detriment of analysing changes in $\delta$. For the experiments in this lab, you can consider DP to be defined entirely in terms of ϵ. Formally, the transition to $(\epsilon, \delta)$ delta was necessary to move from an inefficient noise generation mechanism to Gaussian noise as ML models are much more complex than typical vector-valued functions.

# %% [markdown]
# Differentially private **approximations** of functions are usually **constructed** by the addition of noise proportional to the sensitivity of the function---think of it as the maximal impact that the addition or removal of a data point can have upon the output of the function. From now on, we shall refer to this noise level as the **`noise_multiplier`** as it scales the noise multiplicatively based on the sensitivity. When DP was extended to a DL context, making the system differentially private by intervening upon the gradients used during training rather than the final model was significantly more straightforward than operating on the model as a function after training. In the context of ML model updates (gradient descent steps or pseudo-gradients in FL), their sensitivity is generally defined in terms of the l2 norm (when noise is Gaussian) of the update, and the noise is thus scaled based on this norm.
#
# As such, the **original DP-SGD** operates as follows:
#
# 1.  _Compute_ the derivative concerning each sample (not minibatch).
# 2.  _Clip_ the L2 norm of the derivative so it falls below a given bound.
# 3.  _Aggregate_ these clipped derivatives and _add_ Gaussian _noise_ to obfuscate the impact of specific samples used to compute the gradients. Here, the noise is proportional to the L2 bound.
#
# Suppose we reframe DP to the original context of databases and records. In that case, the larger the number of noisy answers the database offers, the more an attacker can eliminate the noise by looking at the entire distribution of answers. Similarly, the more samples out of the total an ML model sees (or the more times it sees the same sample), the more the noise of the sample gradients average out. For a model to be trained for an extended period, it is thus necessary to use a higher `noise_multiplier`. We shall soon extend this trade-off to clients within an FL context.
#
# While this process operates reasonably in the context of centralised, applying DP-SGD on every client in FL is **problematic**, given the reduced efficiency of the training method. As a result of this inefficiency, the federated model will likely incur significant drops in its already low performance. Furthermore, multiple studies have confirmed that applying DP locally has disastrous effects on the accuracy of the final federated model.

# %% [markdown]
# # 3.User-level Differential Privacy

# %% [markdown]
# Differential privacy at a client/user level in FL follows the same **definition**, except adjacent datasets are constructed by adding or removing all samples from a given client. Thus, under _maximum privacy scenarios_, with $\epsilon=0$ and $\delta=0$, two models should behave identically regardless of the presence of a specific user in the federation. For user-level DP, training with more users (rather than samples) results in the degradation of privacy. Thus, the **`noise_multiplier`** necessary to make an FL system differentially private with respect to an L2 norm bound depends on the total number of users, the number of users sampled every round and the number of rounds.
#
# **DP-FedAvg** represents a reasonably direct analogue to DP-SGD as it applies the same process to FL pseudo-gradients that DP-SGD applies to gradients generated by one sample. Namely, it clips the gradients based on the L2 norm on the local client after training. The server then adds Gaussian noise related to the L2 norm bound via the `noise_multiplier` when it receives the gradients.
#
# However, this extension is hampered by the fact that DP-SGD assumes an IID distribution of samples. As we, clients in FL contain **non-IID data** and have skewed numbers of samples. As such, for the theoretical privacy guarantee to hold DP-FedAvg **must assume** that _clients will not drop_ out and that the overall set of available clients in the population is static---both being significant limitations. Furthermore, _unweighted aggregation_ is usually enforced since weighted aggregation is more likely to leak data from a specific user. An _additional note_ worth making is that even when violating the theoretical assumptions of DP, applying noise and clipping gradients is still likely to make reconstructing data belonging to a specific client more difficult in practice.
#
# One final theoretical concern worth addressing prior to experimentation is the **nature of the L2 norm clipping**. Two specific _questions_ arise in the early works discussing DP-FedAvg:
#
# - Should the clipping be done per layer or uniformly across the entire model? Consider scenarios where a single large layer encodes all the relevant information about a specific user and is not clipped because the overall L2 norm of the gradient is lower than a generic bound.
# - How should a L2 bound be chosen and changed? If the model updates are too small, the model is less likely to learn. However, a more oversized bound implies more noise and thus leads to potential degradation yet again.
#
# These questions have been answered by follow-up work. On the _first point_, this stack overflow answer by one of the authors of paper \[3] above indicates that per-layer bounding leads to worse performance as it is harsher for little benefit. On the _second point_, methods for efficiently tracking a given quantile of the L2 distribution amongst client updates were proposed in \[3]. We will glance at this adaptive mechanism in today's lab but shall not examine it in detail.

# %% [markdown]
# **Question 1 (Part II ✅ | Part III/MPhil ✅):**
#
# (This is a conceptual question. Please do not provide more than three sentences per sub-question.)
#
# Consider two applications of FL, next-word prediction and image classification based on personal user data from smartphones.
#
# 1. What kind of sensitive information could be extracted from models trained on these tasks?
# 2. How would DP help preserve privacy for each task when applied on a per-sample versus per-client-dataset level?

# %% [markdown]
# ---
# **Question 1 Answer:**
#
# Part 1: For the next word prediction task, it may be possible to extract sensitive information that the user might have entered such as private messages, passwords, credit card number, social security number, health details etc. For the image classification task, it may be possible to extract sensitive images of the user, their family, friends, location, pictures of events as well as sensitive documents that user has taken a picture of or other personal images that the user might have stored on their device.
#
# Part 2: Using DP in a per-sample basis could help obfuscating each data point that the client has contributed to the model making it more difficult to extract/connect a specific picture or text regarding/to the user. However, using DP on a per-client-dataset level could still help in preserving the privacy of the user by adding noise to the entire dataset but it might be still possible to identify some connection/relationship between the data points in the client-dataset as the noise is added to the entire dataset and not to each data point individually. This would potentially provide less privacy compared to per-sample level DP.
#
# ---

# %% [markdown]
# **Question 2 (Part III/MPhil ✅):**
#
# (This is a **short** conceptual question. Please do not provide more than four sentences as an answer.)
#
# Considering a scenario of a multimodal LLM that may or may not have been trained on your images, how would you test for privacy leakage given access to:
#
# 1.  Only a chat UI to interact with the model.
# 2.  The full model and all of your data that could have gone into it.

# %% [markdown]
# ---
#
# **Question 2 Answer:**
#
# Part 1: We could test for privacy leakage by constructing a set of queries that contain specific details about our images such as the location, time, people in the image, etc. and observe the responses from the model. Another option is to provide an image to the model (if it is possible) and ask questions about the image that otherwise would not be possible to know such as the name of the people on the image, location, time, etc.
#
# Part 2: If full access to the model is given the privacy leakage can be tested by doing a gradient inversion attack such as [GI-SMN](https://arxiv.org/pdf/2405.03516) presented by Qian et al. to get the original data that was used to train the model. Another option to test for privacy leakage is to use a [membership inference attack](https://dl.acm.org/doi/pdf/10.1145/3523273) to see the difference in outputs such as confidence scores, token probabilities, or perplexity regarding the data that was used to train the model and the one that was not.
#
#
#
# ---

# %% [markdown]
# ## 3.1 Fixed Norm Bound DP
#
# Given the highly abstract definition of privacy that DP uses, could you think of ways to test the effectiveness of DP practically?

# %% [markdown]
# We shall begin by implementing the `DPFedAvg` strategy based on the description above using a static bound on the L2 norm of clients. While we could near-effortlessly add client-level Differential Privacy by using wrappers provided by Flower, implementing its components should be straightforward and informative.
#
# The first cell provides utilities for gradient clipping and noise injection. The clipping operates via simple multiplication.

# %%
def compute_model_delta(
    trained_parameters: NDArrays, og_parameters: NDArrays
) -> NDArrays:
    """Compute the delta between two sets of parameters."""
    return list(
        starmap(np.subtract, zip(trained_parameters, og_parameters, strict=True))
    )


def compute_norm(update: NDArrays) -> float:
    """Compute the l2 norm of a parameter update.

    It will account for mismatched NumPy array shapes, to be used in clipping.
    """
    flat_update = update[0]
    for i in range(1, len(update)):
        flat_update = np.append(flat_update, update[i])
    squared_update = np.square(flat_update)
    norm_sum = np.sum(squared_update)
    norm = np.sqrt(norm_sum)
    return norm


def clip_by_l2(update: NDArrays, threshold: float) -> tuple[NDArrays, bool]:
    """Scales the update so thats its L2 norm is upper-bound to threshold."""
    update_norm = compute_norm(update)
    scaling_factor = min(1, threshold / update_norm)
    update_clipped: NDArrays = [layer * scaling_factor for layer in update]
    return update_clipped, (scaling_factor < 1)


def add_gaussian_noise(update: NDArrays, std_dev: float) -> NDArrays:
    """Add Gaussian noise to each floating point value."""
    update_noised = [
        layer + np.random.normal(0, std_dev, layer.shape) for layer in update
    ]
    return update_noised

# %% [markdown]
# These components are all we need to design a DP client which can add noise to its updates according to parameters received from the strategy. According to the evaluated threat model, the flower implementation allows noise injection to be equivalently done on the client or server. We shall assume a trustworthy server for this lab and eschew adding noise on the clients.
#
# The client training procedure shall follow the description above verbatim and proceed as follows:
#
# 1.  The client receives the parameters and standard configuration arguments as in previous labs.
# 2.  It also receives a maximum bound on the L2 norm of the trained model.
# 3.  The model is trained, and the client computes the delta or **update** between its parameters and the original ones received.
# 4.  The client computes the ratio between the L2 norm of its local update and the maximum it received. It then rescales all the weights in the update by this ratio, so the final norm is at-most the bound---since $||\alpha \times w||_2 = |\alpha| \times ||w||_2$.
# 5.  The client applies the clipped update to the original parameters and potentially adds Gaussian noise---if this does not already happen on the server---before returning them.

# %%
np.random.seed(Seeds.DEFAULT)
random.seed(Seeds.DEFAULT)
torch.manual_seed(Seeds.DEFAULT)
network_generator_cnn = get_network_generator_cnn()
seed_net_cnn = network_generator_cnn()
seed_model_cnn_params: NDArrays = get_model_parameters(seed_net_cnn)
federated_evaluation_function = get_federated_evaluation_function(
    data_dir=data_dir,
    centralized_mapping=centralized_mapping,
    device=get_device(),
    batch_size=get_default_test_config()["batch_size"],
    num_workers=get_default_test_config()["num_workers"],
    model_generator=network_generator_cnn,
    criterion=nn.CrossEntropyLoss(),
)
# Out:
# INFO flwr 2025-02-15 19:17:45,044 | client_utils.py:423 | Reduced federated test_set size from 28510 to a size of 1500 mean index: 14726.628666666667
# INFO:flwr:Reduced federated test_set size from 28510 to a size of 1500 mean index: 14726.628666666667

# %%
# Based on the original implementation by Vasundhara Agarwal
class DPFlowerRayClient(FlowerClient):
    """Extends the FlowerClient class to implement DP-FedAvg."""

    def fit(
        self, parameters: NDArrays, config: dict[str, Scalar], **kwargs: dict[str, Any]
    ) -> tuple[NDArrays, int, dict]:
        """Receive and train a model on the local client data.

        It uswa parameters from the config dict while injecting gaussian noise into the
        parameter update.

        Args:
            net (NDArrays): Pytorch model parameters
            config (dict[str, Scalar]): Dictionary describing the training parameters

        Returns
        -------
            tuple[NDArrays, int, dict]: Returns the updated model, the size of the
                local dataset and other metrics
        """
        # Create a copy of the initial parameters
        og_parameters = deepcopy(parameters)

        # Only create model right before training/testing
        # To lower memory usage when idle
        net = self.set_parameters(parameters)
        net.to(self.device)
        train_loader: DataLoader = self._create_data_loader(
            config, name="train", **kwargs
        )
        train_loss = self._train(
            net, train_loader=train_loader, config=config, **kwargs
        )

        # Metrics dict since the DP strategy requires an indicator
        # to be returned if the model updates was not clipped on the client
        # and should be clipped on the server
        metrics = {"train_loss": train_loss}

        trained_parameters = get_model_parameters(net)
        # Calculate the delta between the two models
        model_update = list(
            starmap(np.subtract, zip(trained_parameters, og_parameters, strict=True))
        )

        metrics['norm_prior_clip'] = compute_norm(model_update)

        # Clip the delta so all of the updates fall bellow
        # The same norm
        model_update, clipped = clip_by_l2(model_update, config["dpfedavg_clip_norm"])

        if "dpfedavg_noise_stddev" in config:
            # Noising
            model_update = add_gaussian_noise(
                model_update, config["dpfedavg_noise_stddev"]
            )

        for i, _ in enumerate(og_parameters):
            trained_parameters[i] = og_parameters[i] + model_update[i]

        # Calculating value of norm indicator bit, required for adaptive clipping
        if "dpfedavg_adaptive_clip_enabled" in config:
            if not isinstance(config["dpfedavg_adaptive_clip_enabled"], bool):
                raise DPAdaptiveClipFlagError(
                    "dpfedavg_adaptive_clip_enabled should be a boolean-valued flag."
                )
            metrics["dpfedavg_norm_bit"] = not clipped

        return trained_parameters, len(train_loader), metrics

# %% [markdown]
# The following cell will construct a generator for this client class capable of filtering participants with less than one batch of data. This is necessary to avoid failures as "DPFedAvg" is not tolerant of dropouts.

# %%
fl_client_gen = get_flower_client_generator(
    network_generator_cnn, federated_partition, data_dir
)
client_to_num_sample: list[tuple[int, int]] = [
    (cid, fl_client_gen(i).get_train_set_size()) for i, cid in enumerate(range(3229))
]
client_samples_dataframe = pd.DataFrame(
    client_to_num_sample, columns=["cid", "n_samples"]
)

# Remove clients with less than 32 samples corresponding to the default batch size
min_n_samples = 32
client_samples_dataframe = client_samples_dataframe.drop(
    client_samples_dataframe[client_samples_dataframe.n_samples < min_n_samples].index,
)
client_samples_dataframe.reset_index(drop=True)
num_total_clients = len(client_samples_dataframe)
log(INFO, "Num total clients: %s", num_total_clients)


def get_dp_client_generator(
    model_generator: Callable[[], Module],
    data_dir: Path,
    partition_dir: Path,
    mapping_fn: Callable[[int], int] | None = lambda x: client_samples_dataframe.cid[x],
) -> Callable[[str], FlowerClient]:
    """Wrap function for the client instance generator.

    This provides the client generator with a model generator function.
    Also, the partition directory must be passed.
    A mapping function could be used for filtering/ordering clients.

    Args:
        data_dir (Path): path to the dataset folder.
        model_generator (Callable[[], Module]): model generator function.
        partition_dir (Path): directory containing the partition.
        mapping_fn (Optional[Callable[[int], int]]): function mapping sorted/filtered
            ids to real cid.

    Returns
    -------
        Callable[[str], FlowerRayClient]: client instance.
    """

    def client_fn(cid: str) -> DPFlowerRayClient:
        """Create a single client instance given the client id `cid`.

        Args:
            cid (str): client id, Flower requires this to of type str.

        Returns
        -------
            FlowerRayClient: client instance.
        """
        return DPFlowerRayClient(
            cid=mapping_fn(int(cid)) if mapping_fn is not None else int(cid),
            data_dir=data_dir,
            partition_dir=partition_dir,
            model_generator=model_generator,
        )

    return client_fn
# Out:
# INFO flwr 2025-02-15 19:17:47,727 | client.py:51 | Creating client with cid: 0
# INFO:flwr:Creating client with cid: 0
# INFO flwr 2025-02-15 19:17:47,730 | client.py:51 | Creating client with cid: 1
# INFO:flwr:Creating client with cid: 1
# INFO flwr 2025-02-15 19:17:47,731 | client.py:51 | Creating client with cid: 2
# INFO:flwr:Creating client with cid: 2
# INFO flwr 2025-02-15 19:17:47,733 | client.py:51 | Creating client with cid: 3
# INFO:flwr:Creating client with cid: 3
# INFO flwr 2025-02-15 19:17:47,734 | client.py:51 | Creating client with cid: 4
# INFO:flwr:Creating client with cid: 4
# INFO flwr 2025-02-15 19:17:47,736 | client.py:51 | Creating client with cid: 5
# INFO:flwr:Creating client with cid: 5
# INFO flwr 2025-02-15 19:17:47,738 | client.py:51 | Creating client with cid: 6
# INFO:flwr:Creating client with cid: 6
# INFO flwr 2025-02-15 19:17:47,740 | client.py:51 | Creating client with cid: 7
# INFO:flwr:Creating client with cid: 7
# INFO flwr 2025-02-15 19:17:47,741 | client.py:51 | Creating client with cid: 8
# INFO:flwr:Creating client with cid: 8
# INFO flwr 2025-02-15 19:17:47,743 | client.py:51 | Creating client with cid: 9
# INFO:flwr:Creating client with cid: 9
# INFO flwr 2025-02-15 19:17:47,744 | client.py:51 | Creating client with cid: 10
# INFO:flwr:Creating client with cid: 10
# INFO flwr 2025-02-15 19:17:47,746 | client.py:51 | Creating client with cid: 11
# INFO:flwr:Creating client with cid: 11
# INFO flwr 2025-02-15 19:17:47,747 | client.py:51 | Creating client with cid: 12
# INFO:flwr:Creating client with cid: 12
# INFO flwr 2025-02-15 19:17:47,748 | client.py:51 | Creating client with cid: 13
# INFO:flwr:Creating client with cid: 13
# INFO flwr 2025-02-15 19:17:47,750 | client.py:51 | Creating client with cid: 14
# INFO:flwr:Creating client with cid: 14
# INFO flwr 2025-02-15 19:17:47,752 | client.py:51 | Creating client with cid: 15
# INFO:flwr:Creating client with cid: 15
# INFO flwr 2025-02-15 19:17:47,753 | client.py:51 | Creating client with cid: 16
# INFO:flwr:Creating client with cid: 16
# INFO flwr 2025-02-15 19:17:47,755 | client.py:51 | Creating client with cid: 17
# INFO:flwr:Creating client with cid: 17
# INFO flwr 2025-02-15 19:17:47,757 | client.py:51 | Creating client with cid: 18
# INFO:flwr:Creating client with cid: 18
# INFO flwr 2025-02-15 19:17:47,758 | client.py:51 | Creating client with cid: 19
# INFO:flwr:Creating client with cid: 19
# INFO flwr 2025-02-15 19:17:47,759 | client.py:51 | Creating client with cid: 20
# INFO:flwr:Creating client with cid: 20
# INFO flwr 2025-02-15 19:17:47,760 | client.py:51 | Creating client with cid: 21
# INFO:flwr:Creating client with cid: 21
# INFO flwr 2025-02-15 19:17:47,762 | client.py:51 | Creating client with cid: 22
# INFO:flwr:Creating client with cid: 22
# INFO flwr 2025-02-15 19:17:47,763 | client.py:51 | Creating client with cid: 23
# INFO:flwr:Creating client with cid: 23
# INFO flwr 2025-02-15 19:17:47,766 | client.py:51 | Creating client with cid: 24
# INFO:flwr:Creating client with cid: 24
# INFO flwr 2025-02-15 19:17:47,768 | client.py:51 | Creating client with cid: 25
# INFO:flwr:Creating client with cid: 25
# INFO flwr 2025-02-15 19:17:47,772 | client.py:51 | Creating client with cid: 26
# INFO:flwr:Creating client with cid: 26
# INFO flwr 2025-02-15 19:17:47,773 | client.py:51 | Creating client with cid: 27
# INFO:flwr:Creating client with cid: 27
# INFO flwr 2025-02-15 19:17:47,775 | client.py:51 | Creating client with cid: 28
# INFO:flwr:Creating client with cid: 28
# INFO flwr 2025-02-15 19:17:47,776 | client.py:51 | Creating client with cid: 29
# INFO:flwr:Creating client with cid: 29
# INFO flwr 2025-02-15 19:17:47,781 | client.py:51 | Creating client with cid: 30
# INFO:flwr:Creating client with cid: 30
# INFO flwr 2025-02-15 19:17:47,782 | client.py:51 | Creating client with cid: 31
# INFO:flwr:Creating client with cid: 31
# INFO flwr 2025-02-15 19:17:47,787 | client.py:51 | Creating client with cid: 32
# INFO:flwr:Creating client with cid: 32
# INFO flwr 2025-02-15 19:17:47,790 | client.py:51 | Creating client with cid: 33
# INFO:flwr:Creating client with cid: 33
# INFO flwr 2025-02-15 19:17:47,792 | client.py:51 | Creating client with cid: 34
# INFO:flwr:Creating client with cid: 34
# INFO flwr 2025-02-15 19:17:47,794 | client.py:51 | Creating client with cid: 35
# INFO:flwr:Creating client with cid: 35
# INFO flwr 2025-02-15 19:17:47,796 | client.py:51 | Creating client with cid: 36
# INFO:flwr:Creating client with cid: 36
# INFO flwr 2025-02-15 19:17:47,811 | client.py:51 | Creating client with cid: 37
# INFO:flwr:Creating client with cid: 37
# INFO flwr 2025-02-15 19:17:47,818 | client.py:51 | Creating client with cid: 38
# INFO:flwr:Creating client with cid: 38
# INFO flwr 2025-02-15 19:17:47,824 | client.py:51 | Creating client with cid: 39
# INFO:flwr:Creating client with cid: 39
# INFO flwr 2025-02-15 19:17:47,829 | client.py:51 | Creating client with cid: 40
# INFO:flwr:Creating client with cid: 40
# INFO flwr 2025-02-15 19:17:47,834 | client.py:51 | Creating client with cid: 41
# INFO:flwr:Creating client with cid: 41
# INFO flwr 2025-02-15 19:17:47,839 | client.py:51 | Creating client with cid: 42
# INFO:flwr:Creating client with cid: 42
# INFO flwr 2025-02-15 19:17:47,844 | client.py:51 | Creating client with cid: 43
# INFO:flwr:Creating client with cid: 43
# INFO flwr 2025-02-15 19:17:47,847 | client.py:51 | Creating client with cid: 44
# INFO:flwr:Creating client with cid: 44
# INFO flwr 2025-02-15 19:17:47,849 | client.py:51 | Creating client with cid: 45
# INFO:flwr:Creating client with cid: 45
# INFO flwr 2025-02-15 19:17:47,851 | client.py:51 | Creating client with cid: 46
# INFO:flwr:Creating client with cid: 46
# INFO flwr 2025-02-15 19:17:47,855 | client.py:51 | Creating client with cid: 47
# INFO:flwr:Creating client with cid: 47
# INFO flwr 2025-02-15 19:17:47,858 | client.py:51 | Creating client with cid: 48
# INFO:flwr:Creating client with cid: 48
# INFO flwr 2025-02-15 19:17:47,861 | client.py:51 | Creating client with cid: 49
# INFO:flwr:Creating client with cid: 49
# INFO flwr 2025-02-15 19:17:47,863 | client.py:51 | Creating client with cid: 50
# INFO:flwr:Creating client with cid: 50
# INFO flwr 2025-02-15 19:17:47,865 | client.py:51 | Creating client with cid: 51
# INFO:flwr:Creating client with cid: 51
# INFO flwr 2025-02-15 19:17:47,869 | client.py:51 | Creating client with cid: 52
# INFO:flwr:Creating client with cid: 52
# INFO flwr 2025-02-15 19:17:47,872 | client.py:51 | Creating client with cid: 53
# INFO:flwr:Creating client with cid: 53
# INFO flwr 2025-02-15 19:17:47,873 | client.py:51 | Creating client with cid: 54
# INFO:flwr:Creating client with cid: 54
# INFO flwr 2025-02-15 19:17:47,878 | client.py:51 | Creating client with cid: 55
# INFO:flwr:Creating client with cid: 55
# INFO flwr 2025-02-15 19:17:47,883 | client.py:51 | Creating client with cid: 56
# INFO:flwr:Creating client with cid: 56
# INFO flwr 2025-02-15 19:17:47,885 | client.py:51 | Creating client with cid: 57
# INFO:flwr:Creating client with cid: 57
# INFO flwr 2025-02-15 19:17:47,887 | client.py:51 | Creating client with cid: 58
# INFO:flwr:Creating client with cid: 58
# INFO flwr 2025-02-15 19:17:47,889 | client.py:51 | Creating client with cid: 59
# INFO:flwr:Creating client with cid: 59
# INFO flwr 2025-02-15 19:17:47,890 | client.py:51 | Creating client with cid: 60
# INFO:flwr:Creating client with cid: 60
# INFO flwr 2025-02-15 19:17:47,892 | client.py:51 | Creating client with cid: 61
# INFO:flwr:Creating client with cid: 61
# INFO flwr 2025-02-15 19:17:47,895 | client.py:51 | Creating client with cid: 62
# INFO:flwr:Creating client with cid: 62
# INFO flwr 2025-02-15 19:17:47,899 | client.py:51 | Creating client with cid: 63
# INFO:flwr:Creating client with cid: 63
# INFO flwr 2025-02-15 19:17:47,901 | client.py:51 | Creating client with cid: 64
# INFO:flwr:Creating client with cid: 64
# INFO flwr 2025-02-15 19:17:47,903 | client.py:51 | Creating client with cid: 65
# INFO:flwr:Creating client with cid: 65
# INFO flwr 2025-02-15 19:17:47,905 | client.py:51 | Creating client with cid: 66
# INFO:flwr:Creating client with cid: 66
# INFO flwr 2025-02-15 19:17:47,908 | client.py:51 | Creating client with cid: 67
# INFO:flwr:Creating client with cid: 67
# INFO flwr 2025-02-15 19:17:47,911 | client.py:51 | Creating client with cid: 68
# INFO:flwr:Creating client with cid: 68
# INFO flwr 2025-02-15 19:17:47,978 | client.py:51 | Creating client with cid: 69
# INFO:flwr:Creating client with cid: 69
# INFO flwr 2025-02-15 19:17:47,991 | client.py:51 | Creating client with cid: 70
# INFO:flwr:Creating client with cid: 70
# INFO flwr 2025-02-15 19:17:47,994 | client.py:51 | Creating client with cid: 71
# INFO:flwr:Creating client with cid: 71
# INFO flwr 2025-02-15 19:17:47,996 | client.py:51 | Creating client with cid: 72
# INFO:flwr:Creating client with cid: 72
# INFO flwr 2025-02-15 19:17:47,997 | client.py:51 | Creating client with cid: 73
# INFO:flwr:Creating client with cid: 73
# INFO flwr 2025-02-15 19:17:47,999 | client.py:51 | Creating client with cid: 74
# INFO:flwr:Creating client with cid: 74
# INFO flwr 2025-02-15 19:17:48,000 | client.py:51 | Creating client with cid: 75
# INFO:flwr:Creating client with cid: 75
# INFO flwr 2025-02-15 19:17:48,002 | client.py:51 | Creating client with cid: 76
# INFO:flwr:Creating client with cid: 76
# INFO flwr 2025-02-15 19:17:48,003 | client.py:51 | Creating client with cid: 77
# INFO:flwr:Creating client with cid: 77
# INFO flwr 2025-02-15 19:17:48,005 | client.py:51 | Creating client with cid: 78
# INFO:flwr:Creating client with cid: 78
# INFO flwr 2025-02-15 19:17:48,007 | client.py:51 | Creating client with cid: 79
# INFO:flwr:Creating client with cid: 79
# INFO flwr 2025-02-15 19:17:48,008 | client.py:51 | Creating client with cid: 80
# INFO:flwr:Creating client with cid: 80
# INFO flwr 2025-02-15 19:17:48,010 | client.py:51 | Creating client with cid: 81
# INFO:flwr:Creating client with cid: 81
# INFO flwr 2025-02-15 19:17:48,012 | client.py:51 | Creating client with cid: 82
# INFO:flwr:Creating client with cid: 82
# INFO flwr 2025-02-15 19:17:48,013 | client.py:51 | Creating client with cid: 83
# INFO:flwr:Creating client with cid: 83
# INFO flwr 2025-02-15 19:17:48,015 | client.py:51 | Creating client with cid: 84
# INFO:flwr:Creating client with cid: 84
# INFO flwr 2025-02-15 19:17:48,016 | client.py:51 | Creating client with cid: 85
# INFO:flwr:Creating client with cid: 85
# INFO flwr 2025-02-15 19:17:48,017 | client.py:51 | Creating client with cid: 86
# INFO:flwr:Creating client with cid: 86
# INFO flwr 2025-02-15 19:17:48,019 | client.py:51 | Creating client with cid: 87
# INFO:flwr:Creating client with cid: 87
# INFO flwr 2025-02-15 19:17:48,020 | client.py:51 | Creating client with cid: 88
# INFO:flwr:Creating client with cid: 88
# INFO flwr 2025-02-15 19:17:48,023 | client.py:51 | Creating client with cid: 89
# INFO:flwr:Creating client with cid: 89
# INFO flwr 2025-02-15 19:17:48,024 | client.py:51 | Creating client with cid: 90
# INFO:flwr:Creating client with cid: 90
# INFO flwr 2025-02-15 19:17:48,026 | client.py:51 | Creating client with cid: 91
# INFO:flwr:Creating client with cid: 91
# INFO flwr 2025-02-15 19:17:48,027 | client.py:51 | Creating client with cid: 92
# INFO:flwr:Creating client with cid: 92
# INFO flwr 2025-02-15 19:17:48,029 | client.py:51 | Creating client with cid: 93
# INFO:flwr:Creating client with cid: 93
# INFO flwr 2025-02-15 19:17:48,030 | client.py:51 | Creating client with cid: 94
# INFO:flwr:Creating client with cid: 94
# INFO flwr 2025-02-15 19:17:48,033 | client.py:51 | Creating client with cid: 95
# INFO:flwr:Creating client with cid: 95
# INFO flwr 2025-02-15 19:17:48,054 | client.py:51 | Creating client with cid: 96
# INFO:flwr:Creating client with cid: 96
# INFO flwr 2025-02-15 19:17:48,057 | client.py:51 | Creating client with cid: 97
# INFO:flwr:Creating client with cid: 97
# INFO flwr 2025-02-15 19:17:48,060 | client.py:51 | Creating client with cid: 98
# INFO:flwr:Creating client with cid: 98
# INFO flwr 2025-02-15 19:17:48,064 | client.py:51 | Creating client with cid: 99
# INFO:flwr:Creating client with cid: 99
# INFO flwr 2025-02-15 19:17:48,071 | client.py:51 | Creating client with cid: 100
# INFO:flwr:Creating client with cid: 100
# INFO flwr 2025-02-15 19:17:48,079 | client.py:51 | Creating client with cid: 101
# INFO:flwr:Creating client with cid: 101
# INFO flwr 2025-02-15 19:17:48,082 | client.py:51 | Creating client with cid: 102
# INFO:flwr:Creating client with cid: 102
# INFO flwr 2025-02-15 19:17:48,086 | client.py:51 | Creating client with cid: 103
# INFO:flwr:Creating client with cid: 103
# INFO flwr 2025-02-15 19:17:48,087 | client.py:51 | Creating client with cid: 104
# INFO:flwr:Creating client with cid: 104
# INFO flwr 2025-02-15 19:17:48,089 | client.py:51 | Creating client with cid: 105
# INFO:flwr:Creating client with cid: 105
# INFO flwr 2025-02-15 19:17:48,090 | client.py:51 | Creating client with cid: 106
# INFO:flwr:Creating client with cid: 106
# INFO flwr 2025-02-15 19:17:48,091 | client.py:51 | Creating client with cid: 107
# INFO:flwr:Creating client with cid: 107
# INFO flwr 2025-02-15 19:17:48,092 | client.py:51 | Creating client with cid: 108
# INFO:flwr:Creating client with cid: 108
# INFO flwr 2025-02-15 19:17:48,093 | client.py:51 | Creating client with cid: 109
# INFO:flwr:Creating client with cid: 109
# INFO flwr 2025-02-15 19:17:48,094 | client.py:51 | Creating client with cid: 110
# INFO:flwr:Creating client with cid: 110
# INFO flwr 2025-02-15 19:17:48,095 | client.py:51 | Creating client with cid: 111
# INFO:flwr:Creating client with cid: 111
# INFO flwr 2025-02-15 19:17:48,096 | client.py:51 | Creating client with cid: 112
# INFO:flwr:Creating client with cid: 112
# INFO flwr 2025-02-15 19:17:48,097 | client.py:51 | Creating client with cid: 113
# INFO:flwr:Creating client with cid: 113
# INFO flwr 2025-02-15 19:17:48,098 | client.py:51 | Creating client with cid: 114
# INFO:flwr:Creating client with cid: 114
# INFO flwr 2025-02-15 19:17:48,100 | client.py:51 | Creating client with cid: 115
# INFO:flwr:Creating client with cid: 115
# INFO flwr 2025-02-15 19:17:48,102 | client.py:51 | Creating client with cid: 116
# INFO:flwr:Creating client with cid: 116
# INFO flwr 2025-02-15 19:17:48,103 | client.py:51 | Creating client with cid: 117
# INFO:flwr:Creating client with cid: 117
# INFO flwr 2025-02-15 19:17:48,104 | client.py:51 | Creating client with cid: 118
# INFO:flwr:Creating client with cid: 118
# INFO flwr 2025-02-15 19:17:48,105 | client.py:51 | Creating client with cid: 119
# INFO:flwr:Creating client with cid: 119
# INFO flwr 2025-02-15 19:17:48,106 | client.py:51 | Creating client with cid: 120
# INFO:flwr:Creating client with cid: 120
# INFO flwr 2025-02-15 19:17:48,107 | client.py:51 | Creating client with cid: 121
# INFO:flwr:Creating client with cid: 121
# INFO flwr 2025-02-15 19:17:48,108 | client.py:51 | Creating client with cid: 122
# INFO:flwr:Creating client with cid: 122
# INFO flwr 2025-02-15 19:17:48,110 | client.py:51 | Creating client with cid: 123
# INFO:flwr:Creating client with cid: 123
# INFO flwr 2025-02-15 19:17:48,117 | client.py:51 | Creating client with cid: 124
# INFO:flwr:Creating client with cid: 124
# INFO flwr 2025-02-15 19:17:48,130 | client.py:51 | Creating client with cid: 125
# INFO:flwr:Creating client with cid: 125
# INFO flwr 2025-02-15 19:17:48,137 | client.py:51 | Creating client with cid: 126
# INFO:flwr:Creating client with cid: 126
# INFO flwr 2025-02-15 19:17:48,139 | client.py:51 | Creating client with cid: 127
# INFO:flwr:Creating client with cid: 127
# INFO flwr 2025-02-15 19:17:48,141 | client.py:51 | Creating client with cid: 128
# INFO:flwr:Creating client with cid: 128
# INFO flwr 2025-02-15 19:17:48,143 | client.py:51 | Creating client with cid: 129
# INFO:flwr:Creating client with cid: 129
# INFO flwr 2025-02-15 19:17:48,145 | client.py:51 | Creating client with cid: 130
# INFO:flwr:Creating client with cid: 130
# INFO flwr 2025-02-15 19:17:48,148 | client.py:51 | Creating client with cid: 131
# INFO:flwr:Creating client with cid: 131
# INFO flwr 2025-02-15 19:17:48,152 | client.py:51 | Creating client with cid: 132
# INFO:flwr:Creating client with cid: 132
# INFO flwr 2025-02-15 19:17:48,155 | client.py:51 | Creating client with cid: 133
# INFO:flwr:Creating client with cid: 133
# INFO flwr 2025-02-15 19:17:48,158 | client.py:51 | Creating client with cid: 134
# INFO:flwr:Creating client with cid: 134
# INFO flwr 2025-02-15 19:17:48,160 | client.py:51 | Creating client with cid: 135
# INFO:flwr:Creating client with cid: 135
# INFO flwr 2025-02-15 19:17:48,167 | client.py:51 | Creating client with cid: 136
# INFO:flwr:Creating client with cid: 136
# INFO flwr 2025-02-15 19:17:48,173 | client.py:51 | Creating client with cid: 137
# INFO:flwr:Creating client with cid: 137
# INFO flwr 2025-02-15 19:17:48,175 | client.py:51 | Creating client with cid: 138
# INFO:flwr:Creating client with cid: 138
# INFO flwr 2025-02-15 19:17:48,178 | client.py:51 | Creating client with cid: 139
# INFO:flwr:Creating client with cid: 139
# INFO flwr 2025-02-15 19:17:48,180 | client.py:51 | Creating client with cid: 140
# INFO:flwr:Creating client with cid: 140
# INFO flwr 2025-02-15 19:17:48,184 | client.py:51 | Creating client with cid: 141
# INFO:flwr:Creating client with cid: 141
# INFO flwr 2025-02-15 19:17:48,186 | client.py:51 | Creating client with cid: 142
# INFO:flwr:Creating client with cid: 142
# INFO flwr 2025-02-15 19:17:48,187 | client.py:51 | Creating client with cid: 143
# INFO:flwr:Creating client with cid: 143
# INFO flwr 2025-02-15 19:17:48,189 | client.py:51 | Creating client with cid: 144
# INFO:flwr:Creating client with cid: 144
# INFO flwr 2025-02-15 19:17:48,191 | client.py:51 | Creating client with cid: 145
# INFO:flwr:Creating client with cid: 145
# INFO flwr 2025-02-15 19:17:48,194 | client.py:51 | Creating client with cid: 146
# INFO:flwr:Creating client with cid: 146
# INFO flwr 2025-02-15 19:17:48,201 | client.py:51 | Creating client with cid: 147
# INFO:flwr:Creating client with cid: 147
# INFO flwr 2025-02-15 19:17:48,206 | client.py:51 | Creating client with cid: 148
# INFO:flwr:Creating client with cid: 148
# INFO flwr 2025-02-15 19:17:48,208 | client.py:51 | Creating client with cid: 149
# INFO:flwr:Creating client with cid: 149
# INFO flwr 2025-02-15 19:17:48,217 | client.py:51 | Creating client with cid: 150
# INFO:flwr:Creating client with cid: 150
# INFO flwr 2025-02-15 19:17:48,224 | client.py:51 | Creating client with cid: 151
# INFO:flwr:Creating client with cid: 151
# INFO flwr 2025-02-15 19:17:48,231 | client.py:51 | Creating client with cid: 152
# INFO:flwr:Creating client with cid: 152
# INFO flwr 2025-02-15 19:17:48,239 | client.py:51 | Creating client with cid: 153
# INFO:flwr:Creating client with cid: 153
# INFO flwr 2025-02-15 19:17:48,244 | client.py:51 | Creating client with cid: 154
# INFO:flwr:Creating client with cid: 154
# INFO flwr 2025-02-15 19:17:48,251 | client.py:51 | Creating client with cid: 155
# INFO:flwr:Creating client with cid: 155
# INFO flwr 2025-02-15 19:17:48,255 | client.py:51 | Creating client with cid: 156
# INFO:flwr:Creating client with cid: 156
# INFO flwr 2025-02-15 19:17:48,258 | client.py:51 | Creating client with cid: 157
# INFO:flwr:Creating client with cid: 157
# INFO flwr 2025-02-15 19:17:48,262 | client.py:51 | Creating client with cid: 158
# INFO:flwr:Creating client with cid: 158
# INFO flwr 2025-02-15 19:17:48,264 | client.py:51 | Creating client with cid: 159
# INFO:flwr:Creating client with cid: 159
# INFO flwr 2025-02-15 19:17:48,335 | client.py:51 | Creating client with cid: 160
# INFO:flwr:Creating client with cid: 160
# INFO flwr 2025-02-15 19:17:48,338 | client.py:51 | Creating client with cid: 161
# INFO:flwr:Creating client with cid: 161
# INFO flwr 2025-02-15 19:17:48,341 | client.py:51 | Creating client with cid: 162
# INFO:flwr:Creating client with cid: 162
# INFO flwr 2025-02-15 19:17:48,343 | client.py:51 | Creating client with cid: 163
# INFO:flwr:Creating client with cid: 163
# INFO flwr 2025-02-15 19:17:48,359 | client.py:51 | Creating client with cid: 164
# INFO:flwr:Creating client with cid: 164
# INFO:flwr:Creating client with cid: 189
# INFO flwr 2025-02-15 19:17:48,481 | client.py:51 | Creating client with cid: 190
# INFO:flwr:Creating client with cid: 190
# INFO flwr 2025-02-15 19:17:48,483 | client.py:51 | Creating client with cid: 191
# INFO:flwr:Creating client with cid: 191
# INFO flwr 2025-02-15 19:17:48,486 | client.py:51 | Creating client with cid: 192
# INFO:flwr:Creating client with cid: 192
# INFO flwr 2025-02-15 19:17:48,489 | client.py:51 | Creating client with cid: 193
# INFO:flwr:Creating client with cid: 193
# INFO flwr 2025-02-15 19:17:48,490 | client.py:51 | Creating client with cid: 194
# INFO:flwr:Creating client with cid: 194
# INFO flwr 2025-02-15 19:17:48,492 | client.py:51 | Creating client with cid: 195
# INFO:flwr:Creating client with cid: 195
# INFO flwr 2025-02-15 19:17:48,493 | client.py:51 | Creating client with cid: 196
# INFO:flwr:Creating client with cid: 196
# INFO flwr 2025-02-15 19:17:48,495 | client.py:51 | Creating client with cid: 197
# INFO:flwr:Creating client with cid: 197
# INFO flwr 2025-02-15 19:17:48,497 | client.py:51 | Creating client with cid: 198
# INFO:flwr:Creating client with cid: 198
# INFO flwr 2025-02-15 19:17:48,499 | client.py:51 | Creating client with cid: 199
# INFO:flwr:Creating client with cid: 199
# INFO flwr 2025-02-15 19:17:48,504 | client.py:51 | Creating client with cid: 200
# INFO:flwr:Creating client with cid: 200
# INFO flwr 2025-02-15 19:17:48,507 | client.py:51 | Creating client with cid: 201
# INFO:flwr:Creating client with cid: 201
# INFO flwr 2025-02-15 19:17:48,510 | client.py:51 | Creating client with cid: 202
# INFO:flwr:Creating client with cid: 202
# INFO flwr 2025-02-15 19:17:48,512 | client.py:51 | Creating client with cid: 203
# INFO:flwr:Creating client with cid: 203
# INFO flwr 2025-02-15 19:17:48,514 | client.py:51 | Creating client with cid: 204
# INFO:flwr:Creating client with cid: 204
# INFO flwr 2025-02-15 19:17:48,516 | client.py:51 | Creating client with cid: 205
# INFO:flwr:Creating client with cid: 205
# INFO flwr 2025-02-15 19:17:48,518 | client.py:51 | Creating client with cid: 206
# INFO:flwr:Creating client with cid: 206
# INFO flwr 2025-02-15 19:17:48,520 | client.py:51 | Creating client with cid: 207
# INFO:flwr:Creating client with cid: 207
# INFO flwr 2025-02-15 19:17:48,522 | client.py:51 | Creating client with cid: 208
# INFO:flwr:Creating client with cid: 208
# INFO flwr 2025-02-15 19:17:48,524 | client.py:51 | Creating client with cid: 209
# INFO:flwr:Creating client with cid: 209
# INFO flwr 2025-02-15 19:17:48,527 | client.py:51 | Creating client with cid: 210
# INFO:flwr:Creating client with cid: 210
# INFO flwr 2025-02-15 19:17:48,530 | client.py:51 | Creating client with cid: 211
# INFO:flwr:Creating client with cid: 211
# INFO flwr 2025-02-15 19:17:48,531 | client.py:51 | Creating client with cid: 212
# INFO:flwr:Creating client with cid: 212
# INFO flwr 2025-02-15 19:17:48,534 | client.py:51 | Creating client with cid: 213
# INFO:flwr:Creating client with cid: 213
# INFO flwr 2025-02-15 19:17:48,535 | client.py:51 | Creating client with cid: 214
# INFO:flwr:Creating client with cid: 214
# INFO flwr 2025-02-15 19:17:48,539 | client.py:51 | Creating client with cid: 215
# INFO:flwr:Creating client with cid: 215
# INFO flwr 2025-02-15 19:17:48,542 | client.py:51 | Creating client with cid: 216
# INFO:flwr:Creating client with cid: 216
# INFO flwr 2025-02-15 19:17:48,544 | client.py:51 | Creating client with cid: 217
# INFO:flwr:Creating client with cid: 217
# INFO flwr 2025-02-15 19:17:48,547 | client.py:51 | Creating client with cid: 218
# INFO:flwr:Creating client with cid: 218
# INFO flwr 2025-02-15 19:17:48,549 | client.py:51 | Creating client with cid: 219
# INFO:flwr:Creating client with cid: 219
# INFO flwr 2025-02-15 19:17:48,554 | client.py:51 | Creating client with cid: 220
# INFO:flwr:Creating client with cid: 220
# INFO flwr 2025-02-15 19:17:48,557 | client.py:51 | Creating client with cid: 221
# INFO:flwr:Creating client with cid: 221
# INFO flwr 2025-02-15 19:17:48,561 | client.py:51 | Creating client with cid: 222
# INFO:flwr:Creating client with cid: 222
# INFO flwr 2025-02-15 19:17:48,564 | client.py:51 | Creating client with cid: 223
# INFO:flwr:Creating client with cid: 223
# INFO flwr 2025-02-15 19:17:48,566 | client.py:51 | Creating client with cid: 224
# INFO:flwr:Creating client with cid: 224
# INFO flwr 2025-02-15 19:17:48,569 | client.py:51 | Creating client with cid: 225
# INFO:flwr:Creating client with cid: 225
# INFO flwr 2025-02-15 19:17:48,572 | client.py:51 | Creating client with cid: 226
# INFO:flwr:Creating client with cid: 226
# INFO flwr 2025-02-15 19:17:48,575 | client.py:51 | Creating client with cid: 227
# INFO:flwr:Creating client with cid: 227
# INFO flwr 2025-02-15 19:17:48,641 | client.py:51 | Creating client with cid: 228
# INFO:flwr:Creating client with cid: 228
# INFO flwr 2025-02-15 19:17:48,644 | client.py:51 | Creating client with cid: 229
# INFO:flwr:Creating client with cid: 229
# INFO flwr 2025-02-15 19:17:48,646 | client.py:51 | Creating client with cid: 230
# INFO:flwr:Creating client with cid: 230
# INFO flwr 2025-02-15 19:17:48,647 | client.py:51 | Creating client with cid: 231
# INFO:flwr:Creating client with cid: 231
# INFO flwr 2025-02-15 19:17:48,649 | client.py:51 | Creating client with cid: 232
# INFO:flwr:Creating client with cid: 232
# INFO flwr 2025-02-15 19:17:48,666 | client.py:51 | Creating client with cid: 233
# INFO:flwr:Creating client with cid: 233
# INFO flwr 2025-02-15 19:17:48,671 | client.py:51 | Creating client with cid: 234
# INFO:flwr:Creating client with cid: 234
# INFO flwr 2025-02-15 19:17:48,675 | client.py:51 | Creating client with cid: 235
# INFO:flwr:Creating client with cid: 235
# INFO flwr 2025-02-15 19:17:48,677 | client.py:51 | Creating client with cid: 236
# INFO:flwr:Creating client with cid: 236
# INFO flwr 2025-02-15 19:17:48,678 | client.py:51 | Creating client with cid: 237
# INFO:flwr:Creating client with cid: 237
# INFO flwr 2025-02-15 19:17:48,680 | client.py:51 | Creating client with cid: 238
# INFO:flwr:Creating client with cid: 238
# INFO:flwr:Creating client with cid: 288
# INFO flwr 2025-02-15 19:17:48,792 | client.py:51 | Creating client with cid: 289
# INFO:flwr:Creating client with cid: 289
# INFO flwr 2025-02-15 19:17:48,794 | client.py:51 | Creating client with cid: 290
# INFO:flwr:Creating client with cid: 290
# INFO flwr 2025-02-15 19:17:48,795 | client.py:51 | Creating client with cid: 291
# INFO:flwr:Creating client with cid: 291
# INFO flwr 2025-02-15 19:17:48,797 | client.py:51 | Creating client with cid: 292
# INFO:flwr:Creating client with cid: 292
# INFO flwr 2025-02-15 19:17:48,799 | client.py:51 | Creating client with cid: 293
# INFO:flwr:Creating client with cid: 293
# INFO flwr 2025-02-15 19:17:48,802 | client.py:51 | Creating client with cid: 294
# INFO:flwr:Creating client with cid: 294
# INFO flwr 2025-02-15 19:17:48,805 | client.py:51 | Creating client with cid: 295
# INFO:flwr:Creating client with cid: 295
# INFO flwr 2025-02-15 19:17:48,806 | client.py:51 | Creating client with cid: 296
# INFO:flwr:Creating client with cid: 296
# INFO flwr 2025-02-15 19:17:48,808 | client.py:51 | Creating client with cid: 297
# INFO:flwr:Creating client with cid: 297
# INFO flwr 2025-02-15 19:17:48,809 | client.py:51 | Creating client with cid: 298
# INFO:flwr:Creating client with cid: 298
# INFO flwr 2025-02-15 19:17:48,811 | client.py:51 | Creating client with cid: 299
# INFO:flwr:Creating client with cid: 299
# INFO flwr 2025-02-15 19:17:48,812 | client.py:51 | Creating client with cid: 300
# INFO:flwr:Creating client with cid: 300
# INFO flwr 2025-02-15 19:17:48,814 | client.py:51 | Creating client with cid: 301
# INFO:flwr:Creating client with cid: 301
# INFO flwr 2025-02-15 19:17:48,815 | client.py:51 | Creating client with cid: 302
# INFO:flwr:Creating client with cid: 302
# INFO flwr 2025-02-15 19:17:48,817 | client.py:51 | Creating client with cid: 303
# INFO:flwr:Creating client with cid: 303
# INFO flwr 2025-02-15 19:17:48,819 | client.py:51 | Creating client with cid: 304
# INFO:flwr:Creating client with cid: 304
# INFO flwr 2025-02-15 19:17:48,832 | client.py:51 | Creating client with cid: 305
# INFO:flwr:Creating client with cid: 305
# INFO flwr 2025-02-15 19:17:48,892 | client.py:51 | Creating client with cid: 306
# INFO:flwr:Creating client with cid: 306
# INFO flwr 2025-02-15 19:17:48,895 | client.py:51 | Creating client with cid: 307
# INFO:flwr:Creating client with cid: 307
# INFO flwr 2025-02-15 19:17:48,897 | client.py:51 | Creating client with cid: 308
# INFO:flwr:Creating client with cid: 308
# INFO flwr 2025-02-15 19:17:48,899 | client.py:51 | Creating client with cid: 309
# INFO:flwr:Creating client with cid: 309
# INFO flwr 2025-02-15 19:17:48,900 | client.py:51 | Creating client with cid: 310
# INFO:flwr:Creating client with cid: 310
# INFO flwr 2025-02-15 19:17:48,902 | client.py:51 | Creating client with cid: 311
# INFO:flwr:Creating client with cid: 311
# INFO flwr 2025-02-15 19:17:48,903 | client.py:51 | Creating client with cid: 312
# INFO:flwr:Creating client with cid: 312
# INFO:flwr:Creating client with cid: 3113
# INFO flwr 2025-02-15 19:17:58,536 | client.py:51 | Creating client with cid: 3114
# INFO:flwr:Creating client with cid: 3114
# INFO flwr 2025-02-15 19:17:58,540 | client.py:51 | Creating client with cid: 3115
# INFO:flwr:Creating client with cid: 3115
# INFO flwr 2025-02-15 19:17:58,544 | client.py:51 | Creating client with cid: 3116
# INFO:flwr:Creating client with cid: 3116
# INFO flwr 2025-02-15 19:17:58,545 | client.py:51 | Creating client with cid: 3117
# INFO:flwr:Creating client with cid: 3117
# INFO flwr 2025-02-15 19:17:58,547 | client.py:51 | Creating client with cid: 3118
# INFO:flwr:Creating client with cid: 3118
# INFO flwr 2025-02-15 19:17:58,552 | client.py:51 | Creating client with cid: 3119
# INFO:flwr:Creating client with cid: 3119
# INFO flwr 2025-02-15 19:17:58,554 | client.py:51 | Creating client with cid: 3120
# INFO:flwr:Creating client with cid: 3120
# INFO flwr 2025-02-15 19:17:58,556 | client.py:51 | Creating client with cid: 3121
# INFO:flwr:Creating client with cid: 3121
# INFO flwr 2025-02-15 19:17:58,557 | client.py:51 | Creating client with cid: 3122
# INFO:flwr:Creating client with cid: 3122
# INFO flwr 2025-02-15 19:17:58,558 | client.py:51 | Creating client with cid: 3123
# INFO:flwr:Creating client with cid: 3123
# INFO flwr 2025-02-15 19:17:58,560 | client.py:51 | Creating client with cid: 3124
# INFO:flwr:Creating client with cid: 3124
# INFO flwr 2025-02-15 19:17:58,561 | client.py:51 | Creating client with cid: 3125
# INFO:flwr:Creating client with cid: 3125
# INFO flwr 2025-02-15 19:17:58,562 | client.py:51 | Creating client with cid: 3126
# INFO:flwr:Creating client with cid: 3126
# INFO flwr 2025-02-15 19:17:58,563 | client.py:51 | Creating client with cid: 3127
# INFO:flwr:Creating client with cid: 3127
# INFO flwr 2025-02-15 19:17:58,564 | client.py:51 | Creating client with cid: 3128
# INFO:flwr:Creating client with cid: 3128
# INFO flwr 2025-02-15 19:17:58,566 | client.py:51 | Creating client with cid: 3129
# INFO:flwr:Creating client with cid: 3129
# INFO flwr 2025-02-15 19:17:58,566 | client.py:51 | Creating client with cid: 3130
# INFO:flwr:Creating client with cid: 3130
# INFO flwr 2025-02-15 19:17:58,568 | client.py:51 | Creating client with cid: 3131
# INFO:flwr:Creating client with cid: 3131
# INFO flwr 2025-02-15 19:17:58,570 | client.py:51 | Creating client with cid: 3132
# INFO:flwr:Creating client with cid: 3132
# INFO flwr 2025-02-15 19:17:58,571 | client.py:51 | Creating client with cid: 3133
# INFO:flwr:Creating client with cid: 3133
# INFO flwr 2025-02-15 19:17:58,572 | client.py:51 | Creating client with cid: 3134
# INFO:flwr:Creating client with cid: 3134
# INFO flwr 2025-02-15 19:17:58,573 | client.py:51 | Creating client with cid: 3135
# INFO:flwr:Creating client with cid: 3135
# INFO flwr 2025-02-15 19:17:58,575 | client.py:51 | Creating client with cid: 3136
# INFO:flwr:Creating client with cid: 3136
# INFO flwr 2025-02-15 19:17:58,577 | client.py:51 | Creating client with cid: 3137
# INFO flwr 2025-02-15 19:17:58,997 | client.py:51 | Creating client with cid: 3210
# INFO:flwr:Creating client with cid: 3210
# INFO flwr 2025-02-15 19:17:58,998 | client.py:51 | Creating client with cid: 3211
# INFO:flwr:Creating client with cid: 3211
# INFO flwr 2025-02-15 19:17:59,000 | client.py:51 | Creating client with cid: 3212
# INFO:flwr:Creating client with cid: 3212
# INFO flwr 2025-02-15 19:17:59,001 | client.py:51 | Creating client with cid: 3213
# INFO:flwr:Creating client with cid: 3213
# INFO flwr 2025-02-15 19:17:59,002 | client.py:51 | Creating client with cid: 3214
# INFO:flwr:Creating client with cid: 3214
# INFO flwr 2025-02-15 19:17:59,003 | client.py:51 | Creating client with cid: 3215
# INFO:flwr:Creating client with cid: 3215
# INFO flwr 2025-02-15 19:17:59,005 | client.py:51 | Creating client with cid: 3216
# INFO:flwr:Creating client with cid: 3216
# INFO flwr 2025-02-15 19:17:59,006 | client.py:51 | Creating client with cid: 3217
# INFO:flwr:Creating client with cid: 3217
# INFO flwr 2025-02-15 19:17:59,007 | client.py:51 | Creating client with cid: 3218
# INFO:flwr:Creating client with cid: 3218
# INFO flwr 2025-02-15 19:17:59,008 | client.py:51 | Creating client with cid: 3219
# INFO:flwr:Creating client with cid: 3219
# INFO flwr 2025-02-15 19:17:59,009 | client.py:51 | Creating client with cid: 3220
# INFO:flwr:Creating client with cid: 3220
# INFO flwr 2025-02-15 19:17:59,010 | client.py:51 | Creating client with cid: 3221
# INFO:flwr:Creating client with cid: 3221
# INFO flwr 2025-02-15 19:17:59,011 | client.py:51 | Creating client with cid: 3222
# INFO:flwr:Creating client with cid: 3222
# INFO flwr 2025-02-15 19:17:59,013 | client.py:51 | Creating client with cid: 3223
# INFO:flwr:Creating client with cid: 3223
# INFO flwr 2025-02-15 19:17:59,014 | client.py:51 | Creating client with cid: 3224
# INFO:flwr:Creating client with cid: 3224
# INFO flwr 2025-02-15 19:17:59,015 | client.py:51 | Creating client with cid: 3225
# INFO:flwr:Creating client with cid: 3225
# INFO flwr 2025-02-15 19:17:59,016 | client.py:51 | Creating client with cid: 3226
# INFO:flwr:Creating client with cid: 3226
# INFO flwr 2025-02-15 19:17:59,018 | client.py:51 | Creating client with cid: 3227
# INFO:flwr:Creating client with cid: 3227
# INFO flwr 2025-02-15 19:17:59,019 | client.py:51 | Creating client with cid: 3228
# INFO:flwr:Creating client with cid: 3228
# INFO flwr 2025-02-15 19:17:59,026 | 4184221825.py:18 | Num total clients: 3224
# INFO:flwr:Num total clients: 3224

# %% [markdown]
# This DP client encapsulates all the meaningful work required for client-level differential privacy to be carried out. However, the strategy controls the L2 norm bound and the noise multiplier used to determine the Gaussian noise standard deviation based on this bound.
#
# We shall now implement a strategy capable of orchestrating DP clients in a manner which best preserves privacy within a given budget.

# %%
from collections.abc import Callable

from logging import INFO

import numpy as np

from flwr.common import (
    FitIns,
    FitRes,
    NDArrays,
    Scalar,
)
from flwr.common.logger import log
from math import sqrt


# Based on the original implementation by Vasundhara Agarwal
class DPFedAvgFixed(FedAvgM):
    """Configurable FedAvg strategy implementation."""

    # pylint: disable=too-many-arguments,too-many-instance-attributes,line-too-long
    def __init__(
        self,
        *,
        fraction_fit: float = 1.0,
        fraction_evaluate: float = 1.0,
        min_fit_clients: int = 2,
        min_evaluate_clients: int = 2,
        min_available_clients: int = 2,
        evaluate_fn: (
            Callable[
                [int, NDArrays, dict[str, Scalar]],
                tuple[float, dict[str, Scalar]] | None,
            ]
            | None
        ) = None,
        on_fit_config_fn: Callable[[int], dict[str, Scalar]] | None = None,
        on_evaluate_config_fn: Callable[[int], dict[str, Scalar]] | None = None,
        accept_failures: bool = False,
        initial_parameters: Parameters | None = None,
        fit_metrics_aggregation_fn: MetricsAggregationFn | None = None,
        evaluate_metrics_aggregation_fn: MetricsAggregationFn | None = None,
        server_learning_rate: float = 1.0,
        server_momentum: float = 0.0,
        num_clients_per_round: int,
        clip_norm: float,
        noise_multiplier: float = 1,
        server_side_noising: bool = True,
    ) -> None:
        super().__init__(
            fraction_fit=fraction_fit,
            fraction_evaluate=fraction_evaluate,
            min_fit_clients=min_fit_clients,
            min_evaluate_clients=min_evaluate_clients,
            min_available_clients=min_available_clients,
            evaluate_fn=evaluate_fn,
            on_fit_config_fn=on_fit_config_fn,
            on_evaluate_config_fn=on_evaluate_config_fn,
            accept_failures=accept_failures,
            initial_parameters=initial_parameters,
            fit_metrics_aggregation_fn=fit_metrics_aggregation_fn,
            evaluate_metrics_aggregation_fn=evaluate_metrics_aggregation_fn,
            server_learning_rate=server_learning_rate,
            server_momentum=server_momentum,
        )
        # Doing fixed-size subsampling as in https://arxiv.org/abs/1905.03871
        self.num_clients_per_round = num_clients_per_round
        self.noise_multiplier = noise_multiplier
        self.server_side_noising = server_side_noising
        self.clip_norm = clip_norm

    # Automatically calculate the standard deviation of the noise
    # Based on the clip norm and number of clients per round
    # The noise multiplier controls the number of standard deviations from the mean
    def _calc_client_noise_stddev(self) -> float:
        stddev = (
            self.noise_multiplier * self.clip_norm / (sqrt(self.num_clients_per_round))
        )
        return float(stddev)

    def configure_fit(
        self,
        server_round: int,
        parameters: Parameters,
        client_manager: CustomClientManager,
    ) -> list[tuple[ClientProxy, FitIns]]:
        """Configure the next round of training."""
        config = {}
        if self.on_fit_config_fn is not None:
            # Custom fit config function provided
            config = self.on_fit_config_fn(server_round)

        # Add DP info to config for local update clipping
        config["dpfedavg_clip_norm"] = self.clip_norm
        if not self.server_side_noising:
            config["dpfedavg_noise_stddev"] = self._calc_client_noise_stddev()
        fit_ins = FitIns(parameters, config)

        # Sample clients
        sample_size, min_num_clients = self.num_fit_clients(
            client_manager.num_available()
        )
        clients = client_manager.sample(
            num_clients=sample_size,
            min_num_clients=min_num_clients,
            server_round=server_round,
        )

        # Return client/config pairs
        return [(client, fit_ins) for client in clients]

    def aggregate_fit(
        self,
        server_round: int,
        results: list[tuple[ClientProxy, FitRes]],
        failures: list[tuple[ClientProxy, FitRes] | BaseException],
    ) -> tuple[Parameters | None, dict[str, Scalar]]:
        """Aggregate the results of the training round."""
        if failures and not self.accept_failures:
            return None, {}
        # Forcing unweighted aggregation, as in https://arxiv.org/abs/1905.03871
        # By setting the number of examples associated to each model
        # To 1
        for _, fit_res in results:
            fit_res.num_examples = 1
            if self.server_side_noising:
                fit_res.parameters = ndarrays_to_parameters(
                    add_gaussian_noise(
                        parameters_to_ndarrays(fit_res.parameters),
                        self._calc_client_noise_stddev(),
                    )
                )

        return super().aggregate_fit(server_round, results, failures)

# %% [markdown]
# Do observe how the unweighted aggregation combines with the norm clipping to limit the disproportionate impact of high-data clients upon the federated model to treat all clients close-to-equally regarding privacy leaks.
#
# We can now create a function to run such experiments, allowing you to easily maintain and change default parameters as needed.

# %%
dp_client_generator = get_dp_client_generator(
    network_generator_cnn,
    data_dir,
    federated_partition,
    lambda x: client_samples_dataframe.cid[x],
)
default_parameters: dict = {
    "train_config": get_default_train_config(),
    "test_config": get_default_test_config(),
    "num_total_clients": num_total_clients,
    "num_clients_per_round": 4,
    "num_evaluate_clients": 0,
    "num_evaluate": 0,
    "accept_failures": False,
    "min_fit_clients": 2,
    "min_available_clients": 2,
    "initial_parameters": ndarrays_to_parameters(seed_model_cnn_params),
    "client_generator": dp_client_generator,
    "seed": Seeds.DEFAULT,
    "num_rounds": 30,
    "strategy": DPFedAvgFixed,
    "fed_eval": True,
    "server_side_noising": True,
}


def run_dp_fixed_fl(
    clip_norm: float = 4.0,
    noise_multiplier: float = 0.05,
    default_parameters: dict = default_parameters,
    **kwargs: dict[str, Any],
) -> Any:
    """Execute a DP-FedAvg simulation with fixed clip norm and noise multiplier."""
    parameters: dict = {**default_parameters, **kwargs}

    def on_fit_config_fn(cid: int) -> dict[str, Scalar]:
        return parameters["train_config"]

    def on_evaluate_config_fn(cid: int) -> dict[str, Scalar]:
        return parameters["test_config"]

    fraction_fit: float = (
        float(parameters["num_clients_per_round"]) / parameters["num_total_clients"]
    )
    fraction_evaluate: float = (
        float(parameters["num_evaluate_clients"]) / parameters["num_total_clients"]
    )

    strategy = parameters["strategy"](
        num_clients_per_round=parameters["num_clients_per_round"],
        fraction_fit=fraction_fit,
        fraction_evaluate=fraction_evaluate,
        min_fit_clients=parameters["min_fit_clients"],
        min_available_clients=parameters["min_available_clients"],
        on_fit_config_fn=on_fit_config_fn,
        on_evaluate_config_fn=on_evaluate_config_fn,
        initial_parameters=parameters["initial_parameters"],
        accept_failures=parameters["accept_failures"],
        evaluate_fn=(
            federated_evaluation_function if parameters["fed_eval"] is True else None
        ),
        fit_metrics_aggregation_fn=aggregate_weighted_average,
        evaluate_metrics_aggregation_fn=aggregate_weighted_average,
        clip_norm=clip_norm,
        noise_multiplier=noise_multiplier,
        server_side_noising=parameters["server_side_noising"],
    )
    client_manager = CustomClientManager(criterion=None, seed=parameters["seed"])
    server = Server(
        client_manager=client_manager,
        strategy=strategy,
    )
    return start_seeded_simulation(
        client_fn=lambda cid: parameters["client_generator"](cid).to_client(),
        num_clients=parameters["num_total_clients"],
        server=server,
        config=ServerConfig(num_rounds=parameters["num_rounds"]),
        strategy=strategy,
        seed=parameters["seed"],
        name=f"fixed_clip_norm_{clip_norm}_noise_{noise_multiplier}",
    )

# %%
parameters_for_every_round, hist_clip_bound_4_noise_0_05 = run_dp_fixed_fl(4)
# Out:
# WARNING flwr 2025-02-15 19:18:11,443 | app.py:213 | Both server and strategy were provided, ignoring strategy
# WARNING:flwr:Both server and strategy were provided, ignoring strategy
# INFO flwr 2025-02-15 19:18:11,453 | app.py:149 | Starting Flower simulation, config: ServerConfig(num_rounds=30, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=30, round_timeout=None)
# INFO flwr 2025-02-15 19:18:11,485 | server_returns_parameters.py:81 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2025-02-15 19:18:11,490 | server_returns_parameters.py:273 | Using initial parameters provided by strategy
# INFO:flwr:Using initial parameters provided by strategy
# INFO flwr 
| client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:18:26,291 | client_manager.py:68 | Sampled the following clients: ['2251', '159', '3062', '2996']
# INFO:flwr:Sampled the following clients: ['2251', '159', '3062', '2996']
# DEBUG flwr 2025-02-15 19:18:26,291 | server_returns_parameters.py:223 | fit_round 7: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 7: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:18:26,292 | client.py:51 | Creating client with cid: 2251
# INFO:flwr:Creating client with cid: 2251
# INFO flwr 2025-02-15 19:18:26,292 | client.py:51 | Creating client with cid: 159
# INFO:flwr:Creating client with cid: 159
# INFO flwr 2025-02-15 19:18:26,293 | client.py:51 | Creating client with cid: 3062
# INFO:flwr:Creating client with cid: 3062
# INFO flwr 2025-02-15 19:18:26,293 | client.py:51 | Creating client with cid: 2996
# INFO:flwr:Creating client with cid: 2996
# DEBUG flwr 2025-02-15 19:18:27,805 | server_returns_parameters.py:237 | fit_round 7 received 4 results and 0 failures
# DEBUG:flwr:fit_round 7 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:18:27,810 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 206.19it/s]
# INFO flwr 2025-02-15 19:18:28,046 | server_returns_parameters.py:120 | fit progress: (7, 118.46738469600677, {'accuracy': 0.38466666666666666}, 15.81749312498141)
# INFO:flwr:fit progress: (7, 118.46738469600677, {'accuracy': 0.38466666666666666}, 15.81749312498141)
# INFO flwr 2025-02-15 19:18:28,046 | server_returns_parameters.py:171 | evaluate_round 7: no clients selected, cancel
# INFO:flwr:evaluate_round 7: no clients selected, cancel
# INFO flwr 2025-02-15 19:18:28,053 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:18:28,053 | client_manager.py:68 | Sampled the following clients: ['2411', '528', '943', '725']
# INFO:flwr:Sampled the following clients: ['2411', '528', '943', '725']
# DEBUG flwr 2025-02-15 19:18:28,054 | server_returns_parameters.py:223 | fit_round 8: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 8: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:18:28,055 | client.py:51 | Creating client with cid: 2411
# INFO:flwr:Creating client with cid: 2411
# INFO flwr 2025-02-15 19:18:28,056 | client.py:51 | Creating client with cid: 528
# INFO:flwr:Creating client with cid: 528
# INFO flwr 2025-02-15 19:18:28,056 | client.py:51 | Creating client with cid: 943
# INFO:flwr:Creating client with cid: 943
# INFO flwr 2025-02-15 19:18:28,056 | client.py:51 | Creating client with cid: 725
# INFO:flwr:Creating client with cid: 725
# DEBUG flwr 2025-02-15 19:18:30,126 | server_returns_parameters.py:237 | fit_round 8 received 4 results and 0 failures
# DEBUG:flwr:fit_round 8 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:18:30,131 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 202.23it/s]
# INFO flwr 2025-02-15 19:18:30,373 | server_returns_parameters.py:120 | fit progress: (8, 115.02863311767578, {'accuracy': 0.4013333333333333}, 18.145303582889028)
# INFO:flwr:fit progress: (8, 115.02863311767578, {'accuracy': 0.4013333333333333}, 18.145303582889028)
# INFO flwr 2025-02-15 19:18:30,374 | server_returns_parameters.py:171 | evaluate_round 8: no clients selected, cancel
# INFO:flwr:evaluate_round 8: no clients selected, cancel
# INFO flwr 2025-02-15 19:18:30,382 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:18:30,383 | client_manager.py:68 | Sampled the following clients: ['1850', '249', '2079', '1864']
# INFO:flwr:Sampled the following clients: ['1850', '249', '2079', '1864']
# DEBUG flwr 2025-02-15 19:18:30,383 | server_returns_parameters.py:223 | fit_round 9: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 9: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:18:30,384 | client.py:51 | Creating client with cid: 1850
# INFO:flwr:Creating client with cid: 1850
# INFO flwr 2025-02-15 19:18:30,384 | client.py:51 | Creating client with cid: 249
# INFO flwr 2025-02-15 19:18:30,385 | client.py:51 | Creating client with cid: 2079
# INFO:flwr:Creating client with cid: 249
# INFO flwr 2025-02-15 19:18:30,385 | client.py:51 | Creating client with cid: 1864
# INFO:flwr:Creating client with cid: 2079
# INFO:flwr:Creating client with cid: 1864
# DEBUG flwr 2025-02-15 19:18:31,950 | server_returns_parameters.py:237 | fit_round 9 received 4 results and 0 failures
# DEBUG:flwr:fit_round 9 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:18:31,956 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 200.85it/s]
# INFO flwr 2025-02-15 19:18:32,197 | server_returns_parameters.py:120 | fit progress: (9, 117.12573206424713, {'accuracy': 0.35}, 19.968766374979168)
# INFO:flwr:fit progress: (9, 117.12573206424713, {'accuracy': 0.35}, 19.968766374979168)
# INFO flwr 2025-02-15 19:18:32,197 | server_returns_parameters.py:171 | evaluate_round 9: no clients selected, cancel
# INFO:flwr:evaluate_round 9: no clients selected, cancel
# INFO flwr 2025-02-15 19:18:32,206 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:18:32,206 | client_manager.py:68 | Sampled the following clients: ['2777', '82', '2583', '2652']
# INFO:flwr:Sampled the following clients: ['2777', '82', '2583', '2652']
# DEBUG flwr 2025-02-15 19:18:32,207 | server_returns_parameters.py:223 | fit_round 10: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 10: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:18:32,208 | client.py:51 | Creating client with cid: 2777
# INFO:flwr:Creating client with cid: 2777
# INFO flwr 2025-02-15 19:18:32,208 | client.py:51 | Creating client with cid: 82
# INFO:flwr:Creating client with cid: 82
# INFO flwr 2025-02-15 19:18:32,209 | client.py:51 | Creating client with cid: 2583
# INFO:flwr:Creating client with cid: 2583
# INFO flwr 2025-02-15 19:18:32,209 | client.py:51 | Creating client with cid: 2652
# INFO:flwr:Creating client with cid: 2652
# DEBUG flwr 2025-02-15 19:18:34,149 | server_returns_parameters.py:237 | fit_round 10 received 4 results and 0 failures
# DEBUG:flwr:fit_round 10 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:18:34,156 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 195.21it/s]
# INFO flwr 2025-02-15 19:18:34,405 | server_returns_parameters.py:120 | fit progress: (10, 106.68713092803955, {'accuracy': 0.43866666666666665}, 22.177292957901955)
# INFO:flwr:fit progress: (10, 106.68713092803955, {'accuracy': 0.43866666666666665}, 22.177292957901955)
# INFO flwr 2025-02-15 19:18:34,406 | server_returns_parameters.py:171 | evaluate_round 10: no clients selected, cancel
# INFO:flwr:evaluate_round 10: no clients selected, cancel
# INFO flwr 2025-02-15 19:18:34,416 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:18:34,417 | client_manager.py:68 | Sampled the following clients: ['2511', '257', '2232', '1056']
# INFO:flwr:Sampled the following clients: ['2511', '257', '2232', '1056']
# DEBUG flwr 2025-02-15 19:18:34,418 | server_returns_parameters.py:223 | fit_round 11: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 11: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:18:34,419 | client.py:51 | Creating client with cid: 2511
# INFO:flwr:Creating client with cid: 2511
# INFO flwr 2025-02-15 19:18:34,419 | client.py:51 | Creating client with cid: 257
# INFO:flwr:Creating client with cid: 257
# INFO flwr 2025-02-15 19:18:34,420 | client.py:51 | Creating client with cid: 2232
# INFO:flwr:Creating client with cid: 2232
# INFO flwr 2025-02-15 19:18:34,420 | client.py:51 | Creating client with cid: 1056
# INFO:flwr:Creating client with cid: 1056
# DEBUG flwr 2025-02-15 19:18:36,443 | server_returns_parameters.py:237 | fit_round 11 received 4 results and 0 failures
# DEBUG:flwr:fit_round 11 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:18:36,449 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 211.20it/s]
# INFO flwr 2025-02-15 19:18:36,679 | server_returns_parameters.py:120 | fit progress: (11, 109.43176352977753, {'accuracy': 0.398}, 24.451303290901706)
# INFO:flwr:fit progress: (11, 109.43176352977753, {'accuracy': 0.398}, 24.451303290901706)
# INFO flwr 2025-02-15 19:18:36,680 | server_returns_parameters.py:171 | evaluate_round 11: no clients selected, cancel
# INFO:flwr:evaluate_round 11: no clients selected, cancel
# INFO flwr 2025-02-15 19:18:36,689 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:18:36,690 | client_manager.py:68 | Sampled the following clients: ['225', '657', '1844', '1504']
# INFO:flwr:Sampled the following clients: ['225', '657', '1844', '1504']
# DEBUG flwr 2025-02-15 19:18:36,691 | server_returns_parameters.py:223 | fit_round 12: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 12: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:18:36,691 | client.py:51 | Creating client with cid: 225
# INFO:flwr:Creating client with cid: 225
# INFO flwr 2025-02-15 19:18:36,692 | client.py:51 | Creating client with cid: 657
# INFO:flwr:Creating client with cid: 657
# INFO flwr 2025-02-15 19:18:36,693 | client.py:51 | Creating client with cid: 1844
# INFO:flwr:Creating client with cid: 1844
# INFO flwr 2025-02-15 19:18:36,693 | client.py:51 | Creating client with cid: 1504
# INFO:flwr:Creating client with cid: 1504
# DEBUG flwr 2025-02-15 19:18:38,966 | server_returns_parameters.py:237 | fit_round 12 received 4 results and 0 failures
# DEBUG:flwr:fit_round 12 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:18:38,972 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 182.62it/s]
# INFO flwr 2025-02-15 19:18:39,237 | server_returns_parameters.py:120 | fit progress: (12, 120.36606180667877, {'accuracy': 0.37333333333333335}, 27.009151749894954)
# INFO:flwr:fit progress: (12, 120.36606180667877, {'accuracy': 0.37333333333333335}, 27.009151749894954)
# INFO flwr 2025-02-15 19:18:39,238 | server_returns_parameters.py:171 | evaluate_round 12: no clients selected, cancel
# INFO:flwr:evaluate_round 12: no clients selected, cancel
# INFO flwr 2025-02-15 19:18:39,249 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:18:39,250 | client_manager.py:68 | Sampled the following clients: ['168', '2252', '2386', '1450']
# INFO:flwr:Sampled the following clients: ['168', '2252', '2386', '1450']
# DEBUG flwr 2025-02-15 19:18:39,251 | server_returns_parameters.py:223 | fit_round 13: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 13: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:18:39,252 | client.py:51 | Creating client with cid: 168
# INFO:flwr:Creating client with cid: 168
# INFO flwr 2025-02-15 19:18:39,252 | client.py:51 | Creating client with cid: 2252
# INFO:flwr:Creating client with cid: 2252
# INFO flwr 2025-02-15 19:18:39,253 | client.py:51 | Creating client with cid: 2386
# INFO flwr 2025-02-15 19:18:39,253 | client.py:51 | Creating client with cid: 1450
# INFO:flwr:Creating client with cid: 2386
# INFO:flwr:Creating client with cid: 1450
# DEBUG flwr 2025-02-15 19:18:40,968 | server_returns_parameters.py:237 | fit_round 13 received 4 results and 0 failures
# DEBUG:flwr:fit_round 13 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:18:40,973 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 195.82it/s]
# INFO flwr 2025-02-15 19:18:41,221 | server_returns_parameters.py:120 | fit progress: (13, 119.94430482387543, {'accuracy': 0.42733333333333334}, 28.9928789580008)
# INFO:flwr:fit progress: (13, 119.94430482387543, {'accuracy': 0.42733333333333334}, 28.9928789580008)
# INFO flwr 2025-02-15 19:18:41,222 | server_returns_parameters.py:171 | evaluate_round 13: no clients selected, cancel
# INFO:flwr:evaluate_round 13: no clients selected, cancel
# INFO flwr 2025-02-15 19:18:41,233 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:18:41,234 | client_manager.py:68 | Sampled the following clients: ['1448', '982', '197', '1521']
# INFO:flwr:Sampled the following clients: ['1448', '982', '197', '1521']
# DEBUG flwr 2025-02-15 19:18:41,235 | server_returns_parameters.py:223 | fit_round 14: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 14: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:18:41,235 | client.py:51 | Creating client with cid: 1448
# INFO:flwr:Creating client with cid: 1448
# INFO flwr 2025-02-15 19:18:41,236 | client.py:51 | Creating client with cid: 982
# INFO:flwr:Creating client with cid: 982
# INFO flwr 2025-02-15 19:18:41,236 | client.py:51 | Creating client with cid: 197
# INFO:flwr:Creating client with cid: 197
# INFO flwr 2025-02-15 19:18:41,237 | client.py:51 | Creating client with cid: 1521
# INFO:flwr:Creating client with cid: 1521
# DEBUG flwr 2025-02-15 19:18:43,053 | server_returns_parameters.py:237 | fit_round 14 received 4 results and 0 failures
# DEBUG:flwr:fit_round 14 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:18:43,059 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 200.74it/s]
# INFO flwr 2025-02-15 19:18:43,301 | server_returns_parameters.py:120 | fit progress: (14, 116.67200362682343, {'accuracy': 0.41733333333333333}, 31.073274040943943)
# INFO:flwr:fit progress: (14, 116.67200362682343, {'accuracy': 0.41733333333333333}, 31.073274040943943)
# INFO flwr 2025-02-15 19:18:43,302 | server_returns_parameters.py:171 | evaluate_round 14: no clients selected, cancel
# INFO:flwr:evaluate_round 14: no clients selected, cancel
# INFO flwr 2025-02-15 19:18:43,315 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:18:43,317 | client_manager.py:68 | Sampled the following clients: ['1853', '3134', '2351', '1628']
# INFO:flwr:Sampled the following clients: ['1853', '3134', '2351', '1628']
# DEBUG flwr 2025-02-15 19:18:43,318 | server_returns_parameters.py:223 | fit_round 15: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 15: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:18:43,319 | client.py:51 | Creating client with cid: 1853
# INFO:flwr:Creating client with cid: 1853
# INFO flwr 2025-02-15 19:18:43,319 | client.py:51 | Creating client with cid: 3134
# INFO:flwr:Creating client with cid: 3134
# INFO flwr 2025-02-15 19:18:43,319 | client.py:51 | Creating client with cid: 2351
# INFO:flwr:Creating client with cid: 2351
# INFO flwr 2025-02-15 19:18:43,320 | client.py:51 | Creating client with cid: 1628
# INFO:flwr:Creating client with cid: 1628
# DEBUG flwr 2025-02-15 19:18:44,818 | server_returns_parameters.py:237 | fit_round 15 received 4 results and 0 failures
# DEBUG:flwr:fit_round 15 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:18:44,823 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00,
| server_returns_parameters.py:237 | fit_round 18 received 4 results and 0 failures
# DEBUG:flwr:fit_round 18 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:18:52,172 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 107.24it/s]
# INFO flwr 2025-02-15 19:18:52,618 | server_returns_parameters.py:120 | fit progress: (18, 149.35440850257874, {'accuracy': 0.37333333333333335}, 40.38966999994591)
# INFO:flwr:fit progress: (18, 149.35440850257874, {'accuracy': 0.37333333333333335}, 40.38966999994591)
# INFO flwr 2025-02-15 19:18:52,619 | server_returns_parameters.py:171 | evaluate_round 18: no clients selected, cancel
# INFO:flwr:evaluate_round 18: no clients selected, cancel
# INFO flwr 2025-02-15 19:18:52,637 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:18:52,638 | client_manager.py:68 | Sampled the following clients: ['723', '1096', '2064', '2940']
# INFO:flwr:Sampled the following clients: ['723', '1096', '2064', '2940']
# DEBUG flwr 2025-02-15 19:18:52,639 | server_returns_parameters.py:223 | fit_round 19: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 19: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:18:52,640 | client.py:51 | Creating client with cid: 723
# INFO:flwr:Creating client with cid: 723
# INFO flwr 2025-02-15 19:18:52,641 | client.py:51 | Creating client with cid: 1096
# INFO:flwr:Creating client with cid: 1096
# INFO flwr 2025-02-15 19:18:52,641 | client.py:51 | Creating client with cid: 2064
# INFO:flwr:Creating client with cid: 2064
# INFO flwr 2025-02-15 19:18:52,641 | client.py:51 | Creating client with cid: 2940
# INFO:flwr:Creating client with cid: 2940
# DEBUG flwr 2025-02-15 19:18:54,845 | server_returns_parameters.py:237 | fit_round 19 received 4 results and 0 failures
# DEBUG:flwr:fit_round 19 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:18:54,878 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 204.48it/s]
# INFO flwr 2025-02-15 19:18:55,121 | server_returns_parameters.py:120 | fit progress: (19, 142.23544549942017, {'accuracy': 0.36133333333333334}, 42.892821290995926)
# INFO:flwr:fit progress: (19, 142.23544549942017, {'accuracy': 0.36133333333333334}, 42.892821290995926)
# INFO flwr 2025-02-15 19:18:55,122 | server_returns_parameters.py:171 | evaluate_round 19: no clients selected, cancel
# INFO:flwr:evaluate_round 19: no clients selected, cancel
# INFO flwr 2025-02-15 19:18:55,138 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:18:55,139 | client_manager.py:68 | Sampled the following clients: ['1489', '2656', '994', '2742']
# INFO:flwr:Sampled the following clients: ['1489', '2656', '994', '2742']
# DEBUG flwr 2025-02-15 19:18:55,140 | server_returns_parameters.py:223 | fit_round 20: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 20: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:18:55,140 | client.py:51 | Creating client with cid: 1489
# INFO:flwr:Creating client with cid: 1489
# INFO flwr 2025-02-15 19:18:55,141 | client.py:51 | Creating client with cid: 2656
# INFO:flwr:Creating client with cid: 2656
# INFO flwr 2025-02-15 19:18:55,141 | client.py:51 | Creating client with cid: 994
# INFO:flwr:Creating client with cid: 994
# INFO flwr 2025-02-15 19:18:55,142 | client.py:51 | Creating client with cid: 2742
# INFO:flwr:Creating client with cid: 2742
# DEBUG flwr 2025-02-15 19:18:56,835 | server_returns_parameters.py:237 | fit_round 20 received 4 results and 0 failures
# DEBUG:flwr:fit_round 20 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:18:56,840 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 217.86it/s]
# INFO flwr 2025-02-15 19:18:57,063 | server_returns_parameters.py:120 | fit progress: (20, 119.07090735435486, {'accuracy': 0.4646666666666667}, 44.834911999991164)
# INFO:flwr:fit progress: (20, 119.07090735435486, {'accuracy': 0.4646666666666667}, 44.834911999991164)
# INFO flwr 2025-02-15 19:18:57,064 | server_returns_parameters.py:171 | evaluate_round 20: no clients selected, cancel
# INFO:flwr:evaluate_round 20: no clients selected, cancel
# INFO flwr 2025-02-15 19:18:57,081 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:18:57,082 | client_manager.py:68 | Sampled the following clients: ['764', '1484', '2389', '1480']
# INFO:flwr:Sampled the following clients: ['764', '1484', '2389', '1480']
# DEBUG flwr 2025-02-15 19:18:57,083 | server_returns_parameters.py:223 | fit_round 21: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 21: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:18:57,083 | client.py:51 | Creating client with cid: 764
# INFO:flwr:Creating client with cid: 764
# INFO flwr 2025-02-15 19:18:57,084 | client.py:51 | Creating client with cid: 1484
# INFO:flwr:Creating client with cid: 1484
# INFO flwr 2025-02-15 19:18:57,084 | client.py:51 | Creating client with cid: 2389
# INFO:flwr:Creating client with cid: 2389
# INFO flwr 2025-02-15 19:18:57,084 | client.py:51 | Creating client with cid: 1480
# INFO:flwr:Creating client with cid: 1480
# DEBUG flwr 2025-02-15 19:18:58,977 | server_returns_parameters.py:237 | fit_round 21 received 4 results and 0 failures
# DEBUG:flwr:fit_round 21 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:18:58,983 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 198.55it/s]
# INFO flwr 2025-02-15 19:18:59,228 | server_returns_parameters.py:120 | fit progress: (21, 110.29190719127655, {'accuracy': 0.5053333333333333}, 46.99948312493507)
# INFO:flwr:fit progress: (21, 110.29190719127655, {'accuracy': 0.5053333333333333}, 46.99948312493507)
# INFO flwr 2025-02-15 19:18:59,229 | server_returns_parameters.py:171 | evaluate_round 21: no clients selected, cancel
# INFO:flwr:evaluate_round 21: no clients selected, cancel
# INFO flwr 2025-02-15 19:18:59,246 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:18:59,246 | client_manager.py:68 | Sampled the following clients: ['2956', '1486', '3184', '2464']
# INFO:flwr:Sampled the following clients: ['2956', '1486', '3184', '2464']
# DEBUG flwr 2025-02-15 19:18:59,247 | server_returns_parameters.py:223 | fit_round 22: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 22: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:18:59,248 | client.py:51 | Creating client with cid: 2956
# INFO:flwr:Creating client with cid: 2956
# INFO flwr 2025-02-15 19:18:59,248 | client.py:51 | Creating client with cid: 1486
# INFO:flwr:Creating client with cid: 1486
# INFO flwr 2025-02-15 19:18:59,249 | client.py:51 | Creating client with cid: 3184
# INFO:flwr:Creating client with cid: 3184
# INFO flwr 2025-02-15 19:18:59,250 | client.py:51 | Creating client with cid: 2464
# INFO:flwr:Creating client with cid: 2464
# DEBUG flwr 2025-02-15 19:19:00,782 | server_returns_parameters.py:237 | fit_round 22 received 4 results and 0 failures
# DEBUG:flwr:fit_round 22 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:19:00,788 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 206.14it/s]
# INFO flwr 2025-02-15 19:19:01,024 | server_returns_parameters.py:120 | fit progress: (22, 110.955002784729, {'accuracy': 0.466}, 48.79534958291333)
# INFO:flwr:fit progress: (22, 110.955002784729, {'accuracy': 0.466}, 48.79534958291333)
# INFO flwr 2025-02-15 19:19:01,024 | server_returns_parameters.py:171 | evaluate_round 22: no clients selected, cancel
# INFO:flwr:evaluate_round 22: no clients selected, cancel
# INFO flwr 2025-02-15 19:19:01,043 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:19:01,044 | client_manager.py:68 | Sampled the following clients: ['1306', '0', '2651', '2426']
# INFO:flwr:Sampled the following clients: ['1306', '0', '2651', '2426']
# DEBUG flwr 2025-02-15 19:19:01,044 | server_returns_parameters.py:223 | fit_round 23: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 23: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:19:01,045 | client.py:51 | Creating client with cid: 1306
# INFO:flwr:Creating client with cid: 1306
# INFO flwr 2025-02-15 19:19:01,046 | client.py:51 | Creating client with cid: 0
# INFO:flwr:Creating client with cid: 0
# INFO flwr 2025-02-15 19:19:01,046 | client.py:51 | Creating client with cid: 2651
# INFO:flwr:Creating client with cid: 2651
# INFO flwr 2025-02-15 19:19:01,047 | client.py:51 | Creating client with cid: 2426
# INFO:flwr:Creating client with cid: 2426
# DEBUG flwr 2025-02-15 19:19:02,676 | server_returns_parameters.py:237 | fit_round 23 received 4 results and 0 failures
# DEBUG:flwr:fit_round 23 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:19:02,682 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 211.24it/s]
# INFO flwr 2025-02-15 19:19:02,913 | server_returns_parameters.py:120 | fit progress: (23, 108.11147236824036, {'accuracy': 0.45}, 50.684347790898755)
# INFO:flwr:fit progress: (23, 108.11147236824036, {'accuracy': 0.45}, 50.684347790898755)
# INFO flwr 2025-02-15 19:19:02,913 | server_returns_parameters.py:171 | evaluate_round 23: no clients selected, cancel
# INFO:flwr:evaluate_round 23: no clients selected, cancel
# INFO flwr 2025-02-15 19:19:02,932 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:19:02,933 | client_manager.py:68 | Sampled the following clients: ['1721', '2204', '3192', '1258']
# INFO:flwr:Sampled the following clients: ['1721', '2204', '3192', '1258']
# DEBUG flwr 2025-02-15 19:19:02,933 | server_returns_parameters.py:223 | fit_round 24: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 24: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:19:02,934 | client.py:51 | Creating client with cid: 1721
# INFO:flwr:Creating client with cid: 1721
# INFO flwr 2025-02-15 19:19:02,935 | client.py:51 | Creating client with cid: 2204
# INFO:flwr:Creating client with cid: 2204
# INFO flwr 2025-02-15 19:19:02,935 | client.py:51 | Creating client with cid: 3192
# INFO:flwr:Creating client with cid: 3192
# INFO flwr 2025-02-15 19:19:02,935 | client.py:51 | Creating client with cid: 1258
# INFO:flwr:Creating client with cid: 1258
# DEBUG flwr 2025-02-15 19:19:05,292 | server_returns_parameters.py:237 | fit_round 24 received 4 results and 0 failures
# DEBUG:flwr:fit_round 24 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:19:05,299 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 183.51it/s]
# INFO flwr 2025-02-15 19:19:05,563 | server_returns_parameters.py:120 | fit progress: (24, 128.23630261421204, {'accuracy': 0.35733333333333334}, 53.33509291592054)
# INFO:flwr:fit progress: (24, 128.23630261421204, {'accuracy': 0.35733333333333334}, 53.33509291592054)
# INFO flwr 2025-02-15 19:19:05,564 | server_returns_parameters.py:171 | evaluate_round 24: no clients selected, cancel
# INFO:flwr:evaluate_round 24: no clients selected, cancel
# INFO flwr 2025-02-15 19:19:05,585 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:19:05,586 | client_manager.py:68 | Sampled the following clients: ['2176', '1230', '1374', '1154']
# INFO:flwr:Sampled the following clients: ['2176', '1230', '1374', '1154']
# DEBUG flwr 2025-02-15 19:19:05,587 | server_returns_parameters.py:223 | fit_round 25: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 25: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:19:05,588 | client.py:51 | Creating client with cid: 2176
# INFO:flwr:Creating client with cid: 2176
# INFO flwr 2025-02-15 19:19:05,588 | client.py:51 | Creating client with cid: 1230
# INFO:flwr:Creating client with cid: 1230
# INFO flwr 2025-02-15 19:19:05,588 | client.py:51 | Creating client with cid: 1374
# INFO:flwr:Creating client with cid: 1374
# INFO flwr 2025-02-15 19:19:05,589 | client.py:51 | Creating client with cid: 1154
# INFO:flwr:Creating client with cid: 1154
# DEBUG flwr 2025-02-15 19:19:07,393 | server_returns_parameters.py:237 | fit_round 25 received 4 results and 0 failures
# DEBUG:flwr:fit_round 25 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:19:07,398 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 195.45it/s]
# INFO flwr 2025-02-15 19:19:07,646 | server_returns_parameters.py:120 | fit progress: (25, 200.5713939666748, {'accuracy': 0.13866666666666666}, 55.41799833299592)
# INFO:flwr:fit progress: (25, 200.5713939666748, {'accuracy': 0.13866666666666666}, 55.41799833299592)
# INFO flwr 2025-02-15 19:19:07,647 | server_returns_parameters.py:171 | evaluate_round 25: no clients selected, cancel
# INFO:flwr:evaluate_round 25: no clients selected, cancel
# INFO flwr 2025-02-15 19:19:07,668 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:19:07,669 | client_manager.py:68 | Sampled the following clients: ['1924', '3035', '2189', '1444']
# INFO:flwr:Sampled the following clients: ['1924', '3035', '2189', '1444']
# DEBUG flwr 2025-02-15 19:19:07,669 | server_returns_parameters.py:223 | fit_round 26: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 26: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:19:07,670 | client.py:51 | Creating client with cid: 1924
# INFO:flwr:Creating client with cid: 1924
# INFO flwr 2025-02-15 19:19:07,671 | client.py:51 | Creating client with cid: 3035
# INFO:flwr:Creating client with cid: 3035
# INFO flwr 2025-02-15 19:19:07,671 | client.py:51 | Creating client with cid: 2189
# INFO flwr 2025-02-15 19:19:07,671 | client.py:51 | Creating client with cid: 1444
# INFO:flwr:Creating client with cid: 2189
# INFO:flwr:Creating client with cid: 1444
# DEBUG flwr 2025-02-15 19:19:09,153 | server_returns_parameters.py:237 | fit_round 26 received 4 results and 0 failures
# DEBUG:flwr:fit_round 26 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:19:09,159 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 199.11it/s]
# INFO flwr 2025-02-15 19:19:09,404 | server_returns_parameters.py:120 | fit progress: (26, 130.03652131557465, {'accuracy': 0.3353333333333333}, 57.175120749976486)
# INFO:flwr:fit progress: (26, 130.03652131557465, {'accuracy': 0.3353333333333333}, 57.175120749976486)
# INFO flwr 2025-02-15 19:19:09,404 | server_returns_parameters.py:171 | evaluate_round 26: no clients selected, cancel
# INFO:flwr:evaluate_round 26: no clients selected, cancel
# INFO flwr 2025-02-15 19:19:09,426 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19
# 1. Use one round of federated training with `num_clients_per_round=50` to empirically derive a **very rough baseline** of the average L2 norm at the beginning of training. Modify the client `fit` function to return in the metrics dictionary the L2 norm of the model update **prior** to clipping. Finally, compute the mean $\mu$ of the L2 norms from all of the 50 clients. You can find them in the history object returned in the "all" category of the metric. _NOTE: do not use the "avg" category because it is weighted._
#
#    > The results of this question will be used in the next one. Thus, to save yourself work, modify the strategy object. Make it compute the L2 norm of the overall model delta. This delta is defined as the difference between the federated model at the start of the round and the federated model after aggregation. Put the value of the L2 norm of the delta into the history object as a metric into the already aggregated metrics object. (The strategy has access to the starting parameters of a round in `configure_fit` as well as the aggregated metrics of all the clients.)
#
# 2. Using values of `clip_norm`$\in \{ \mu \times 0.25,\, \mu, \,\mu \times 1.75\}$, run `DPFedAvgFixed` experiments with the same parameters as the example provided above using a `noise_multiplier=0`.
#
# 3. Plot per-round accuracy on the federated test set of models trained using the three bounds above. Which bound converges the fastest and to the highest final accuracy, and why do you think that is?

# %% [markdown]
# ---
#
# **Question 3 Answer:**
#
# Part 1:

# %%
num_clients_per_round=50
exp_3_run_parameters = default_parameters.copy()
exp_3_run_parameters["num_clients_per_round"] = num_clients_per_round
exp_3_run_parameters["num_rounds"] = 1
parameters_for_one_round_exp_3, hist_exp_3 = run_dp_fixed_fl(default_parameters=exp_3_run_parameters)
# Out:
# WARNING flwr 2025-02-15 19:20:16,876 | app.py:213 | Both server and strategy were provided, ignoring strategy
# WARNING:flwr:Both server and strategy were provided, ignoring strategy
# INFO flwr 2025-02-15 19:20:16,895 | app.py:149 | Starting Flower simulation, config: ServerConfig(num_rounds=1, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=1, round_timeout=None)
# INFO flwr 2025-02-15 19:20:16,939 | server_returns_parameters.py:81 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2025-02-15 19:20:16,943 | server_returns_parameters.py:273 | Using initial parameters provided by strategy
# INFO:flwr:Using initial parameters provided by strategy
# INFO flwr 2025-02-15 19:20:16,950 | server_returns_parameters.py:84 | Evaluating initial parameters
# INFO:flwr:Evaluating initial parameters
# 100%|██████████| 47/47 [00:00<00:00, 52.22it/s]
# INFO flwr 2025-02-15 19:20:17,912 | server_returns_parameters.py:87 | initial parameters (loss, other metrics): 194.37576580047607, {'accuracy': 0.004}
# INFO:flwr:initial parameters (loss, other metrics): 194.37576580047607, {'accuracy': 0.004}
# INFO flwr 2025-02-15 19:20:17,913 | server_returns_parameters.py:97 | FL starting
# INFO:flwr:FL starting
# INFO flwr 2025-02-15 19:20:17,916 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:20:17,918 | client_manager.py:68 | Sampled the following clients: ['1101', '2904', '2613', '3179', '455', '1608', '1626', '1613', '1378', '2455', '2757', '907', '135', '1997', '1321', '2425', '1329', '834', '880', '531', '689', '3073', '1317', '409', '1426', '2917', '981', '613', '2528', '1961', '2474', '1918', '1882', '2839', '2626', '2356', '78', '3144', '1610', '1306', '2423', '586', '1002', '1281', '3132', '550', '1297', '3101', '1801', '2736']
# INFO:flwr:Sampled the following clients: ['1101', '2904', '2613', '3179', '455', '1608', '1626', '1613', '1378', '2455', '2757', '907', '135', '1997', '1321', '2425', '1329', '834', '880', '531', '689', '3073', '1317', '409', '1426', '2917', '981', '613', '2528', '1961', '2474', '1918', '1882', '2839', '2626', '2356', '78', '3144', '1610', '1306', '2423', '586', '1002', '1281', '3132', '550', '1297', '3101', '1801', '2736']
# DEBUG flwr 2025-02-15 19:20:17,921 | server_returns_parameters.py:223 | fit_round 1: strategy sampled 50 clients (out of 3224)
# DEBUG:flwr:fit_round 1: strategy sampled 50 clients (out of 3224)
# INFO flwr 2025-02-15 19:20:17,925 | client.py:51 | Creating client with cid: 1101
# INFO:flwr:Creating client with cid: 1101
# INFO flwr 2025-02-15 19:20:17,927 | client.py:51 | Creating client with cid: 2904
# INFO:flwr:Creating client with cid: 2904
# INFO flwr 2025-02-15 19:20:17,928 | client.py:51 | Creating client with cid: 2613
# INFO:flwr:Creating client with cid: 2613
# INFO flwr 2025-02-15 19:20:17,928 | client.py:51 | Creating client with cid: 3179
# INFO:flwr:Creating client with cid:
| app.py:149 | Starting Flower simulation, config: ServerConfig(num_rounds=30, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=30, round_timeout=None)
# INFO flwr 2025-02-15 19:35:15,250 | server_returns_parameters.py:81 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2025-02-15 19:35:15,253 | server_returns_parameters.py:273 | Using initial parameters provided by strategy
# INFO:flwr:Using initial parameters provided by strategy
# INFO flwr 2025-02-15 19:35:15,256 | server_returns_parameters.py:84 | Evaluating initial parameters
# INFO:flwr:Evaluating initial parameters
# 100%|██████████| 47/47 [00:00<00:00, 54.61it/s]
# INFO flwr 2025-02-15 19:35:16,165 | server_returns_parameters.py:87 | initial parameters (loss, other metrics): 194.37576580047607, {'accuracy': 0.004}
# INFO:flwr:initial parameters (loss, other metrics): 194.37576580047607, {'accuracy': 0.004}
# INFO flwr 2025-02-15 19:35:16,166 | server_returns_parameters.py:97 | FL starting
# INFO:flwr:FL starting
# INFO flwr 2025-02-15 19:35:16,169 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:35:16,170 | client_manager.py:68 | Sampled the following clients: ['1101', '2904', '2613', '3179']
# INFO:flwr:Sampled the following clients: ['1101', '2904', '2613', '3179']
# DEBUG flwr 2025-02-15 19:35:16,171 | server_returns_parameters.py:223 | fit_round 1: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 1: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:35:16,173 | client.py:51 | Creating client with cid: 1101
# INFO:flwr:Creating client with cid: 1101
# INFO flwr 2025-02-15 19:35:16,174 | client.py:51 | Creating client with cid: 2904
# INFO:flwr:Creating client with cid: 2904
# INFO flwr 2025-02-15 19:35:16,174 | client.py:51 | Creating client with cid: 2613
# INFO:flwr:Creating client with cid: 2613
# INFO flwr 2025-02-15 19:35:16,174 | client.py:51 | Creating client with cid: 3179
# INFO:flwr:Creating client with cid: 3179
# DEBUG flwr 2025-02-15 19:35:18,363 | server_returns_parameters.py:237 | fit_round 1 received 4 results and 0 failures
# DEBUG:flwr:fit_round 1 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:35:18,370 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 185.25it/s]
# INFO flwr 2025-02-15 19:35:18,632 | server_returns_parameters.py:120 | fit progress: (1, 190.85867738723755, {'accuracy': 0.07933333333333334}, 2.4645919159520417)
# INFO:flwr:fit progress: (1, 190.85867738723755, {'accuracy': 0.07933333333333334}, 2.4645919159520417)
# INFO flwr 2025-02-15 19:35:18,633 | server_returns_parameters.py:171 | evaluate_round 1: no clients selected, cancel
# INFO:flwr:evaluate_round 1: no clients selected, cancel
# INFO flwr 2025-02-15 19:35:18,635 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:35:18,636 | client_manager.py:68 | Sampled the following clients: ['1418', '27', '1758', '410']
# INFO:flwr:Sampled the following clients: ['1418', '27', '1758', '410']
# DEBUG flwr 2025-02-15 19:35:18,636 | server_returns_parameters.py:223 | fit_round 2: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 2: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:35:18,637 | client.py:51 | Creating client with cid: 1418
# INFO:flwr:Creating client with cid: 1418
# INFO flwr 2025-02-15 19:35:18,638 | client.py:51 | Creating client with cid: 27
# INFO:flwr:Creating client with cid: 27
# INFO flwr 2025-02-15 19:35:18,638 | client.py:51 | Creating client with cid: 1758
# INFO:flwr:Creating client with cid: 1758
# INFO flwr 2025-02-15 19:35:18,639 | client.py:51 | Creating client with cid: 410
# INFO:flwr:Creating client with cid: 410
# DEBUG flwr 2025-02-15 19:35:20,578 | server_returns_parameters.py:237 | fit_round 2 received 4 results and 0 failures
# DEBUG:flwr:fit_round 2 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:35:20,584 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 201.52it/s]
# INFO flwr 2025-02-15 19:35:20,825 | server_returns_parameters.py:120 | fit progress: (2, 186.04349517822266, {'accuracy': 0.07933333333333334}, 4.6572019580053166)
# INFO:flwr:fit progress: (2, 186.04349517822266, {'accuracy': 0.07933333333333334}, 4.6572019580053166)
# INFO flwr 2025-02-15 19:35:20,825 | server_returns_parameters.py:171 | evaluate_round 2: no clients selected, cancel
# INFO:flwr:evaluate_round 2: no clients selected, cancel
# INFO flwr 2025-02-15 19:35:20,828 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:35:20,829 | client_manager.py:68 | Sampled the following clients: ['2215', '1477', '3146', '993']
# INFO:flwr:Sampled the following clients: ['2215', '1477', '3146', '993']
# DEBUG flwr 2025-02-15 19:35:20,830 | server_returns_parameters.py:223 | fit_round 3: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 3: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:35:20,832 | client.py:51 | Creating client with cid: 2215
# INFO:flwr:Creating client with cid: 2215
# INFO flwr 2025-02-15 19:35:20,832 | client.py:51 | Creating client with cid: 1477
# INFO:flwr:Creating client with cid: 1477
# INFO flwr 2025-02-15 19:35:20,833 | client.py:51 | Creating client with cid: 3146
# INFO:flwr:Creating client with cid: 3146
# INFO flwr 2025-02-15 19:35:20,834 | client.py:51 | Creating client with cid: 993
# INFO:flwr:Creating client with cid: 993
# DEBUG flwr 2025-02-15 19:35:22,611 | server_returns_parameters.py:237 | fit_round 3 received 4 results and 0 failures
# DEBUG:flwr:fit_round 3 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:35:22,618 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 174.72it/s]
# INFO flwr 2025-02-15 19:35:22,895 | server_returns_parameters.py:120 | fit progress: (3, 172.68837547302246, {'accuracy': 0.07933333333333334}, 6.727135416003875)
# INFO:flwr:fit progress: (3, 172.68837547302246, {'accuracy': 0.07933333333333334}, 6.727135416003875)
# INFO flwr 2025-02-15 19:35:22,896 | server_returns_parameters.py:171 | evaluate_round 3: no clients selected, cancel
# INFO:flwr:evaluate_round 3: no clients selected, cancel
# INFO flwr 2025-02-15 19:35:22,900 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:35:22,901 | client_manager.py:68 | Sampled the following clients: ['2955', '1583', '580', '779']
# INFO:flwr:Sampled the following clients: ['2955', '1583', '580', '779']
# DEBUG flwr 2025-02-15 19:35:22,901 | server_returns_parameters.py:223 | fit_round 4: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 4: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:35:22,902 | client.py:51 | Creating client with cid: 2955
# INFO:flwr:Creating client with cid: 2955
# INFO flwr 2025-02-15 19:35:22,903 | client.py:51 | Creating client with cid: 1583
# INFO:flwr:Creating client with cid: 1583
# INFO flwr 2025-02-15 19:35:22,903 | client.py:51 | Creating client with cid: 580
# INFO:flwr:Creating client with cid: 580
# INFO flwr 2025-02-15 19:35:22,903 | client.py:51 | Creating client with cid: 779
# INFO:flwr:Creating client with cid: 779
# DEBUG flwr 2025-02-15 19:35:25,028 | server_returns_parameters.py:237 | fit_round 4 received 4 results and 0 failures
# DEBUG:flwr:fit_round 4 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:35:25,034 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 166.00it/s]
# INFO flwr 2025-02-15 19:35:25,326 | server_returns_parameters.py:120 | fit progress: (4, 169.07495212554932, {'accuracy': 0.08866666666666667}, 9.158413290977478)
# INFO:flwr:fit progress: (4, 169.07495212554932, {'accuracy': 0.08866666666666667}, 9.158413290977478)
# INFO flwr 2025-02-15 19:35:25,327 | server_returns_parameters.py:171 | evaluate_round 4: no clients selected, cancel
# INFO:flwr:evaluate_round 4: no clients selected, cancel
# INFO flwr 2025-02-15 19:35:25,332 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:35:25,333 | client_manager.py:68 | Sampled the following clients: ['1656', '1717', '1348', '261']
# INFO:flwr:Sampled the following clients: ['1656', '1717', '1348', '261']
# DEBUG flwr 2025-02-15 19:35:25,334 | server_returns_parameters.py:223 | fit_round 5: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 5: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:35:25,335 | client.py:51 | Creating client with cid: 1656
# INFO:flwr:Creating client with cid: 1656
# INFO flwr 2025-02-15 19:35:25,336 | client.py:51 | Creating client with cid: 1717
# INFO:flwr:Creating client with cid: 1717
# INFO flwr 2025-02-15 19:35:25,336 | client.py:51 | Creating client with cid: 1348
# INFO:flwr:Creating client with cid: 1348
# INFO flwr 2025-02-15 19:35:25,336 | client.py:51 | Creating client with cid: 261
# INFO:flwr:Creating client with cid: 261
# DEBUG flwr 2025-02-15 19:35:27,326 | server_returns_parameters.py:237 | fit_round 5 received 4 results and 0 failures
# DEBUG:flwr:fit_round 5 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:35:27,332 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 203.63it/s]
# INFO flwr 2025-02-15 19:35:27,571 | server_returns_parameters.py:120 | fit progress: (5, 164.46526074409485, {'accuracy': 0.08666666666666667}, 11.40390391589608)
# INFO:flwr:fit progress: (5, 164.46526074409485, {'accuracy': 0.08666666666666667}, 11.40390391589608)
# INFO flwr 2025-02-15 19:35:27,572 | server_returns_parameters.py:171 | evaluate_round 5: no clients selected, cancel
# INFO:flwr:evaluate_round 5: no clients selected, cancel
# INFO flwr 2025-02-15 19:35:27,577 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:35:27,578 | client_manager.py:68 | Sampled the following clients: ['346', '2627', '2817', '1058']
# INFO:flwr:Sampled the following clients: ['346', '2627', '2817', '1058']
# DEBUG flwr 2025-02-15 19:35:27,579 | server_returns_parameters.py:223 | fit_round 6: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 6: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:35:27,579 | client.py:51 | Creating client with cid: 346
# INFO:flwr:Creating client with cid: 346
# INFO flwr 2025-02-15 19:35:27,580 | client.py:51 | Creating client with cid: 2627
# INFO:flwr:Creating client with cid: 2627
# INFO flwr 2025-02-15 19:35:27,580 | client.py:51 | Creating client with cid: 2817
# INFO:flwr:Creating client with cid: 2817
# INFO flwr 2025-02-15 19:35:27,581 | client.py:51 | Creating client with cid: 1058
# INFO:flwr:Creating client with cid: 1058
# DEBUG flwr 2025-02-15 19:35:29,646 | server_returns_parameters.py:237 | fit_round 6 received 4 results and 0 failures
# DEBUG:flwr:fit_round 6 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:35:29,651 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 208.66it/s]
# INFO flwr 2025-02-15 19:35:29,885 | server_returns_parameters.py:120 | fit progress: (6, 160.29001092910767, {'accuracy': 0.08933333333333333}, 13.716944999992847)
# INFO:flwr:fit progress: (6, 160.29001092910767, {'accuracy': 0.08933333333333333}, 13.716944999992847)
# INFO flwr 2025-02-15 19:35:29,885 | server_returns_parameters.py:171 | evaluate_round 6: no clients selected, cancel
# INFO:flwr:evaluate_round 6: no clients selected, cancel
# INFO flwr 2025-02-15 19:35:29,891 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:35:29,892 | client_manager.py:68 | Sampled the following clients: ['2251', '159', '3062', '2996']
# INFO:flwr:Sampled the following clients: ['2251', '159', '3062', '2996']
# DEBUG flwr 2025-02-15 19:35:29,892 | server_returns_parameters.py:223 | fit_round 7: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 7: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:35:29,893 | client.py:51 | Creating client with cid: 2251
# INFO:flwr:Creating client with cid: 2251
# INFO flwr 2025-02-15 19:35:29,893 | client.py:51 | Creating client with cid: 159
# INFO:flwr:Creating client with cid: 159
# INFO flwr 2025-02-15 19:35:29,894 | client.py:51 | Creating client with cid: 3062
# INFO:flwr:Creating client with cid: 3062
# INFO flwr 2025-02-15 19:35:29,894 | client.py:51 | Creating client with cid: 2996
# INFO:flwr:Creating client with cid: 2996
# DEBUG flwr 2025-02-15 19:35:31,399 | server_returns_parameters.py:237 | fit_round 7 received 4 results and 0 failures
# DEBUG:flwr:fit_round 7 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:35:31,406 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 200.40it/s]
# INFO flwr 2025-02-15 19:35:31,649 | server_returns_parameters.py:120 | fit progress: (7, 154.12442922592163, {'accuracy': 0.19}, 15.481293374905363)
# INFO:flwr:fit progress: (7, 154.12442922592163, {'accuracy': 0.19}, 15.481293374905363)
# INFO flwr 2025-02-15 19:35:31,649 | server_returns_parameters.py:171 | evaluate_round 7: no clients selected, cancel
# INFO:flwr:evaluate_round 7: no clients selected, cancel
# INFO flwr 2025-02-15 19:35:31,656 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:35:31,657 | client_manager.py:68 | Sampled the following clients: ['2411', '528', '943', '725']
# INFO:flwr:Sampled the following clients: ['2411', '528', '943', '725']
# DEBUG flwr 2025-02-15 19:35:31,657 | server_returns_parameters.py:223 | fit_round 8: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 8: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:35:31,658 | client.py:51 | Creating client with cid: 2411
# INFO:flwr:Creating client with cid: 2411
# INFO flwr 2025-02-15 19:35:31,659 | client.py:51 | Creating client with cid: 528
# INFO:flwr:Creating client with cid: 528
# INFO flwr 2025-02-15 19:35:31,659 | client.py:51 | Creating client with cid: 943
# INFO flwr 2025-02-15 19:35:31,660 | client.py:51 | Creating client with cid: 725
# INFO:flwr:Creating client with cid: 943
# INFO:flwr:Creating client with cid: 725
# DEBUG flwr 2025-02-15 19:35:33,604 | server_returns_parameters.py:237 | fit_round 8 received 4 results and 0 failures
# DEBUG:flwr:fit_round 8 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:35:33,610 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 194.41it/s]
# INFO flwr 2025-02-15 19:35:33,861 | server_returns_parameters.py:120 | fit progress: (8, 148.19002413749695, {'accuracy': 0.22266666666666668}, 17.69296549994033)
# INFO:flwr:fit progress: (8, 148.19002413749695, {'accuracy': 0.22266666666666668}, 17.69296549994033)
# INFO flwr 2025-02-15 19:35:33,861 | server_returns_parameters.py:171 | evaluate_round 8: no clients selected, cancel
# INFO:flwr:evaluate_round 8: no clients selected, cancel
# INFO flwr 2025-02-15 19:35:33,869 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:35:33,870 | client_manager.py:68 | Sampled the following clients: ['1850', '249', '2079', '1864']
# INFO:flwr:Sampled the following clients: ['1850', '249', '2079', '1864']
# DEBUG flwr 2025-02-15 19:35:33,871 | server_returns_parameters.py:223 | fit_round 9: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 9: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:35:33,871 | client.py:51 | Creating client with cid: 1850
# INFO:flwr:Creating client with cid: 1850
# INFO flwr 2025-02-15 19:35:33,872 | client.py:51 | Creating client with cid: 249
# INFO:flwr:Creating client with cid: 249
# INFO flwr 2025-02-15 19:35:33,872 | client.py:51 | Creating client with cid: 2079
# INFO flwr 2025-02-15 19:35:33,873 | client.py:51 | Creating client with cid: 1864
# INFO:flwr:Creating client with cid: 2079
# INFO:flwr:Creating client with cid: 1864
# DEBUG flwr 2025-02-15 19:35:35,474 | server_returns_parameters.py:237 | fit_round 9 received 4 results and 0 failures
# DEBUG:flwr:fit_round 9 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:35:35,480 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 191.05it/s]
# INFO flwr 2025-02-15 19:35:35,734 | server_returns_parameters.py:120 | fit progress: (9, 140.37460064888, {'accuracy': 0.24533333333333332}, 19.566507499897853)
# INFO:flwr:fit progress: (9, 140.37460064888, {'accuracy': 0.24533333333333332}, 19.566507499897853)
# INFO flwr 2025-02-15 19:35:35,735 | server_returns_parameters.py:171 | evaluate_round 9: no clients selected, cancel
# INFO:flwr:evaluate_round 9: no clients selected, cancel
# INFO flwr 2025-02-15 19:35:35,744 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:35:35,745 | client_manager.py:68 | Sampled the following clients: ['2777', '82', '2583', '2652']
# INFO:flwr:Sampled the following clients: ['2777', '82', '2583', '2652']
# DEBUG flwr 2025-02-15 19:35:35,745 | server_returns_parameters.py:223 | fit_round 10: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 10: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:35:35,746 | client.py:51 | Creating client with cid: 2777
# INFO:flwr:Creating client with cid: 2777
# INFO flwr 2025-02-15 19:35:35,747 | client.py:51 | Creating client with cid: 82
# INFO:flwr:Creating client with cid: 82
# INFO flwr 2025-02-15 19:35:35,747 | client.py:51 | Creating client with cid: 2583
# INFO:flwr:Creating client with cid: 2583
# INFO flwr 2025-02-15 19:35:35,747 | client.py:51 | Creating client with cid: 2652
# INFO:flwr:Creating client with cid: 2652
# DEBUG flwr 2025-02-15 19:35:37,818 | server_returns_parameters.py:237 | fit_round 10 received 4 results and 0 failures
# DEBUG:flwr:fit_round 10 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:35:37,823 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 196.28it/s]
# INFO flwr 2025-02-15 19:35:38,071 | server_returns_parameters.py:120 | fit progress: (10, 130.91253328323364, {'accuracy': 0.294}, 21.90311087493319)
# INFO:flwr:fit progress: (10, 130.91253328323364, {'accuracy': 0.294}, 21.90311087493319)
# INFO flwr 2025-02-15 19:35:38,072 | server_returns_parameters.py:171 | evaluate_round 10: no clients selected, cancel
# INFO:flwr:evaluate_round 10: no clients selected, cancel
# INFO flwr 2025-02-15 19:35:38,081 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:35:38,081 | client_manager.py:68 | Sampled the following clients: ['2511', '257', '2232', '1056']
# INFO:flwr:Sampled the following clients: ['2511', '257', '2232', '1056']
# DEBUG flwr 2025-02-15 19:35:38,082 | server_returns_parameters.py:223 | fit_round 11: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 11: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:35:38,083 | client.py:51 | Creating client with cid: 2511
# INFO:flwr:Creating client with cid: 2511
# INFO flwr 2025-02-15 19:35:38,084 | client.py:51 | Creating client with cid: 257
# INFO:flwr:Creating client with cid: 257
# INFO flwr 2025-02-15 19:35:38,084 | client.py:51 | Creating client with cid: 2232
# INFO:flwr:Creating client with cid: 2232
# INFO flwr 2025-02-15 19:35:38,085 | client.py:51 | Creating client with cid: 1056
# INFO:flwr:Creating client with cid: 1056
# DEBUG flwr 2025-02-15 19:35:40,154 | server_returns_parameters.py:237 | fit_round 11 received 4 results and 0 failures
# DEBUG:flwr:fit_round 11 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:35:40,160 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 188.89it/s]
# INFO flwr 2025-02-15 19:35:40,417 | server_returns_parameters.py:120 | fit progress: (11, 124.00609993934631, {'accuracy': 0.31466666666666665}, 24.249712124932557)
# INFO:flwr:fit progress: (11, 124.00609993934631, {'accuracy': 0.31466666666666665}, 24.249712124932557)
# INFO flwr 2025-02-15 19:35:40,418 | server_returns_parameters.py:171 | evaluate_round 11: no clients selected, cancel
# INFO:flwr:evaluate_round 11: no clients selected, cancel
# INFO flwr 2025-02-15 19:35:40,428 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:35:40,429 | client_manager.py:68 | Sampled the following clients: ['225', '657', '1844', '1504']
# INFO:flwr:Sampled the following clients: ['225', '657', '1844', '1504']
# DEBUG flwr 2025-02-15 19:35:40,430 | server_returns_parameters.py:223 | fit_round 12: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 12: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:35:40,430 | client.py:51 | Creating client with cid: 225
# INFO:flwr:Creating client with cid: 225
# INFO flwr 2025-02-15 19:35:40,431 | client.py:51 | Creating client with cid: 657
# INFO:flwr:Creating client with cid: 657
# INFO flwr 2025-02-15 19:35:40,431 | client.py:51 | Creating client with cid: 1844
# INFO:flwr:Creating client with cid: 1844
# INFO flwr 2025-02-15 19:35:40,432 | client.py:51 | Creating client with cid: 1504
# INFO:flwr:Creating client with cid: 1504
# DEBUG flwr 2025-02-15 19:35:42,324 | server_returns_parameters.py:237 | fit_round 12 received 4 results and 0 failures
# DEBUG:flwr:fit_round 12 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:35:42,330 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 212.01it/s]
# INFO flwr 2025-02-15 19:35:42,559 | server_returns_parameters.py:120 | fit progress: (12, 117.11294436454773, {'accuracy': 0.3353333333333333}, 26.391661915928125)
# INFO:flwr:fit progress: (12, 117.11294436454773, {'accuracy': 0.3353333333333333}, 26.391661915928125)
# INFO flwr 2025-02-15 19:35:42,560 | server_returns_parameters.py:171 | evaluate_round 12: no clients selected, cancel
# INFO:flwr:evaluate_round 12: no clients selected, cancel
# INFO flwr 2025-02-15 19:35:42,570 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:35:42,571 | client_manager.py:68 | Sampled the following clients: ['168', '2252', '2386', '1450']
# INFO:flwr:Sampled the following clients: ['168', '2252', '2386', '1450']
# DEBUG flwr 2025-02-15 19:35:42,572 | server_returns_parameters.py:223 | fit_round 13: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 13: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:35:42,573 | client.py:51 | Creating client with cid: 168
# INFO:flwr:Creating client with cid: 168
# INFO flwr 2025-02-15 19:35:42,573 | client.py:51 | Creating client with cid: 2252
# INFO:flwr:Creating client with cid: 2252
# INFO flwr 2025-02-15 19:35:42,573 | client.py:51 | Creating client with cid: 2386
# INFO flwr 2025-02-15 19:35:42,573 | client.py:51 | Creating client with cid: 1450
# INFO:flwr:Creating client with cid: 2386
# INFO:flwr:Creating client with cid: 1450
# DEBUG flwr 2025-02-15 19:35:44,292 | server_returns_parameters.py:237 | fit_round 13 received 4 results and 0 failures
# DEBUG:flwr:fit_round 13 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:35:44,298 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 202.71it/s]
# INFO flwr 2025-02-15 19:35:44,537 | server_returns_parameters.py:120 | fit progress: (13, 111.00401151180267, {'accuracy': 0.36333333333333334}, 28.369080832926556)
# INFO:flwr:fit progress: (13, 111.00401151180267, {'accuracy': 0.36333333333333334}, 28.369080832926556)
# INFO flwr 2025-02-15 19:35:44,537 | server_returns_parameters.py:171 | evaluate_round 13: no clients selected, cancel
# INFO:flwr:evaluate_round 13: no clients selected, cancel
# INFO flwr 2025-02-15 19:35:44,548 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:35:44,549 | client_manager.py:68 | Sampled the following clients: ['1448', '982', '197', '1521']
# INFO:flwr:Sampled the following clients: ['1448', '982', '197', '1521']
# DEBUG flwr 2025-02-15 19:35:44,550 | server_returns_parameters.py:223 | fit_round 14: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 14: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:35:44,550 | client.py:51 | Creating client with cid: 1448
# INFO:flwr:Creating client with cid: 1448
# INFO flwr 2025-02-15 19:35:44,550 | client.py:51 | Creating client with cid: 982
# INFO:flwr:Creating client with cid: 982
# INFO flwr 2025-02-15 19:35:44,551 | client.py:51 | Creating client with cid: 197
# INFO:flwr:Creating client with cid: 197
# INFO flwr 2025-02-15 19:35:44,552 | client.py:51 | Creating client with cid: 1521
# INFO:flwr:Creating client with cid: 1521
# DEBUG flwr 2025-02-15 19:35:46,206 | server_returns_parameters.py:237 | fit_round 14 received 4 results and 0 failures
# DEBUG:flwr:fit_round 14 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:35:46,213 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 203.51it/s]
# INFO flwr 2025-02-15 19:35:46,455 | server_returns_parameters.py:120 | fit progress: (14, 107.53268754482269, {'accuracy': 0.39}, 30.28723795793485)
# INFO:flwr:fit progress: (14, 107.53268754482269, {'accuracy': 0.39}, 30.28723795793485)
# INFO flwr 2025-02-15 19:35:46,456 | server_returns_parameters.py:171 | evaluate_round 14: no clients selected, cancel
# INFO:flwr:evaluate_round 14: no clients selected, cancel
# INFO flwr 2025-02-15 19:35:46,468 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:35:46,468 | client_manager.py:68 | Sampled the following clients: ['1853', '3134', '2351', '1628']
# INFO:flwr:Sampled the following clients: ['1853', '3134', '2351', '1628']
# DEBUG flwr 2025-02-15 19:35:46,469 | server_returns_parameters.py:223 | fit_round 15: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 15: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:35:46,469 | client.py:51 | Creating client with cid: 1853
# INFO:flwr:Creating client with cid: 1853
# INFO flwr 2025-02-15 19:35:46,470 | client.py:51 | Creating client with cid: 3134
# INFO:flwr:Creating client with cid: 3134
# INFO flwr 2025-02-15 19:35:46,471 | client.py:51 | Creating client with cid: 2351
# INFO:flwr:Creating client with cid: 2351
# INFO flwr 2025-02-15 19:35:46,471 | client.py:51 | Creating client with cid: 1628
# INFO:flwr:Creating client with cid: 1628
# DEBUG flwr 2025-02-15 19:35:48,040 | server_returns_parameters.py:237 | fit_round 15 received 4 results and 0 failures
# DEBUG:flwr:fit_round 15 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:35:48,045 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 204.60it/s]
# INFO flwr 2025-02-15 19:35:48,283 | server_returns_parameters.py:120 | fit progress: (15, 104.10664987564087, {'accuracy': 0.4226666666666667}, 32.11515033291653)
# INFO:flwr:fit progress: (15, 104.10664987564087, {'accuracy': 0.4226666666666667}, 32.11515033291653)
# INFO flwr 2025-02-15 19:35:48,283 | server_returns_parameters.py:171 | evaluate_round 15: no clients selected, cancel
# INFO:flwr:evaluate_round 15: no clients selected, cancel
# INFO flwr 2025-02-15 19:35:48,297 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:35:48,298 | client_manager.py:68 | Sampled the following clients: ['2945', '2689', '2753', '1003']
# INFO:flwr:Sampled the following clients: ['2945', '2689', '2753', '1003']
# DEBUG flwr 2025-02-15 19:35:48,298 | server_returns_parameters.py:223 | fit_round 16: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 16: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:35:48,299 | client.py:51 | Creating client with cid: 2945
# INFO:flwr:Creating client with cid: 2945
# INFO flwr 2025-02-15 19:35:48,300 | client.py:51 | Creating client with cid: 2689
# INFO:flwr:Creating client with cid: 2689
# INFO flwr 2025-02-15 19:35:48,300 | client.py:51 | Creating client with cid: 2753
# INFO:flwr:Creating client with cid: 2753
# INFO flwr 2025-02-15 19:35:48,301 | client.py:51 | Creating client with cid: 1003
# INFO:flwr:Creating client with cid: 1003
# DEBUG flwr 2025-02-15 19:35:49,891 | server_returns_parameters.py:237 | fit_round 16 received 4 results and 0 failures
# DEBUG:flwr:fit_round 16 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:35:49,897 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 204.72it/s]
# INFO flwr 2025-02-15 19:35:50,134 | server_returns_parameters.py:120 | fit progress: (16, 102.59247124195099, {'accuracy': 0.44733333333333336}, 33.96595816593617)
# INFO:flwr:fit progress: (16, 102.59247124195099, {'accuracy': 0.44733333333333336}, 33.96595816593617)
# INFO flwr 2025-02-15 19:35:50,134 | server_returns_parameters.py:171 | evaluate_round 16: no clients selected, cancel
# INFO:flwr:evaluate_round 16: no clients selected, cancel
# INFO flwr 2025-02-15 19:35:50,148 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:35:50,149 | client_manager.py:68 | Sampled the following clients: ['770', '2852', '1893', '292']
# INFO:flwr:Sampled the following clients: ['770', '2852', '1893', '292']
# DEBUG flwr 2025-02-15 19:35:50,149 | server_returns_parameters.py:223 | fit_round 17: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 17: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:35:50,150 | client.py:51 | Creating client with cid: 770
# INFO:flwr:Creating client with cid: 770
# INFO flwr 2025-02-15 19:35:50,150 | client.py:51 | Creating client with cid: 2852
# INFO:flwr:Creating client with cid: 2852
# INFO flwr 2025-02-15 19:35:50,151 | client.py:51 | Creating client with cid: 1893
# INFO:flwr:Creating client with cid: 1893
# INFO flwr 2025-02-15 19:35:50,151 | client.py:51 | Creating client with cid: 292
# INFO:flwr:Creating client with cid: 292
# DEBUG flwr 2025-02-15 19:35:52,317 | server_returns_parameters.py:237 | fit_round 17 received 4 results and 0 failures
# DEBUG:flwr:fit_round 17 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:35:52,323 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 198.34it/s]
# INFO flwr 2025-02-15 19:35:52,568 | server_returns_parameters.py:120 | fit progress: (17, 102.0075454711914, {'accuracy': 0.4666666666666667}, 36.40000324998982)
# INFO:flwr:fit progress: (17, 102.0075454711914, {'accuracy': 0.4666666666666667}, 36.40000324998982)
# INFO flwr 2025-02-15 19:35:52,568 | server_returns_parameters.py:171 | evaluate_round 17: no clients selected, cancel
# INFO:flwr:evaluate_round 17: no clients selected, cancel
# INFO flwr 2025-02-15 19:35:52,583 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:35:52,584 | client_manager.py:68 | Sampled the following clients: ['714', '890', '1184', '1557']
# INFO:flwr:Sampled the following clients: ['714', '890', '1184', '1557']
# DEBUG flwr 2025-02-15 19:35:52,584 | server_returns_parameters.py:223 | fit_round 18: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 18: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:35:52,585 | client.py:51 | Creating client with cid: 714
# INFO:flwr:Creating client with cid: 714
# INFO flwr 2025-02-15 19:35:52,585 | client.py:51 | Creating client with cid: 890
# INFO:flwr:Creating client with cid: 890
# INFO flwr 2025-02-15 19:35:52,586 | client.py:51 | Creating client with cid: 1184
# INFO:flwr:Creating client with cid: 1184
# INFO flwr 2025-02-15 19:35:52,586 | client.py:51 | Creating client with cid: 1557
# INFO:flwr:Creating client with cid: 1557
# DEBUG flwr 2025-02-15 19:35:54,455 | server_returns_parameters.py:237 | fit_round 18 received 4 results and 0 failures
# DEBUG:flwr:fit_round 18 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:35:54,460 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 205.20it/s]
# INFO flwr 2025-02-15 19:35:54,698 | server_returns_parameters.py:120 | fit progress: (18, 97.80700147151947, {'accuracy': 0.476}, 38.52990549989045)
# INFO:flwr:fit progress: (18, 97.80700147151947, {'accuracy': 0.476}, 38.52990549989045)
# INFO flwr 2025-02-15 19:35:54,698 | server_returns_parameters.py:171 | evaluate_round 18: no clients selected, cancel
# INFO:flwr:evaluate_round 18: no clients selected, cancel
# INFO flwr 2025-02-15 19:35:54,714 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:35:54,715 | client_manager.py:68 | Sampled the following clients: ['723', '1096', '2064', '2940']
# INFO:flwr:Sampled the following clients: ['723', '1096', '2064', '2940']
# DEBUG flwr 2025-02-15 19:35:54,715 | server_returns_parameters.py:223 | fit_round 19: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 19: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:35:54,716 | client.py:51 | Creating client with cid: 723
# INFO:flwr:Creating client with cid: 723
# INFO flwr 2025-02-15 19:35:54,717 | client.py:51 | Creating client with cid: 1096
# INFO:flwr:Creating client with cid: 1096
# INFO flwr 2025-02-15 19:35:54,717 | client.py:51 | Creating client with cid: 2064
# INFO:flwr:Creating client with cid: 2064
# INFO flwr 2025-02-15 19:35:54,718 | client.py:51 | Creating client with cid: 2940
# INFO:flwr:Creating client with cid: 2940
# DEBUG flwr 2025-02-15 19:35:56,568 | server_returns_parameters.py:237 | fit_round 19 received 4 results and 0 failures
# DEBUG:flwr:fit_round 19 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:35:56,573 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 202.84it/s]
# INFO flwr 2025-02-15 19:35:56,815 | server_returns_parameters.py:120 | fit progress: (19, 95.35901427268982, {'accuracy': 0.49333333333333335}, 40.64671591599472)
# INFO:flwr:fit progress: (19, 95.35901427268982, {'accuracy': 0.49333333333333335}, 40.64671591599472)
# INFO flwr 2025-02-15 19:35:56,815 | server_returns_parameters.py:171 | evaluate_round 19: no clients selected, cancel
# INFO:flwr:evaluate_round 19: no clients selected, cancel
# INFO flwr 2025-02-15 19:35:56,832 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:35:56,833 | client_manager.py:68 | Sampled the following clients: ['1489', '2656', '994', '2742']
# INFO:flwr:Sampled the following clients: ['1489', '2656', '994', '2742']
# DEBUG flwr 2025-02-15 19:35:56,833 | server_returns_parameters.py:223 | fit_round 20: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 20: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:35:56,834 | client.py:51 | Creating client with cid: 1489
# INFO:flwr:Creating client with cid: 1489
# INFO flwr 2025-02-15 19:35:56,835 | client.py:51 | Creating client with cid: 2656
# INFO:flwr:Creating client with cid: 2656
# INFO flwr 2025-02-15 19:35:56,835 | client.py:51 | Creating client with cid: 994
# INFO:flwr:Creating client with cid: 994
# INFO flwr 2025-02-15 19:35:56,836 | client.py:51 | Creating client with cid: 2742
# INFO:flwr:Creating client with cid: 2742
# DEBUG flwr 2025-02-15 19:35:58,652 | server_returns_parameters.py:237 | fit_round 20 received 4 results and 0 failures
# DEBUG:flwr:fit_round 20 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:35:58,658 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 191.75it/s]
# INFO flwr 2025-02-15 19:35:58,911 | server_returns_parameters.py:120 | fit progress: (20, 95.43832576274872, {'accuracy': 0.5153333333333333}, 42.743238832917996)
# INFO:flwr:fit progress: (20, 95.43832576274872, {'accuracy': 0.5153333333333333}, 42.743238832917996)
# INFO flwr 2025-02-15 19:35:58,912 | server_returns_parameters.py:171 | evaluate_round 20: no clients selected, cancel
# INFO:flwr:evaluate_round 20: no clients selected, cancel
# INFO flwr 2025-02-15 19:35:58,928 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:35:58,929 | client_manager.py:68 | Sampled the following clients: ['764', '1484', '2389', '1480']
# INFO:flwr:Sampled the following clients: ['764', '1484', '2389', '1480']
# DEBUG flwr 2025-02-15 19:35:58,930 | server_returns_parameters.py:223 | fit_round 21: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 21: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:35:58,931 | client.py:51 | Creating client with cid: 764
# INFO:flwr:Creating client with cid: 764
# INFO flwr 2025-02-15 19:35:58,932 | client.py:51 | Creating client with cid: 1484
# INFO:flwr:Creating client with cid: 1484
# INFO flwr 2025-02-15 19:35:58,932 | client.py:51 | Creating client with cid: 2389
# INFO:flwr:Creating client with cid: 2389
# INFO flwr 2025-02-15 19:35:58,932 | client.py:51 | Creating client with cid: 1480
# INFO:flwr:Creating client with cid: 1480
# DEBUG flwr 2025-02-15 19:36:00,867 | server_returns_parameters.py:237 | fit_round 21 received 4 results and 0 failures
# DEBUG:flwr:fit_round 21 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:36:00,872 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 207.23it/s]
# INFO flwr 2025-02-15 19:36:01,108 | server_returns_parameters.py:120 | fit progress: (21, 92.39303648471832, {'accuracy': 0.536}, 44.93992716597859)
# INFO:flwr:fit progress: (21, 92.39303648471832, {'accuracy': 0.536}, 44.93992716597859)
# INFO flwr 2025-02-15 19:36:01,108 | server_returns_parameters.py:171 | evaluate_round 21: no clients selected, cancel
# INFO:flwr:evaluate_round 21: no clients selected, cancel
# INFO flwr 2025-02-15 19:36:01,125 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:36:01,126 | client_manager.py:68 | Sampled the following clients: ['2956', '1486', '3184', '2464']
# INFO:flwr:Sampled the following clients: ['2956', '1486', '3184', '2464']
# DEBUG flwr 2025-02-15 19:36:01,127 | server_returns_parameters.py:223 | fit_round 22: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 22: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:36:01,128 | client.py:51 | Creating client with cid: 2956
# INFO:flwr:Creating client with cid: 2956
# INFO flwr 2025-02-15 19:36:01,128 | client.py:51 | Creating client with cid: 1486
# INFO:flwr:Creating client with cid: 1486
# INFO flwr 2025-02-15 19:36:01,128 | client.py:51 | Creating client with cid: 3184
# INFO:flwr:Creating client with cid: 3184
# INFO flwr 2025-02-15 19:36:01,129 | client.py:51 | Creating client with cid: 2464
# INFO:flwr:Creating client with cid: 2464
# DEBUG flwr 2025-02-15 19:36:02,601 | server_returns_parameters.py:237 | fit_round 22 received 4 results and 0 failures
# DEBUG:flwr:fit_round 22 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:36:02,607 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 204.58it/s]
# INFO flwr 2025-02-15 19:36:02,845 | server_returns_parameters.py:120 | fit progress: (22, 90.43542528152466, {'accuracy': 0.5426666666666666}, 46.67710074991919)
# INFO:flwr:fit progress: (22, 90.43542528152466, {'accuracy': 0.5426666666666666}, 46.67710074991919)
# INFO flwr 2025-02-15 19:36:02,845 | server_returns_parameters.py:171 | evaluate_round 22: no clients selected, cancel
# INFO:flwr:evaluate_round 22: no clients selected, cancel
# INFO flwr 2025-02-15 19:36:02,865 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:36:02,865 | client_manager.py:68 | Sampled the following clients: ['1306', '0', '2651', '2426']
# INFO:flwr:Sampled the following clients: ['1306', '0', '2651', '2426']
# DEBUG flwr 2025-02-15 19:36:02,866 | server_returns_parameters.py:223 | fit_round 23: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 23: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:36:02,867 | client.py:51 | Creating client with cid: 1306
# INFO:flwr:Creating client with cid: 1306
# INFO flwr 2025-02-15 19:36:02,868 | client.py:51 | Creating client with cid: 0
# INFO:flwr:Creating client with cid: 0
# INFO flwr 2025-02-15 19:36:02,868 | client.py:51 | Creating client with cid: 2651
# INFO:flwr:Creating client with cid: 2651
# INFO flwr 2025-02-15 19:36:02,869 | client.py:51 | Creating client with cid: 2426
# INFO:flwr:Creating client with cid: 2426
# DEBUG flwr 2025-02-15 19:36:04,643 | server_returns_parameters.py:237 | fit_round 23 received 4 results and 0 failures
# DEBUG:flwr:fit_round 23 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:36:04,649 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 190.25it/s]
# INFO flwr 2025-02-15 19:36:04,904 | server_returns_parameters.py:120 | fit progress: (23, 91.7383964061737, {'accuracy': 0.5553333333333333}, 48.73660087492317)
# INFO:flwr:fit progress: (23, 91.7383964061737, {'accuracy': 0.5553333333333333}, 48.73660087492317)
# INFO flwr 2025-02-15 19:36:04,905 | server_returns_parameters.py:171 | evaluate_round 23: no clients selected, cancel
# INFO:flwr:evaluate_round 23: no clients selected, cancel
# INFO flwr 2025-02-15 19:36:04,923 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:36:04,924 | client_manager.py:68 | Sampled the following clients: ['1721', '2204', '3192', '1258']
# INFO:flwr:Sampled the following clients: ['1721', '2204', '3192', '1258']
# DEBUG flwr 2025-02-15 19:36:04,925 | server_returns_parameters.py:223 | fit_round 24: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 24: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:36:04,926 | client.py:51 | Creating client with cid: 1721
# INFO:flwr:Creating client with cid: 1721
# INFO flwr 2025-02-15 19:36:04,926 | client.py:51 | Creating client with cid: 2204
# INFO:flwr:Creating client with cid: 2204
# INFO flwr 2025-02-15 19:36:04,926 | client.py:51 | Creating client with cid: 3192
# INFO:flwr:Creating client with cid: 3192
# INFO flwr 2025-02-15 19:36:04,926 | client.py:51 | Creating client with cid: 1258
# INFO:flwr:Creating client with cid: 1258
# DEBUG flwr 2025-02-15 19:36:06,616 | server_returns_parameters.py:237 | fit_round 24 received 4 results and 0 failures
# DEBUG:flwr:fit_round 24 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:36:06,622 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 202.53it/s]
# INFO flwr 2025-02-15 19:36:06,862 | server_returns_parameters.py:120 | fit progress: (24, 93.7953269481659, {'accuracy': 0.56}, 50.6940387499053)
# INFO:flwr:fit progress: (24, 93.7953269481659, {'accuracy': 0.56}, 50.6940387499053)
# INFO flwr 2025-02-15 19:36:06,862 | server_returns_parameters.py:171 | evaluate_round 24: no clients selected, cancel
# INFO:flwr:evaluate_round 24: no clients selected, cancel
# INFO flwr 2025-02-15 19:36:06,883 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:36:06,884 | client_manager.py:68 | Sampled the following clients: ['2176', '1230', '1374', '1154']
# INFO:flwr:Sampled the following clients: ['2176', '1230', '1374', '1154']
# DEBUG flwr 2025-02-15 19:36:06,885 | server_returns_parameters.py:223 | fit_round 25: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 25: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:36:06,886 | client.py:51 | Creating client with cid: 2176
# INFO:flwr:Creating client with cid: 2176
# INFO flwr 2025-02-15 19:36:06,887 | client.py:51 | Creating client with cid: 1230
# INFO:flwr:Creating client with cid: 1230
# INFO flwr 2025-02-15 19:36:06,888 | client.py:51 | Creating client with cid: 1374
# INFO:flwr:Creating client with cid: 1374
# INFO flwr 2025-02-15 19:36:06,888 | client.py:51 | Creating client with cid: 1154
# INFO:flwr:Creating client with cid: 1154
# DEBUG flwr 2025-02-15 19:36:08,759 | server_returns_parameters.py:237 | fit_round 25 received 4 results and 0 failures
# DEBUG:flwr:fit_round 25 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:36:08,764 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 190.28it/s]
# INFO flwr 2025-02-15 19:36:09,020 | server_returns_parameters.py:120 | fit progress: (25, 92.6493330001831, {'accuracy': 0.56}, 52.85210525000002)
# INFO:flwr:fit progress: (25, 92.6493330001831, {'accuracy': 0.56}, 52.85210525000002)
# INFO flwr 2025-02-15 19:36:09,021 | server_returns_parameters.py:171 | evaluate_round 25: no clients selected, cancel
# INFO:flwr:evaluate_round 25: no clients selected, cancel
# INFO flwr 2025-02-15 19:36:09,041 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19:36:09,041 | client_manager.py:68 | Sampled the following clients: ['1924', '3035', '2189', '1444']
# INFO:flwr:Sampled the following clients: ['1924', '3035', '2189', '1444']
# DEBUG flwr 2025-02-15 19:36:09,042 | server_returns_parameters.py:223 | fit_round 26: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 26: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 19:36:09,043 | client.py:51 | Creating client with cid: 1924
# INFO:flwr:Creating client with cid: 1924
# INFO flwr 2025-02-15 19:36:09,044 | client.py:51 | Creating client with cid: 3035
# INFO:flwr:Creating client with cid: 3035
# INFO flwr 2025-02-15 19:36:09,044 | client.py:51 | Creating client with cid: 2189
# INFO:flwr:Creating client with cid: 2189
# INFO flwr 2025-02-15 19:36:09,045 | client.py:51 | Creating client with cid: 1444
# INFO:flwr:Creating client with cid: 1444
# DEBUG flwr 2025-02-15 19:36:10,518 | server_returns_parameters.py:237 | fit_round 26 received 4 results and 0 failures
# DEBUG:flwr:fit_round 26 received 4 results and 0 failures
# INFO flwr 2025-02-15 19:36:10,524 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 194.88it/s]
# INFO flwr 2025-02-15 19:36:10,774 | server_returns_parameters.py:120 | fit progress: (26, 84.55301344394684, {'accuracy': 0.6}, 54.605887207901105)
# INFO:flwr:fit progress: (26, 84.55301344394684, {'accuracy': 0.6}, 54.605887207901105)
# INFO flwr 2025-02-15 19:36:10,774 | server_returns_parameters.py:171 | evaluate_round 26: no clients selected, cancel
# INFO:flwr:evaluate_round 26: no clients selected, cancel
# INFO flwr 2025-02-15 19:36:10,796 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 19
# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(13, 7))


for clip, clip_result in exp_3_results.items():
    parameters, hist = clip_result
    clip_round_accuracies = [accuracy for _, accuracy in hist.metrics_centralized["accuracy"]]
    plt.plot(clip_round_accuracies, label=f"Accuracy of clip: {clip}")


plt.xlabel("Round number")
plt.ylabel("Model Accuracy")
plt.title("Model accuracy for different clip norms")
plt.legend()
plt.show()

# %% [markdown]
# **Written Answer:**
#
# From the plots above we can see that the model that was trained using clipping norm $\mu$ * 0.25 ($\approx$ 2.5) takes the longest to converge. This is caused by the fact that the model updates are being clipped frequently resulting in smaller changes/ improvements in the model. On the other hand, when we look at the models with the clipping norm $\mu$ ($\approx$ 10) and $\mu$ * 1.75 ($\approx$ 17.6) we can see a similar trend and convergence ($\mu$ * 1.75 being slightly better) which can be explained by the fact that if the mean unclipped L2 norms is $\mu$ then the model with the clipping norm $\mu$ * 1.75 will clip above the mean value which happens less frequently. Additionally, this larger bound allows larger updates which cause the higher magnitude of changes/fluctuations than the $\mu$ model but also . Additionally, the $\mu$ * 1.75 model achieves the best accuracy, which could be a cause of the less bounded updates. Interestingly all three models converge to a similar/close accuracy which might be caused by the fact the $\mu$ * 0.25 applies smaller but more "stable" resulting in less fluctuations over time.
#
# ---

# %% [markdown]
# ---

# %% [markdown]
# **Question 4 (Part II ✅ | Part III/MPhil ✅):**
#
# (You must provide the answer with **code** and **plots** for this question. A short written argumentation is recommended.)
#
# This question extends the one above to investigate the effect that the `clip_norm` has upon the norm of the federated model update. The federated model update is defined as the difference between the model at the start of the round and the model post-aggregation.
#
# 1. Using the results from the above question, plot the following:
#
#    - The L2 norm of the federated model deltas across rounds for the three bounds above. How does L2 norm of the federated model delta compare to `clip_norm` (draw a horizontal line for all three bounds)? Is the behaviour as you expected, and why/why not?
#    - The accuracy on the federated test set of models trained using the three norms above against the cumulative L2 norm accumulated across rounds as the axis. Consider the accuracy of the initial parameter test (round 0) to map to an L2 norm of 0. By cumulative L2, we mean a running sum where you keep adding the new norm value to the sum and then add the sum to a per-round list. Such a sum can easily be computed from a list using a `accumulate()` call.
#
# 2. How do the L2 norms of the federated model deltas compare against the change in accuracy between rounds? Is the relationship predictable and/or linear? Consider all the `clip_norm` values you have tried in your response and provide potential explanations for why/why not the relationship between accuracy and cumulative L2 changes between bounds.

# %% [markdown]
# ---
#
# **Question 4 Answer:**
#
# Part 1:

# %%
import itertools
for clip_val, clip_result in exp_3_results.items():
    parameters, hist = clip_result

    
    prior_clip_norms = [ np.mean([ value for _, value in norm_prior_clip["all"]]) for round, norm_prior_clip in hist.metrics_distributed_fit["norm_prior_clip"]]

    plt.figure(figsize=(13, 7))
    plt.plot(prior_clip_norms, label="Norm prior to clip")
    plt.axhline(y=clip_val, color='r', linestyle='-', label="Clip value")
    plt.xlabel("Round number")
    plt.ylabel("Norm value")
    plt.title(f"Norm prior to clipping for clip value {clip_val}")
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
plt.figure(figsize=(13, 7))
for clip_val, clip_result in exp_3_results.items():
    parameters, hist = clip_result

    prior_clip_norms = [ np.mean([ value for _, value in norm_prior_clip["all"]]) for round, norm_prior_clip in hist.metrics_distributed_fit["norm_prior_clip"]]
    prior_clip_norms.insert(0,0)
    cumulative_norm = list(itertools.accumulate(prior_clip_norms))
    accuracies = [accuracy for _, accuracy in hist.metrics_centralized["accuracy"]]

    plt.plot(cumulative_norm,accuracies, label=f"Clip value {clip_val}")

plt.xlabel("Cummulative L2 Norm")
plt.ylabel("Model Test Accuracy")
plt.title(f"Model Test Accuracy Against Cummulative Norm Over Rounds")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Written Answer:**
# Regarding the models with with the clip norm $\mu$ * 0.25 and $\mu$ * 1.75 the results were somewhat expected. The L2 norm of model updates for the model with the clip norm of $\mu$ * 0.25 are all above the set clip norm line resulting in all of them being clipped meanwhile the opposite happens to the model with the clip norm of $\mu$ * 1.75 where the updates reside below the set clip norm hence not being clipped. However, the model with the clip norm of $\mu$ present a rather surprising result to what I was expecting. Contrary to expected most updates of the $\mu$ model are above the set clip norm line resulting in them being clipped rather than around half of them being clipped. This could be explained by the fact that we set the clip norm based on the mean of only a single round of training. Since magnitudes of updates change across rounds using a single round to determine the clip norm might not be ideal approach.

# %% [markdown]
# Part 2:
#
# **Written Answer:**
#
# As we can see on the graph there is no predictable relationship between the L2 norm of the federated model deltas and the change in acc
#
#
#
# ---

# %% [markdown]
# ## 3.2 Adaptive Norm Bound DP

# %% [markdown]
# Having investigated the impact of gradient clipping with a fixed norm on performance, you may wonder if your chosen norm will stay appropriate for the entire training.
#
# To avoid perfectly tuning a fixed `clip_norm` an [adaptive version of DPFedAvg](https://arxiv.org/abs/1905.03871) was proposed in paper \[3], which attempts to automatically scale the bound on the L2 norm of model updates based on a quantile of L2 norms provided by clients in a given round. As computing such a value would be computationally expensive and require clients to send private values, the paper proposes an algorithm meant to approximate the quantile.
#
# Specifically, it adjusts the `clip_norm` parameter as:
#
# >     self.clip_norm *= math.exp(-self.clip_norm_lr
#
#             * (noised_clients_with_clipped_norm_fraction - self.clip_norm_target_quantile)
#         )
#
# where the new clip norm depends on a learning rate, the fraction of clients used in training who have clipped their norms (with added noise), and the target quantile. In the code below, the clients who have clipped their norm are reported via a set bit in the config, and thus `noised_clients_with_clipped_norm_fraction` is replaced with `noised_norm_bit_set_fraction`. By knowing approximately how many clients fall below a given norm, we can iteratively improve the `clip_norm` until the percentage of clients with norms smaller than the bound is reached.
#
# The new implementation is hard to use and balance for short experiments such as ours as it includes an initial phase where the norm grows exponentially in its attempts to converge to the actual quantile. Given that we do not want any further interference making the behaviour of DP harder to predict, this would prove inconvenient when trying to deduce the impact of noise. As such, we shall only track the behaviour of the adaptive norm and use the predictable `DPFedAvgFixed` when experimenting with obtaining a given level of $\epsilon$ privacy.

# %%
"""DP-FedAvg [Andrew et al., 2019] with adaptive clipping.
Paper: https://arxiv.org/pdf/1905.03871.pdf
"""

# Original implementation by Vasundhara Agarwal


class DPFedAvgAdaptive(DPFedAvgFixed):
    """Server-side adaptive clipping for DP-FedAvg."""

    # pylint: disable=too-many-arguments,too-many-instance-attributes
    def __init__(
        self,
        *,
        fraction_fit: float = 1.0,
        fraction_evaluate: float = 1.0,
        min_fit_clients: int = 2,
        min_evaluate_clients: int = 2,
        min_available_clients: int = 2,
        evaluate_fn: (
            Callable[
                [int, NDArrays, dict[str, Scalar]],
                tuple[float, dict[str, Scalar]] | None,
            ]
            | None
        ) = None,
        on_fit_config_fn: Callable[[int], dict[str, Scalar]] | None = None,
        on_evaluate_config_fn: Callable[[int], dict[str, Scalar]] | None = None,
        accept_failures: bool = False,
        initial_parameters: Parameters | None = None,
        fit_metrics_aggregation_fn: MetricsAggregationFn | None = None,
        evaluate_metrics_aggregation_fn: MetricsAggregationFn | None = None,
        server_learning_rate: float = 1.0,
        server_momentum: float = 0.0,
        num_clients_per_round: int,
        init_clip_norm: float = 0.1,
        noise_multiplier: float = 1,
        server_side_noising: bool = True,
        clip_norm_lr: float = 0.2,
        clip_norm_target_quantile: float = 0.5,
        clip_count_stddev: float | None = None,
    ) -> None:
        super().__init__(
            fraction_fit=fraction_fit,
            fraction_evaluate=fraction_evaluate,
            min_fit_clients=min_fit_clients,
            min_evaluate_clients=min_evaluate_clients,
            min_available_clients=min_available_clients,
            evaluate_fn=evaluate_fn,
            on_fit_config_fn=on_fit_config_fn,
            on_evaluate_config_fn=on_evaluate_config_fn,
            accept_failures=accept_failures,
            initial_parameters=initial_parameters,
            fit_metrics_aggregation_fn=fit_metrics_aggregation_fn,
            evaluate_metrics_aggregation_fn=evaluate_metrics_aggregation_fn,
            server_learning_rate=server_learning_rate,
            server_momentum=server_momentum,
            num_clients_per_round=num_clients_per_round,
            clip_norm=init_clip_norm,
            noise_multiplier=noise_multiplier,
            server_side_noising=server_side_noising,
        )
        self.clip_norm_lr = clip_norm_lr
        self.clip_norm_target_quantile = clip_norm_target_quantile
        self.clip_count_stddev = clip_count_stddev

        # Decides the level of noise added to the fraction of clients which have clipped
        # their norms
        if self.clip_count_stddev is None:
            self.clip_count_stddev = 0
            if noise_multiplier > 0:
                self.clip_count_stddev = self.num_clients_per_round / 20.0

        if noise_multiplier:
            self.noise_multiplier = (
                self.noise_multiplier ** (-2) - (2 * self.clip_count_stddev) ** (-2)
            ) ** (-0.5)

    def configure_fit(
        self, server_round: int, parameters: Parameters, client_manager: ClientManager
    ) -> list[tuple[ClientProxy, FitIns]]:
        """Configure the next round of training."""
        additional_config = {"dpfedavg_adaptive_clip_enabled": True}

        client_instructions = super().configure_fit(
            server_round, parameters, client_manager
        )

        for _, fit_ins in client_instructions:
            fit_ins.config.update(additional_config)

        return client_instructions

    def _update_clip_norm(self, results: list[tuple[ClientProxy, FitRes]]) -> None:
        """Update the clipping norm based on the fraction of clients which clipped."""
        # Calculating number of clients which set the norm indicator bit
        norm_bit_set_count = 0
        for client_proxy, fit_res in results:
            if "dpfedavg_norm_bit" not in fit_res.metrics:
                raise DPClientNormBitError(
                    f"Indicator bit not returned by client with id {client_proxy.cid}."
                )

            if fit_res.metrics["dpfedavg_norm_bit"]:
                norm_bit_set_count += 1
        # Noising the count
        noised_norm_bit_set_count = float(
            np.random.normal(norm_bit_set_count, self.clip_count_stddev)
        )

        noised_norm_bit_set_fraction = noised_norm_bit_set_count / len(results)
        # Geometric update
        self.clip_norm *= math.exp(
            -self.clip_norm_lr
            * (noised_norm_bit_set_fraction - self.clip_norm_target_quantile)
        )

    def aggregate_fit(
        self,
        server_round: int,
        results: list[tuple[ClientProxy, FitRes]],
        failures: list[tuple[ClientProxy, FitRes] | BaseException],
    ) -> tuple[Parameters | None, dict[str, Scalar]]:
        """Aggregate the results of the training round."""
        if not self.accept_failures and failures:
            return None, {}
        new_global_model, metrics = super().aggregate_fit(
            server_round, results, failures
        )
        self._update_clip_norm(results)
        metrics["adaptive_clip_norm"] = self.clip_norm
        return new_global_model, metrics

# %%
# New function to run the adaptive norm experiments with sensible defaults

dp_client_generator = get_dp_client_generator(
    network_generator_cnn,
    data_dir,
    federated_partition,
    lambda x: client_samples_dataframe.cid[x],
)


adaptive_default_parameters: dict = {
    "train_config": get_default_train_config(),
    "test_config": get_default_test_config(),
    "num_total_clients": num_total_clients,
    "num_clients_per_round": 4,
    "num_evaluate_clients": 0,
    "num_evaluate": 0,
    "accept_failures": False,
    "min_fit_clients": 2,
    "min_available_clients": 2,
    "initial_parameters": ndarrays_to_parameters(seed_model_cnn_params),
    "client_generator": dp_client_generator,
    "seed": Seeds.DEFAULT,
    "num_rounds": 30,
    "strategy": DPFedAvgAdaptive,
    "fed_eval": True,
    "server_side_noising": True,
    "clip_count_stddev": None,
}


def run_dp_adaptive_fl(
    noise_multiplier: float = 0,
    init_clip_norm: float = 2,
    clip_norm_lr: float = 0.2,
    clip_norm_target_quantile: float = 0.5,
    default_parameters: dict = adaptive_default_parameters,
    **kwargs: dict[str, Any],
) -> Any:
    """Execute a DP-FedAvg simulation with adaptive clipping."""
    parameters: dict = {**default_parameters, **kwargs}

    def on_fit_config_fn(cid: int) -> dict[str, Scalar]:
        return parameters["train_config"]

    def on_evaluate_config_fn(cid: int) -> dict[str, Scalar]:
        return parameters["test_config"]

    fraction_fit: float = (
        float(parameters["num_clients_per_round"]) / parameters["num_total_clients"]
    )
    fraction_evaluate: float = (
        float(parameters["num_evaluate_clients"]) / parameters["num_total_clients"]
    )

    strategy = parameters["strategy"](
        num_clients_per_round=parameters["num_clients_per_round"],
        fraction_fit=fraction_fit,
        fraction_evaluate=fraction_evaluate,
        min_fit_clients=parameters["min_fit_clients"],
        min_available_clients=parameters["min_available_clients"],
        on_fit_config_fn=on_fit_config_fn,
        on_evaluate_config_fn=on_evaluate_config_fn,
        initial_parameters=parameters["initial_parameters"],
        accept_failures=parameters["accept_failures"],
        evaluate_fn=(
            federated_evaluation_function if parameters["fed_eval"] is True else None
        ),
        fit_metrics_aggregation_fn=aggregate_weighted_average,
        evaluate_metrics_aggregation_fn=aggregate_weighted_average,
        init_clip_norm=init_clip_norm,
        clip_norm_lr=clip_norm_lr,
        clip_norm_target_quantile=clip_norm_target_quantile,
        noise_multiplier=noise_multiplier,
        server_side_noising=parameters["server_side_noising"],
        clip_count_stddev=parameters["clip_count_stddev"],
    )
    client_manager = CustomClientManager(criterion=None, seed=parameters["seed"])
    server = Server(
        client_manager=client_manager,
        strategy=strategy,
    )
    return start_seeded_simulation(
        client_fn=lambda cid: parameters["client_generator"](cid).to_client(),
        num_clients=parameters["num_total_clients"],
        server=server,
        config=ServerConfig(num_rounds=parameters["num_rounds"]),
        strategy=strategy,
        seed=parameters["seed"],
        name=f"adaptive_target_{clip_norm_target_quantile}_init_clip_norm_{init_clip_norm}_lr_{clip_norm_lr}_noise_{noise_multiplier}",
    )

# %%
parameters_for_every_round, hist_adaptive_quantile_0_5 = run_dp_adaptive_fl(
    clip_norm_target_quantile=0.5, noise_multiplier=0
)
# Out:
# WARNING flwr 2025-02-15 21:58:49,789 | app.py:213 | Both server and strategy were provided, ignoring strategy
# WARNING:flwr:Both server and strategy were provided, ignoring strategy
# INFO flwr 2025-02-15 21:58:49,792 | app.py:149 | Starting Flower simulation, config: ServerConfig(num_rounds=30, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=30, round_timeout=None)
# INFO flwr 2025-02-15 21:58:49,815 | server_returns_parameters.py:81 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 
| app.py:254 | app_fit: metrics_centralized {'accuracy': [(0, 0.004), (1, 0.07933333333333334), (2, 0.07933333333333334), (3, 0.07933333333333334), (4, 0.08866666666666667), (5, 0.07133333333333333), (6, 0.118), (7, 0.218), (8, 0.278), (9, 0.3473333333333333), (10, 0.428), (11, 0.49866666666666665), (12, 0.5006666666666667), (13, 0.512), (14, 0.5213333333333333), (15, 0.56), (16, 0.5846666666666667), (17, 0.598), (18, 0.562), (19, 0.5306666666666666), (20, 0.6246666666666667), (21, 0.646), (22, 0.6586666666666666), (23, 0.6533333333333333), (24, 0.636), (25, 0.6293333333333333), (26, 0.7006666666666667), (27, 0.7326666666666667), (28, 0.6106666666666667), (29, 0.6333333333333333), (30, 0.5833333333333334)]}
# INFO:flwr:app_fit: metrics_centralized {'accuracy': [(0, 0.004), (1, 0.07933333333333334), (2, 0.07933333333333334), (3, 0.07933333333333334), (4, 0.08866666666666667), (5, 0.07133333333333333), (6, 0.118), (7, 0.218), (8, 0.278), (9, 0.3473333333333333), (10, 0.428), (11, 0.49866666666666665), (12, 0.5006666666666667), (13, 0.512), (14, 0.5213333333333333), (15, 0.56), (16, 0.5846666666666667), (17, 0.598), (18, 0.562), (19, 0.5306666666666666), (20, 0.6246666666666667), (21, 0.646), (22, 0.6586666666666666), (23, 0.6533333333333333), (24, 0.636), (25, 0.6293333333333333), (26, 0.7006666666666667), (27, 0.7326666666666667), (28, 0.6106666666666667), (29, 0.6333333333333333), (30, 0.5833333333333334)]}

# %% [markdown]
# Having gone through this slight detour to understand how we could obtain an adaptive bound which leaves the privacy budget mostly undisturbed without experimentation, we shall return to DP's primary goal, matching a given theoretical bound on privacy. However, Part III and MPhil students will now get to play around and observe the behaviour of this adaptive norm algorithm.

# %% [markdown]
# **Question 5 (Part III/MPhil ✅):**
#
# (You need to provide the answer with **code** and **plots** for this question. A short written argumentation is recommended.)
#
# You will now examine the accuracy of adaptive norm clipping compared to the previously fixed norm clipping.
#
# 1. Using values of `clip_norm_target_quantile`$\in \{0.125,\, 0.5, \,0.875\}$ (you should already have results for the default value from the cells above. If you have lost it, look into the `histories` folder). Run `DPFedAvgAdaptive` experiments with the same parameters as the above example using a `noise_multiplier=0`.
# 2. Plot the per-round accuracy on the federated test set of models trained using the three quantile targets above. Which quantile target converges the fastest and to the highest final accuracy, and why do you think that is? Are the results as conclusive as the fixed bound ones? **Hint**: consider the exponential nature of the bound adaptation.
# 3. Do an ordered pairwise comparison between the plots of per-round accuracy of the previous three `clip_norm` results for the fixed norm experiments against the adaptive norm experiments, i.e., plot `clip_norm=mean*0.25` against `clip_norm_target_quantile=0.125`, `clip_norm=mean` against `clip_norm_target_quantile=0.5`, and `clip_norm=mean*1.75` against `clip_norm_target_quantile=0.875`. How does each of the pairs compare? Where are the differences most pronounced, and why do you think that is?

# %% [markdown]
# **Question 5 Answer:**
#
# Part 1:

# %%
clip_norm_target_quantiles = [0.125, 0.5, 0.875]

adaptive_results = {}
for target_quantile in clip_norm_target_quantiles:
    target_quantile_parameters, target_quantile_hist = run_dp_adaptive_fl(clip_norm_target_quantile=target_quantile, noise_multiplier=0)
    adaptive_results[target_quantile] = (target_quantile_parameters, target_quantile_hist)
# Out:
# WARNING flwr 2025-02-15 22:08:12,399 | app.py:213 | Both server and strategy were provided, ignoring strategy
# WARNING:flwr:Both server and strategy were provided, ignoring strategy
# INFO flwr 2025-02-15 22:08:12,411 | app.py:149 | Starting Flower simulation, config: ServerConfig(num_rounds=30, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=30, round_timeout=None)
# INFO flwr 2025-02-15 22:08:12,439 | server_returns_parameters.py:81 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2025-02-15 22:08:12,442 | server_returns_parameters.py:273 | Using initial parameters provided by strategy
# INFO:flwr:Using initial parameters provided by strategy
# INFO flwr 
| strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 189.81it/s]
# INFO flwr 2025-02-15 22:08:19,612 | server_returns_parameters.py:120 | fit progress: (3, 181.20119786262512, {'accuracy': 0.07933333333333334}, 6.166766750044189)
# INFO:flwr:fit progress: (3, 181.20119786262512, {'accuracy': 0.07933333333333334}, 6.166766750044189)
# INFO flwr 2025-02-15 22:08:19,614 | server_returns_parameters.py:171 | evaluate_round 3: no clients selected, cancel
# INFO:flwr:evaluate_round 3: no clients selected, cancel
# INFO flwr 2025-02-15 22:08:19,618 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 22:08:19,619 | client_manager.py:68 | Sampled the following clients: ['2955', '1583', '580', '779']
# INFO:flwr:Sampled the following clients: ['2955', '1583', '580', '779']
# DEBUG flwr 2025-02-15 22:08:19,620 | server_returns_parameters.py:223 | fit_round 4: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 4: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 22:08:19,621 | client.py:51 | Creating client with cid: 2955
# INFO:flwr:Creating client with cid: 2955
# INFO flwr 2025-02-15 22:08:19,621 | client.py:51 | Creating client with cid: 1583
# INFO:flwr:Creating client with cid: 1583
# INFO flwr 2025-02-15 22:08:19,622 | client.py:51 | Creating client with cid: 580
# INFO:flwr:Creating client with cid: 580
# INFO flwr 2025-02-15 22:08:19,622 | client.py:51 | Creating client with cid: 779
# INFO:flwr:Creating client with cid: 779
# DEBUG flwr 2025-02-15 22:08:21,435 | server_returns_parameters.py:237 | fit_round 4 received 4 results and 0 failures
# DEBUG:flwr:fit_round 4 received 4 results and 0 failures
# INFO flwr 2025-02-15 22:08:21,441 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 180.38it/s]
# INFO flwr 2025-02-15 22:08:21,710 | server_returns_parameters.py:120 | fit progress: (4, 176.46190762519836, {'accuracy': 0.07933333333333334}, 8.264611457940191)
# INFO:flwr:fit progress: (4, 176.46190762519836, {'accuracy': 0.07933333333333334}, 8.264611457940191)
# INFO flwr 2025-02-15 22:08:21,711 | server_returns_parameters.py:171 | evaluate_round 4: no clients selected, cancel
# INFO:flwr:evaluate_round 4: no clients selected, cancel
# INFO flwr 2025-02-15 22:08:21,716 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 22:08:21,717 | client_manager.py:68 | Sampled the following clients: ['1656', '1717', '1348', '261']
# INFO:flwr:Sampled the following clients: ['1656', '1717', '1348', '261']
# DEBUG flwr 2025-02-15 22:08:21,717 | server_returns_parameters.py:223 | fit_round 5: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 5: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 22:08:21,719 | client.py:51 | Creating client with cid: 1656
# INFO:flwr:Creating client with cid: 1656
# INFO flwr 2025-02-15 22:08:21,719 | client.py:51 | Creating client with cid: 1717
# INFO:flwr:Creating client with cid: 1717
# INFO flwr 2025-02-15 22:08:21,720 | client.py:51 | Creating client with cid: 1348
# INFO:flwr:Creating client with cid: 1348
# INFO flwr 2025-02-15 22:08:21,720 | client.py:51 | Creating client with cid: 261
# INFO:flwr:Creating client with cid: 261
# DEBUG flwr 2025-02-15 22:08:23,521 | server_returns_parameters.py:237 | fit_round 5 received 4 results and 0 failures
# DEBUG:flwr:fit_round 5 received 4 results and 0 failures
# INFO flwr 2025-02-15 22:08:23,526 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 185.22it/s]
# INFO flwr 2025-02-15 22:08:23,791 | server_returns_parameters.py:120 | fit progress: (5, 170.52861976623535, {'accuracy': 0.07866666666666666}, 10.345778750022873)
# INFO:flwr:fit progress: (5, 170.52861976623535, {'accuracy': 0.07866666666666666}, 10.345778750022873)
# INFO flwr 2025-02-15 22:08:23,792 | server_returns_parameters.py:171 | evaluate_round 5: no clients selected, cancel
# INFO:flwr:evaluate_round 5: no clients selected, cancel
# INFO flwr 2025-02-15 22:08:23,797 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 22:08:23,798 | client_manager.py:68 | Sampled the following clients: ['346', '2627', '2817', '1058']
# INFO:flwr:Sampled the following clients: ['346', '2627', '2817', '1058']
# DEBUG flwr 2025-02-15 22:08:23,799 | server_returns_parameters.py:223 | fit_round 6: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 6: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 22:08:23,800 | client.py:51 | Creating client with cid: 346
# INFO:flwr:Creating client with cid: 346
# INFO flwr 2025-02-15 22:08:23,801 | client.py:51 | Creating client with cid: 2627
# INFO:flwr:Creating client with cid: 2627
# INFO flwr 2025-02-15 22:08:23,801 | client.py:51 | Creating client with cid: 2817
# INFO:flwr:Creating client with cid: 2817
# INFO flwr 2025-02-15 22:08:23,801 | client.py:51 | Creating client with cid: 1058
# INFO:flwr:Creating client with cid: 1058
# DEBUG flwr 2025-02-15 22:08:26,228 | server_returns_parameters.py:237 | fit_round 6 received 4 results and 0 failures
# DEBUG:flwr:fit_round 6 received 4 results and 0 failures
# INFO flwr 2025-02-15 22:08:26,235 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00,
| server_returns_parameters.py:237 | fit_round 9 received 4 results and 0 failures
# DEBUG:flwr:fit_round 9 received 4 results and 0 failures
# INFO flwr 2025-02-15 22:08:32,122 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 205.78it/s]
# INFO flwr 2025-02-15 22:08:32,358 | server_returns_parameters.py:120 | fit progress: (9, 148.42783856391907, {'accuracy': 0.2906666666666667}, 18.912376833031885)
# INFO:flwr:fit progress: (9, 148.42783856391907, {'accuracy': 0.2906666666666667}, 18.912376833031885)
# INFO flwr 2025-02-15 22:08:32,359 | server_returns_parameters.py:171 | evaluate_round 9: no clients selected, cancel
# INFO:flwr:evaluate_round 9: no clients selected, cancel
# INFO flwr 2025-02-15 22:08:32,367 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 22:08:32,368 | client_manager.py:68 | Sampled the following clients: ['2777', '82', '2583', '2652']
# INFO:flwr:Sampled the following clients: ['2777', '82', '2583', '2652']
# DEBUG flwr 2025-02-15 22:08:32,369 | server_returns_parameters.py:223 | fit_round 10: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 10: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 22:08:32,370 | client.py:51 | Creating client with cid: 2777
# INFO:flwr:Creating client with cid: 2777
# INFO flwr 2025-02-15 22:08:32,370 | client.py:51 | Creating client with cid: 82
# INFO:flwr:Creating client with cid: 82
# INFO flwr 2025-02-15 22:08:32,371 | client.py:51 | Creating client with cid: 2583
# INFO:flwr:Creating client with cid: 2583
# INFO flwr 2025-02-15 22:08:32,371 | client.py:51 | Creating client with cid: 2652
# INFO:flwr:Creating client with cid: 2652
# DEBUG flwr 2025-02-15 22:08:34,151 | server_returns_parameters.py:237 | fit_round 10 received 4 results and 0 failures
# DEBUG:flwr:fit_round 10 received 4 results and 0 failures
# INFO flwr 2025-02-15 22:08:34,157 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 201.67it/s]
# INFO flwr 2025-02-15 22:08:34,397 | server_returns_parameters.py:120 | fit progress: (10, 136.19251990318298, {'accuracy': 0.33666666666666667}, 20.951500957948156)
# INFO:flwr:fit progress: (10, 136.19251990318298, {'accuracy': 0.33666666666666667}, 20.951500957948156)
# INFO flwr 2025-02-15 22:08:34,398 | server_returns_parameters.py:171 | evaluate_round 10: no clients selected, cancel
# INFO:flwr:evaluate_round 10: no clients selected, cancel
# INFO flwr 2025-02-15 22:08:34,408 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 22:08:34,409 | client_manager.py:68 | Sampled the following clients: ['2511', '257', '2232', '1056']
# INFO:flwr:Sampled the following clients: ['2511', '257', '2232', '1056']
# DEBUG flwr 2025-02-15 22:08:34,410 | server_returns_parameters.py:223 | fit_round 11: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 11: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 22:08:34,411 | client.py:51 | Creating client with cid: 2511
# INFO:flwr:Creating client with cid: 2511
# INFO flwr 2025-02-15 22:08:34,412 | client.py:51 | Creating client with cid: 257
# INFO:flwr:Creating client with cid: 257
# INFO flwr 2025-02-15 22:08:34,412 | client.py:51 | Creating client with cid: 2232
# INFO flwr 2025-02-15 22:08:34,412 | client.py:51 | Creating client with cid: 1056
# INFO:flwr:Creating client with cid: 2232
# INFO:flwr:Creating client with cid: 1056
# DEBUG flwr 2025-02-15 22:08:36,408 | server_returns_parameters.py:237 | fit_round 11 received 4 results and 0 failures
# DEBUG:flwr:fit_round 11 received 4 results and 0 failures
# INFO flwr 2025-02-15 22:08:36,413 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 186.42it/s]
# INFO flwr 2025-02-15 22:08:36,674 | server_returns_parameters.py:120 | fit progress: (11, 122.49331212043762, {'accuracy': 0.38466666666666666}, 23.228319374960847)
# INFO:flwr:fit progress: (11, 122.49331212043762, {'accuracy': 0.38466666666666666}, 23.228319374960847)
# INFO flwr 2025-02-15 22:08:36,675 | server_returns_parameters.py:171 | evaluate_round 11: no clients selected, cancel
# INFO:flwr:evaluate_round 11: no clients selected, cancel
# INFO flwr 2025-02-15 22:08:36,685 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 22:08:36,686 | client_manager.py:68 | Sampled the following clients: ['225', '657', '1844', '1504']
# INFO:flwr:Sampled the following clients: ['225', '657', '1844', '1504']
# DEBUG flwr 2025-02-15 22:08:36,686 | server_returns_parameters.py:223 | fit_round 12: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 12: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 22:08:36,687 | client.py:51 | Creating client with cid: 225
# INFO:flwr:Creating client with cid: 225
# INFO flwr 2025-02-15 22:08:36,688 | client.py:51 | Creating client with cid: 657
# INFO:flwr:Creating client with cid: 657
# INFO flwr 2025-02-15 22:08:36,688 | client.py:51 | Creating client with cid: 1844
# INFO:flwr:Creating client with cid: 1844
# INFO flwr 2025-02-15 22:08:36,688 | client.py:51 | Creating client with cid: 1504
# INFO:flwr:Creating client with cid: 1504
# DEBUG flwr 2025-02-15 22:08:38,834 | server_returns_parameters.py:237 | fit_round 12 received 4 results and 0 failures
# DEBUG:flwr:fit_round 12 received 4 results and 0 failures
# INFO flwr 2025-02-15 22:08:38,840 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 166.67it/s]
# INFO flwr 2025-02-15 22:08:39,131 | server_returns_parameters.py:120 | fit progress: (12, 110.59587740898132, {'accuracy': 0.414}, 25.68524541601073)
# INFO:flwr:fit progress: (12, 110.59587740898132, {'accuracy': 0.414}, 25.68524541601073)
# INFO flwr 2025-02-15 22:08:39,132 | server_returns_parameters.py:171 | evaluate_round 12: no clients selected, cancel
# INFO:flwr:evaluate_round 12: no clients selected, cancel
# INFO flwr 2025-02-15 22:08:39,143 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 22:08:39,145 | client_manager.py:68 | Sampled the following clients: ['168', '2252', '2386', '1450']
# INFO:flwr:Sampled the following clients: ['168', '2252', '2386', '1450']
# DEBUG flwr 2025-02-15 22:08:39,145 | server_returns_parameters.py:223 | fit_round 13: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 13: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 22:08:39,146 | client.py:51 | Creating client with cid: 168
# INFO:flwr:Creating client with cid: 168
# INFO flwr 2025-02-15 22:08:39,147 | client.py:51 | Creating client with cid: 2252
# INFO:flwr:Creating client with cid: 2252
# INFO flwr 2025-02-15 22:08:39,147 | client.py:51 | Creating client with cid: 2386
# INFO:flwr:Creating client with cid: 2386
# INFO flwr 2025-02-15 22:08:39,147 | client.py:51 | Creating client with cid: 1450
# INFO:flwr:Creating client with cid: 1450
# DEBUG flwr 2025-02-15 22:08:40,939 | server_returns_parameters.py:237 | fit_round 13 received 4 results and 0 failures
# DEBUG:flwr:fit_round 13 received 4 results and 0 failures
# INFO flwr 2025-02-15 22:08:40,945 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 192.13it/s]
# INFO flwr 2025-02-15 22:08:41,197 | server_returns_parameters.py:120 | fit progress: (13, 100.77021622657776, {'accuracy': 0.452}, 27.751505916006863)
# INFO:flwr:fit progress: (13, 100.77021622657776, {'accuracy': 0.452}, 27.751505916006863)
# INFO flwr 2025-02-15 22:08:41,198 | server_returns_parameters.py:171 | evaluate_round 13: no clients selected, cancel
# INFO:flwr:evaluate_round 13: no clients selected, cancel
# INFO flwr 2025-02-15 22:08:41,210 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 22:08:41,210 | client_manager.py:68 | Sampled the following clients: ['1448', '982', '197', '1521']
# INFO:flwr:Sampled the following clients: ['1448', '982', '197', '1521']
# DEBUG flwr 2025-02-15 22:08:41,211 | server_returns_parameters.py:223 | fit_round 14: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 14: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 22:08:41,212 | client.py:51 | Creating client with cid: 1448
# INFO:flwr:Creating client with cid: 1448
# INFO flwr 2025-02-15 22:08:41,213 | client.py:51 | Creating client with cid: 982
# INFO:flwr:Creating client with cid: 982
# INFO flwr 2025-02-15 22:08:41,214 | client.py:51 | Creating client with cid: 197
# INFO:flwr:Creating client with cid: 197
# INFO flwr 2025-02-15 22:08:41,215 | client.py:51 | Creating client with cid: 1521
# INFO:flwr:Creating client with cid: 1521
# DEBUG flwr 2025-02-15 22:08:43,008 | server_returns_parameters.py:237 | fit_round 14 received 4 results and 0 failures
# DEBUG:flwr:fit_round 14 received 4 results and 0 failures
# INFO flwr 2025-02-15 22:08:43,014 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 199.15it/s]
# INFO flwr 2025-02-15 22:08:43,258 | server_returns_parameters.py:120 | fit progress: (14, 97.32054114341736, {'accuracy': 0.48933333333333334}, 29.811786249978468)
# INFO:flwr:fit progress: (14, 97.32054114341736, {'accuracy': 0.48933333333333334}, 29.811786249978468)
# INFO flwr 2025-02-15 22:08:43,258 | server_returns_parameters.py:171 | evaluate_round 14: no clients selected, cancel
# INFO:flwr:evaluate_round 14: no clients selected, cancel
# INFO flwr 2025-02-15 22:08:43,271 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 22:08:43,272 | client_manager.py:68 | Sampled the following clients: ['1853', '3134', '2351', '1628']
# INFO:flwr:Sampled the following clients: ['1853', '3134', '2351', '1628']
# DEBUG flwr 2025-02-15 22:08:43,272 | server_returns_parameters.py:223 | fit_round 15: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 15: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 22:08:43,274 | client.py:51 | Creating client with cid: 1853
# INFO:flwr:Creating client with cid: 1853
# INFO flwr 2025-02-15 22:08:43,275 | client.py:51 | Creating client with cid: 3134
# INFO:flwr:Creating client with cid: 3134
# INFO flwr 2025-02-15 22:08:43,276 | client.py:51 | Creating client with cid: 2351
# INFO:flwr:Creating client with cid: 2351
# INFO flwr 2025-02-15 22:08:43,277 | client.py:51 | Creating client with cid: 1628
# INFO:flwr:Creating client with cid: 1628
# DEBUG flwr 2025-02-15 22:08:44,794 | server_returns_parameters.py:237 | fit_round 15 received 4 results and 0 failures
# DEBUG:flwr:fit_round 15 received 4 results and 0 failures
# INFO flwr 2025-02-15 22:08:44,799 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 200.27it/s]
# INFO flwr 2025-02-15 22:08:45,041 | server_returns_parameters.py:120 | fit progress: (15, 92.33228051662445, {'accuracy': 0.5226666666666666}, 31.59568191599101)
# INFO:flwr:fit progress: (15, 92.33228051662445, {'accuracy': 0.5226666666666666}, 31.59568191599101)
# INFO flwr 2025-02-15 22:08:45,042 | server_returns_parameters.py:171 | evaluate_round 15: no clients selected, cancel
# INFO:flwr:evaluate_round 15: no clients selected, cancel
# INFO flwr 2025-02-15 22:08:45,056 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 22:08:45,057 | client_manager.py:68 | Sampled the following clients: ['2945', '2689', '2753', '1003']
# INFO:flwr:Sampled the following clients: ['2945', '2689', '2753', '1003']
# DEBUG flwr 2025-02-15 22:08:45,058 | server_returns_parameters.py:223 | fit_round 16: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 16: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 22:08:45,059 | client.py:51 | Creating client with cid: 2945
# INFO:flwr:Creating client with cid: 2945
# INFO flwr 2025-02-15 22:08:45,059 | client.py:51 | Creating client with cid: 2689
# INFO:flwr:Creating client with cid: 2689
# INFO flwr 2025-02-15 22:08:45,059 | client.py:51 | Creating client with cid: 2753
# INFO:flwr:Creating client with cid: 2753
# INFO flwr 2025-02-15 22:08:45,060 | client.py:51 | Creating client with cid: 1003
# INFO:flwr:Creating client with cid: 1003
# DEBUG flwr 2025-02-15 22:08:46,500 | server_returns_parameters.py:237 | fit_round 16 received 4 results and 0 failures
# DEBUG:flwr:fit_round 16 received 4 results and 0 failures
# INFO flwr 2025-02-15 22:08:46,506 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 184.92it/s]
# INFO flwr 2025-02-15 22:08:46,769 | server_returns_parameters.py:120 | fit progress: (16, 92.31190931797028, {'accuracy': 0.5366666666666666}, 33.323450749972835)
# INFO:flwr:fit progress: (16, 92.31190931797028, {'accuracy': 0.5366666666666666}, 33.323450749972835)
# INFO flwr 2025-02-15 22:08:46,770 | server_returns_parameters.py:171 | evaluate_round 16: no clients selected, cancel
# INFO:flwr:evaluate_round 16: no clients selected, cancel
# INFO flwr 2025-02-15 22:08:46,783 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 22:08:46,784 | client_manager.py:68 | Sampled the following clients: ['770', '2852', '1893', '292']
# INFO:flwr:Sampled the following clients: ['770', '2852', '1893', '292']
# DEBUG flwr 2025-02-15 22:08:46,786 | server_returns_parameters.py:223 | fit_round 17: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 17: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 22:08:46,786 | client.py:51 | Creating client with cid: 770
# INFO:flwr:Creating client with cid: 770
# INFO flwr 2025-02-15 22:08:46,787 | client.py:51 | Creating client with cid: 2852
# INFO:flwr:Creating client with cid: 2852
# INFO flwr 2025-02-15 22:08:46,787 | client.py:51 | Creating client with cid: 1893
# INFO:flwr:Creating client with cid: 1893
# INFO flwr 2025-02-15 22:08:46,788 | client.py:51 | Creating client with cid: 292
# INFO:flwr:Creating client with cid: 292
# DEBUG flwr 2025-02-15 22:08:49,036 | server_returns_parameters.py:237 | fit_round 17 received 4 results and 0 failures
# DEBUG:flwr:fit_round 17 received 4 results and 0 failures
# INFO flwr 2025-02-15 22:08:49,041 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 184.89it/s]
# INFO flwr 2025-02-15 22:08:49,304 | server_returns_parameters.py:120 | fit progress: (17, 94.73305785655975, {'accuracy': 0.542}, 35.857733875047415)
# INFO:flwr:fit progress: (17, 94.73305785655975, {'accuracy': 0.542}, 35.857733875047415)
# INFO flwr 2025-02-15 22:08:49,304 | server_returns_parameters.py:171 | evaluate_round 17: no clients selected, cancel
# INFO:flwr:evaluate_round 17: no clients selected, cancel
# INFO flwr 2025-02-15 22:08:49,319 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 22:08:49,320 | client_manager.py:68 | Sampled the following clients: ['714', '890', '1184', '1557']
# INFO:flwr:Sampled the following clients: ['714', '890', '1184', '1557']
# DEBUG flwr 2025-02-15 22:08:49,320 | server_returns_parameters.py:223 | fit_round 18: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 18: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 22:08:49,321 | client.py:51 | Creating client with cid: 714
# INFO:flwr:Creating client with cid: 714
# INFO flwr 2025-02-15 22:08:49,321 | client.py:51 | Creating client with cid: 890
# INFO:flwr:Creating client with cid: 890
# INFO flwr 2025-02-15 22:08:49,322 | client.py:51 | Creating client with cid: 1184
# INFO:flwr:Creating client with cid: 1184
# INFO flwr 2025-02-15 22:08:49,322 | client.py:51 | Creating client with cid: 1557
# INFO:flwr:Creating client with cid: 1557
# DEBUG flwr 2025-02-15 22:08:51,271 | server_returns_parameters.py:237 | fit_round 18 received 4 results and 0 failures
# DEBUG:flwr:fit_round 18 received 4 results and 0 failures
# INFO flwr 2025-02-15 22:08:51,276 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 187.49it/s]
# INFO flwr 2025-02-15 22:08:51,535 | server_returns_parameters.py:120 | fit progress: (18, 94.09506249427795, {'accuracy': 0.53}, 38.08966508298181)
# INFO:flwr:fit progress: (18, 94.09506249427795, {'accuracy': 0.53}, 38.08966508298181)
# INFO flwr 2025-02-15 22:08:51,536 | server_returns_parameters.py:171 | evaluate_round 18: no clients selected, cancel
# INFO:flwr:evaluate_round 18: no clients selected, cancel
# INFO flwr 2025-02-15 22:08:51,551 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 22:08:51,552 | client_manager.py:68 | Sampled the following clients: ['723', '1096', '2064', '2940']
# INFO:flwr:Sampled the following clients: ['723', '1096', '2064', '2940']
# DEBUG flwr 2025-02-15 22:08:51,553 | server_returns_parameters.py:223 | fit_round 19: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 19: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 22:08:51,554 | client.py:51 | Creating client with cid: 723
# INFO:flwr:Creating client with cid: 723
# INFO flwr 2025-02-15 22:08:51,554 | client.py:51 | Creating client with cid: 1096
# INFO:flwr:Creating client with cid: 1096
# INFO flwr 2025-02-15 22:08:51,554 | client.py:51 | Creating client with cid: 2064
# INFO flwr 2025-02-15 22:08:51,554 | client.py:51 | Creating client with cid: 2940
# INFO:flwr:Creating client with cid: 2064
# INFO:flwr:Creating client with cid: 2940
# DEBUG flwr 2025-02-15 22:08:53,292 | server_returns_parameters.py:237 | fit_round 19 received 4 results and 0 failures
# DEBUG:flwr:fit_round 19 received 4 results and 0 failures
# INFO flwr 2025-02-15 22:08:53,298 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 193.82it/s]
# INFO flwr 2025-02-15 22:08:53,548 | server_returns_parameters.py:120 | fit progress: (19, 93.68702900409698, {'accuracy': 0.5353333333333333}, 40.10244558297563)
# INFO:flwr:fit progress: (19, 93.68702900409698, {'accuracy': 0.5353333333333333}, 40.10244558297563)
# INFO flwr 2025-02-15 22:08:53,549 | server_returns_parameters.py:171 | evaluate_round 19: no clients selected, cancel
# INFO:flwr:evaluate_round 19: no clients selected, cancel
# INFO flwr 2025-02-15 22:08:53,566 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 22:08:53,567 | client_manager.py:68 | Sampled the following clients: ['1489', '2656', '994', '2742']
# INFO:flwr:Sampled the following clients: ['1489', '2656', '994', '2742']
# DEBUG flwr 2025-02-15 22:08:53,568 | server_returns_parameters.py:223 | fit_round 20: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 20: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 22:08:53,569 | client.py:51 | Creating client with cid: 1489
# INFO:flwr:Creating client with cid: 1489
# INFO flwr 2025-02-15 22:08:53,570 | client.py:51 | Creating client with cid: 2656
# INFO:flwr:Creating client with cid: 2656
# INFO flwr 2025-02-15 22:08:53,570 | client.py:51 | Creating client with cid: 994
# INFO:flwr:Creating client with cid: 994
# INFO flwr 2025-02-15 22:08:53,571 | client.py:51 | Creating client with cid: 2742
# INFO:flwr:Creating client with cid: 2742
# DEBUG flwr 2025-02-15 22:08:55,323 | server_returns_parameters.py:237 | fit_round 20 received 4 results and 0 failures
# DEBUG:flwr:fit_round 20 received 4 results and 0 failures
# INFO flwr 2025-02-15 22:08:55,328 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 201.94it/s]
# INFO flwr 2025-02-15 22:08:55,569 | server_returns_parameters.py:120 | fit progress: (20, 93.83563721179962, {'accuracy': 0.5533333333333333}, 42.12315937504172)
# INFO:flwr:fit progress: (20, 93.83563721179962, {'accuracy': 0.5533333333333333}, 42.12315937504172)
# INFO flwr 2025-02-15 22:08:55,570 | server_returns_parameters.py:171 | evaluate_round 20: no clients selected, cancel
# INFO:flwr:evaluate_round 20: no clients selected, cancel
# INFO flwr 2025-02-15 22:08:55,587 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 22:08:55,588 | client_manager.py:68 | Sampled the following clients: ['764', '1484', '2389', '1480']
# INFO:flwr:Sampled the following clients: ['764', '1484', '2389', '1480']
# DEBUG flwr 2025-02-15 22:08:55,589 | server_returns_parameters.py:223 | fit_round 21: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 21: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 22:08:55,590 | client.py:51 | Creating client with cid: 764
# INFO:flwr:Creating client with cid: 764
# INFO flwr 2025-02-15 22:08:55,590 | client.py:51 | Creating client with cid: 1484
# INFO:flwr:Creating client with cid: 1484
# INFO flwr 2025-02-15 22:08:55,591 | client.py:51 | Creating client with cid: 2389
# INFO:flwr:Creating client with cid: 2389
# INFO flwr 2025-02-15 22:08:55,591 | client.py:51 | Creating client with cid: 1480
# INFO:flwr:Creating client with cid: 1480
# DEBUG flwr 2025-02-15 22:08:57,443 | server_returns_parameters.py:237 | fit_round 21 received 4 results and 0 failures
# DEBUG:flwr:fit_round 21 received 4 results and 0 failures
# INFO flwr 2025-02-15 22:08:57,449 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 194.70it/s]
# INFO flwr 2025-02-15 22:08:57,699 | server_returns_parameters.py:120 | fit progress: (21, 93.38003551959991, {'accuracy': 0.5613333333333334}, 44.25293470802717)
# INFO:flwr:fit progress: (21, 93.38003551959991, {'accuracy': 0.5613333333333334}, 44.25293470802717)
# INFO flwr 2025-02-15 22:08:57,699 | server_returns_parameters.py:171 | evaluate_round 21: no clients selected, cancel
# INFO:flwr:evaluate_round 21: no clients selected, cancel
# INFO flwr 2025-02-15 22:08:57,718 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 22:08:57,719 | client_manager.py:68 | Sampled the following clients: ['2956', '1486', '3184', '2464']
# INFO:flwr:Sampled the following clients: ['2956', '1486', '3184', '2464']
# DEBUG flwr 2025-02-15 22:08:57,720 | server_returns_parameters.py:223 | fit_round 22: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 22: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 22:08:57,721 | client.py:51 | Creating client with cid: 2956
# INFO:flwr:Creating client with cid: 2956
# INFO flwr 2025-02-15 22:08:57,721 | client.py:51 | Creating client with cid: 1486
# INFO flwr 2025-02-15 22:08:57,722 | client.py:51 | Creating client with cid: 3184
# INFO:flwr:Creating client with cid: 1486
# INFO:flwr:Creating client with cid: 3184
# INFO flwr 2025-02-15 22:08:57,723 | client.py:51 | Creating client with cid: 2464
# INFO:flwr:Creating client with cid: 2464
# DEBUG flwr 2025-02-15 22:08:59,144 | server_returns_parameters.py:237 | fit_round 22 received 4 results and 0 failures
# DEBUG:flwr:fit_round 22 received 4 results and 0 failures
# INFO flwr 2025-02-15 22:08:59,150 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 194.00it/s]
# INFO flwr 2025-02-15 22:08:59,400 | server_returns_parameters.py:120 | fit progress: (22, 91.032057762146, {'accuracy': 0.5633333333333334}, 45.95447195798624)
# INFO:flwr:fit progress: (22, 91.032057762146, {'accuracy': 0.5633333333333334}, 45.95447195798624)
# INFO flwr 2025-02-15 22:08:59,401 | server_returns_parameters.py:171 | evaluate_round 22: no clients selected, cancel
# INFO:flwr:evaluate_round 22: no clients selected, cancel
# INFO flwr 2025-02-15 22:08:59,420 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 22:08:59,421 | client_manager.py:68 | Sampled the following clients: ['1306', '0', '2651', '2426']
# INFO:flwr:Sampled the following clients: ['1306', '0', '2651', '2426']
# DEBUG flwr 2025-02-15 22:08:59,422 | server_returns_parameters.py:223 | fit_round 23: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 23: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 22:08:59,423 | client.py:51 | Creating client with cid: 1306
# INFO:flwr:Creating client with cid: 1306
# INFO flwr 2025-02-15 22:08:59,424 | client.py:51 | Creating client with cid: 0
# INFO:flwr:Creating client with cid: 0
# INFO flwr 2025-02-15 22:08:59,424 | client.py:51 | Creating client with cid: 2651
# INFO:flwr:Creating client with cid: 2651
# INFO flwr 2025-02-15 22:08:59,424 | client.py:51 | Creating client with cid: 2426
# INFO:flwr:Creating client with cid: 2426
# DEBUG flwr 2025-02-15 22:09:01,141 | server_returns_parameters.py:237 | fit_round 23 received 4 results and 0 failures
# DEBUG:flwr:fit_round 23 received 4 results and 0 failures
# INFO flwr 2025-02-15 22:09:01,146 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 158.26it/s]
# INFO flwr 2025-02-15 22:09:01,453 | server_returns_parameters.py:120 | fit progress: (23, 93.7626918554306, {'accuracy': 0.5666666666666667}, 48.00735337496735)
# INFO:flwr:fit progress: (23, 93.7626918554306, {'accuracy': 0.5666666666666667}, 48.00735337496735)
# INFO flwr 2025-02-15 22:09:01,454 | server_returns_parameters.py:171 | evaluate_round 23: no clients selected, cancel
# INFO:flwr:evaluate_round 23: no clients selected, cancel
# INFO flwr 2025-02-15 22:09:01,473 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 22:09:01,474 | client_manager.py:68 | Sampled the following clients: ['1721', '2204', '3192', '1258']
# INFO:flwr:Sampled the following clients: ['1721', '2204', '3192', '1258']
# DEBUG flwr 2025-02-15 22:09:01,475 | server_returns_parameters.py:223 | fit_round 24: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 24: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 22:09:01,476 | client.py:51 | Creating client with cid: 1721
# INFO:flwr:Creating client with cid: 1721
# INFO flwr 2025-02-15 22:09:01,477 | client.py:51 | Creating client with cid: 2204
# INFO:flwr:Creating client with cid: 2204
# INFO flwr 2025-02-15 22:09:01,477 | client.py:51 | Creating client with cid: 3192
# INFO:flwr:Creating client with cid: 3192
# INFO flwr 2025-02-15 22:09:01,478 | client.py:51 | Creating client with cid: 1258
# INFO:flwr:Creating client with cid: 1258
# DEBUG flwr 2025-02-15 22:09:03,206 | server_returns_parameters.py:237 | fit_round 24 received 4 results and 0 failures
# DEBUG:flwr:fit_round 24 received 4 results and 0 failures
# INFO flwr 2025-02-15 22:09:03,211 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 189.84it/s]
# INFO flwr 2025-02-15 22:09:03,469 | server_returns_parameters.py:120 | fit progress: (24, 97.72426879405975, {'accuracy': 0.5586666666666666}, 50.022745791007765)
# INFO:flwr:fit progress: (24, 97.72426879405975, {'accuracy': 0.5586666666666666}, 50.022745791007765)
# INFO flwr 2025-02-15 22:09:03,469 | server_returns_parameters.py:171 | evaluate_round 24: no clients selected, cancel
# INFO:flwr:evaluate_round 24: no clients selected, cancel
# INFO flwr 2025-02-15 22:09:03,492 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 22:09:03,493 | client_manager.py:68 | Sampled the following clients: ['2176', '1230', '1374', '1154']
# INFO:flwr:Sampled the following clients: ['2176', '1230', '1374', '1154']
# DEBUG flwr 2025-02-15 22:09:03,494 | server_returns_parameters.py:223 | fit_round 25: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 25: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 22:09:03,496 | client.py:51 | Creating client with cid: 2176
# INFO:flwr:Creating client with cid: 2176
# INFO flwr 2025-02-15 22:09:03,496 | client.py:51 | Creating client with cid: 1230
# INFO:flwr:Creating client with cid: 1230
# INFO flwr 2025-02-15 22:09:03,497 | client.py:51 | Creating client with cid: 1374
# INFO:flwr:Creating client with cid: 1374
# INFO flwr 2025-02-15 22:09:03,497 | client.py:51 | Creating client with cid: 1154
# INFO:flwr:Creating client with cid: 1154
# DEBUG flwr 2025-02-15 22:09:05,308 | server_returns_parameters.py:237 | fit_round 25 received 4 results and 0 failures
# DEBUG:flwr:fit_round 25 received 4 results and 0 failures
# INFO flwr 2025-02-15 22:09:05,313 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 202.57it/s]
# INFO flwr 2025-02-15 22:09:05,554 | server_returns_parameters.py:120 | fit progress: (25, 89.44181740283966, {'accuracy': 0.5653333333333334}, 52.107828708016314)
# INFO:flwr:fit progress: (25, 89.44181740283966, {'accuracy': 0.5653333333333334}, 52.107828708016314)
# INFO flwr 2025-02-15 22:09:05,554 | server_returns_parameters.py:171 | evaluate_round 25: no clients selected, cancel
# INFO:flwr:evaluate_round 25: no clients selected, cancel
# INFO flwr 2025-02-15 22:09:05,574 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 22:09:05,575 | client_manager.py:68 | Sampled the following clients: ['1924', '3035', '2189', '1444']
# INFO:flwr:Sampled the following clients: ['1924', '3035', '2189', '1444']
# DEBUG flwr 2025-02-15 22:09:05,576 | server_returns_parameters.py:223 | fit_round 26: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 26: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 22:09:05,577 | client.py:51 | Creating client with cid: 1924
# INFO:flwr:Creating client with cid: 1924
# INFO flwr 2025-02-15 22:09:05,577 | client.py:51 | Creating client with cid: 3035
# INFO:flwr:Creating client with cid: 3035
# INFO flwr 2025-02-15 22:09:05,577 | client.py:51 | Creating client with cid: 2189
# INFO:flwr:Creating client with cid: 2189
# INFO flwr 2025-02-15 22:09:05,578 | client.py:51 | Creating client with cid: 1444
# INFO:flwr:Creating client with cid: 1444
# DEBUG flwr 2025-02-15 22:09:06,954 | server_returns_parameters.py:237 | fit_round 26 received 4 results and 0 failures
# DEBUG:flwr:fit_round 26 received 4 results and 0 failures
# INFO flwr 2025-02-15 22:09:06,960 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 201.43it/s]
# INFO flwr 2025-02-15 22:09:07,202 | server_returns_parameters.py:120 | fit progress: (26, 78.49828505516052, {'accuracy': 0.62}, 53.756572791025974)
# INFO:flwr:fit progress: (26, 78.49828505516052, {'accuracy': 0.62}, 53.756572791025974)
# INFO flwr 2025-02-15 22:09:07,203 | server_returns_parameters.py:171 | evaluate_round 26: no clients selected, cancel
# INFO:flwr:evaluate_round 26: no clients selected, cancel
# INFO flwr 2025-02-15 22:09:07,226 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 22:09:07,227 | client_manager.py:68 | Sampled the following clients: ['904', '2033', '2893', '1935']
# INFO:flwr:Sampled the following clients: ['904', '2033', '2893', '1935']
# DEBUG flwr 2025-02-15 22:09:07,228 | server_returns_parameters.py:223 | fit_round 27: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 27: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 22:09:07,229 | client.py:51 | Creating client with cid: 904
# INFO:flwr:Creating client with cid: 904
# INFO flwr 2025-02-15 22:09:07,229 | client.py:51 | Creating client with cid: 2033
# INFO:flwr:Creating client with cid: 2033
# INFO flwr 2025-02-15 22:09:07,230 | client.py:51 | Creating client with cid: 2893
# INFO:flwr:Creating client with cid: 2893
# INFO flwr 2025-02-15 22:09:07,230 | client.py:51 | Creating client with cid: 1935
# INFO:flwr:Creating client with cid: 1935
# DEBUG flwr 2025-02-15 22:09:08,625 | server_returns_parameters.py:237 | fit_round 27 received 4 results and 0 failures
# DEBUG:flwr:fit_round 27 received 4 results and 0 failures
# INFO flwr 2025-02-15 22:09:08,631 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 188.97it/s]
# INFO flwr 2025-02-15 22:09:08,887 | server_returns_parameters.py:120 | fit progress: (27, 71.9208328127861, {'accuracy': 0.6446666666666667}, 55.441011040937155)
# INFO:flwr:fit progress: (27, 71.9208328127861, {'accuracy': 0.6446666666666667}, 55.441011040937155)
# ...
# INFO:flwr:Creating client with cid: 994
# INFO flwr 2025-02-15 22:11:21,506 | client.py:51 | Creating client with cid: 2594
# INFO:flwr:Creating client with cid: 2594
# DEBUG flwr 2025-02-15 22:11:23,977 | server_returns_parameters.py:237 | fit_round 28 received 4 results and 0 failures
# DEBUG:flwr:fit_round 28 received 4 results and 0 failures
# INFO flwr 2025-02-15 22:11:23,983 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 169.70it/s]
# INFO flwr 2025-02-15 22:11:24,269 | server_returns_parameters.py:120 | fit progress: (28, 77.89102321863174, {'accuracy': 0.6033333333333334}, 60.65389600000344)
# INFO:flwr:fit progress: (28, 77.89102321863174, {'accuracy': 0.6033333333333334}, 60.65389600000344)
# INFO flwr 2025-02-15 22:11:24,270 | server_returns_parameters.py:171 | evaluate_round 28: no clients selected, cancel
# INFO:flwr:evaluate_round 28: no clients selected, cancel
# INFO flwr 2025-02-15 22:11:24,294 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 22:11:24,295 | client_manager.py:68 | Sampled the following clients: ['1740', '1102', '153', '1874']
# INFO:flwr:Sampled the following clients: ['1740', '1102', '153', '1874']
# DEBUG flwr 2025-02-15 22:11:24,295 | server_returns_parameters.py:223 | fit_round 29: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 29: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 22:11:24,296 | client.py:51 | Creating client with cid: 1740
# INFO:flwr:Creating client with cid: 1740
# INFO flwr 2025-02-15 22:11:24,297 | client.py:51 | Creating client with cid: 1102
# INFO:flwr:Creating client with cid: 1102
# INFO flwr 2025-02-15 22:11:24,297 | client.py:51 | Creating client with cid: 153
# INFO:flwr:Creating client with cid: 153
# INFO flwr 2025-02-15 22:11:24,297 | client.py:51 | Creating client with cid: 1874
# INFO:flwr:Creating client with cid: 1874
# DEBUG flwr 2025-02-15 22:11:26,105 | server_returns_parameters.py:237 | fit_round 29 received 4 results and 0 failures
# DEBUG:flwr:fit_round 29 received 4 results and 0 failures
# INFO flwr 2025-02-15 22:11:26,110 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 187.01it/s]
# INFO flwr 2025-02-15 22:11:26,369 | server_returns_parameters.py:120 | fit progress: (29, 72.44776397943497, {'accuracy': 0.6353333333333333}, 62.7535681250738)
# INFO:flwr:fit progress: (29, 72.44776397943497, {'accuracy': 0.6353333333333333}, 62.7535681250738)
# INFO flwr 2025-02-15 22:11:26,370 | server_returns_parameters.py:171 | evaluate_round 29: no clients selected, cancel
# INFO:flwr:evaluate_round 29: no clients selected, cancel
# INFO flwr 2025-02-15 22:11:26,396 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-15 22:11:26,397 | client_manager.py:68 | Sampled the following clients: ['1044', '387', '989', '2833']
# INFO:flwr:Sampled the following clients: ['1044', '387', '989', '2833']
# DEBUG flwr 2025-02-15 22:11:26,398 | server_returns_parameters.py:223 | fit_round 30: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 30: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-15 22:11:26,399 | client.py:51 | Creating client with cid: 1044
# INFO:flwr:Creating client with cid: 1044
# INFO flwr 2025-02-15 22:11:26,399 | client.py:51 | Creating client with cid: 387
# INFO:flwr:Creating client with cid: 387
# INFO flwr 2025-02-15 22:11:26,399 | client.py:51 | Creating client with cid: 989
# INFO flwr 2025-02-15 22:11:26,400 | client.py:51 | Creating client with cid: 2833
# INFO:flwr:Creating client with cid: 989
# INFO:flwr:Creating client with cid: 2833
# DEBUG flwr 2025-02-15 22:11:28,786 | server_returns_parameters.py:237 | fit_round 30 received 4 results and 0 failures
# DEBUG:flwr:fit_round 30 received 4 results and 0 failures
# INFO flwr 2025-02-15 22:11:28,792 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 183.55it/s]
# INFO flwr 2025-02-15 22:11:29,057 | server_returns_parameters.py:120 | fit progress: (30, 104.0373820066452, {'accuracy': 0.5793333333333334}, 65.44107345805969)
# INFO:flwr:fit progress: (30, 104.0373820066452, {'accuracy': 0.5793333333333334}, 65.44107345805969)
# INFO flwr 2025-02-15 22:11:29,058 | server_returns_parameters.py:171 | evaluate_round 30: no clients selected, cancel
# INFO:flwr:evaluate_round 30: no clients selected, cancel
# INFO flwr 2025-02-15 22:11:29,060 | server_returns_parameters.py:150 | FL finished in 65.44423141598236
# INFO:flwr:FL finished in 65.44423141598236
# INFO flwr 2025-02-15 22:11:29,061 | app.py:250 | app_fit: losses_distributed []
# INFO:flwr:app_fit: losses_distributed []
# INFO flwr 2025-02-15 22:11:29,062 | app.py:251 | app_fit: metrics_distributed_fit {'train_loss': [(1, {'avg': 0.10369113134220243, 'all': [(1, 0.10071000456809998), (1, 0.10979274287819862), (1, 0.10287056677043438), (1, 0.10139121115207672)]}), (2, {'avg': 0.10298981745209959, 'all': [(1, 0.10234147061904271), (1, 0.09861321933567524), (1, 0.10571766313579348), (1, 0.10528691671788692)]}), (3, {'avg': 0.10198943799893771, 'all': [(1, 0.09946224838495255), (1, 0.09882939755916595), (1, 0.10758508848292488), (1, 0.10208101756870747)]}), (4, {'avg': 0.09210580137691327, 'all': [(1, 0.08481377576078687), (1, 0.10356127470731735), (1, 0.09090554714202881), (1, 0.08914260789752007)]}), (5, {'avg': 0.07527640331536531, 'all': [(1, 0.04882
| app.py:254 | app_fit: metrics_centralized {'accuracy': [(0, 0.004), (1, 0.07933333333333334), (2, 0.07933333333333334), (3, 0.074), (4, 0.078), (5, 0.102), (6, 0.134), (7, 0.2753333333333333), (8, 0.30733333333333335), (9, 0.4086666666666667), (10, 0.5113333333333333), (11, 0.5206666666666667), (12, 0.49533333333333335), (13, 0.5586666666666666), (14, 0.54), (15, 0.6326666666666667), (16, 0.6306666666666667), (17, 0.5966666666666667), (18, 0.5306666666666666), (19, 0.642), (20, 0.6666666666666666), (21, 0.6453333333333333), (22, 0.694), (23, 0.6593333333333333), (24, 0.66), (25, 0.6273333333333333), (26, 0.7113333333333334), (27, 0.7253333333333334), (28, 0.6033333333333334), (29, 0.6353333333333333), (30, 0.5793333333333334)]}
# INFO:flwr:app_fit: metrics_centralized {'accuracy': [(0, 0.004), (1, 0.07933333333333334), (2, 0.07933333333333334), (3, 0.074), (4, 0.078), (5, 0.102), (6, 0.134), (7, 0.2753333333333333), (8, 0.30733333333333335), (9, 0.4086666666666667), (10, 0.5113333333333333), (11, 0.5206666666666667), (12, 0.49533333333333335), (13, 0.5586666666666666), (14, 0.54), (15, 0.6326666666666667), (16, 0.6306666666666667), (17, 0.5966666666666667), (18, 0.5306666666666666), (19, 0.642), (20, 0.6666666666666666), (21, 0.6453333333333333), (22, 0.694), (23, 0.6593333333333333), (24, 0.66), (25, 0.6273333333333333), (26, 0.7113333333333334), (27, 0.7253333333333334), (28, 0.6033333333333334), (29, 0.6353333333333333), (30, 0.5793333333333334)]}

# %% [markdown]
# Part 2:

# %%
plt.figure(figsize=(10, 6))


for target_quantile, target_quantile_result in adaptive_results.items():
    parameters, hist = target_quantile_result
    target_quantile_accuracies = [accuracy for _, accuracy in hist.metrics_centralized["accuracy"]]
    plt.plot(target_quantile_accuracies, label=f"Accuracy of clip: {target_quantile}")


plt.xlabel("Round number")
plt.ylabel("Model Accuracy")
plt.title("Model accuracy for different clip norms")
plt.legend()
plt.show()

# %% [markdown]
# **Written Answer:**
#
# From the plot we can see that models with quantile 0.5 and 0.875 converge at a really similar rate while the model with the quantile 0.125 converges slightly slower.

# %% [markdown]
# Part 3:

# %%
experiment_pairs = list(zip(exp_3_results.keys(), adaptive_results.keys()))

for clip_norm_val, adaptive_norm_val in experiment_pairs:
    clip_result = exp_3_results[clip_norm_val]
    adaptive_result = adaptive_results[adaptive_norm_val]

    clip_parameters, clip_hist = clip_result
    adaptive_parameters, adaptive_hist = adaptive_result

    clip_accuracy = [accuracy for _, accuracy in clip_hist.metrics_centralized["accuracy"]]
    adaptive_accuracy = [accuracy for _, accuracy in adaptive_hist.metrics_centralized["accuracy"]]

    plt.figure(figsize=(13, 7))
    plt.plot(clip_accuracy, label=f"Accuracy of clip: {clip_norm_val}")
    plt.plot(adaptive_accuracy, label=f"Accuracy of adaptive: {adaptive_norm_val}")
    plt.xlabel("Round number")
    plt.ylabel("Model Accuracy")
    plt.title(f"Model accuracy for clip norm {clip_norm_val} and adaptive norm {adaptive_norm_val}")
    plt.legend()
    plt.show()

# %% [markdown]
# **Written Answer:**
#
#
#
#
# ---

# %% [markdown]
# **Question 6 (Part III/MPhil ✅):**
#
# (You need to provide the answer with **code** and **plots** for this question. A short written argumentation is recommended.)
#
# This is an extension to the previous question, which tries to expand upon how the adaptive norm applied to client gradients/updates affects the L2 norm of the federated model delta.
#
# 1. Using the previous results for `clip_norm_target_quantile`$\in \{0.125,\, 0.5, \,0.875\}$, plot the L2 norm of the federated model delta for each target quantile. Which of the target quantiles causes the most considerable oscillations in the federated L2 norm, and why do you think that is?
# 2. Do a similar ordered pairwise comparison between the federated L2 norm results of the target quantile experiments against those of the fixed bound experiments as in the previous question. Where is the gap between the adaptive and fixed method the largest?
# 3. Plot the accuracy of experiments with the adaptive bounds against the cumulative L2 norm.

# %% [markdown]
# ---
# **Question 6 Answer:**
#
# Part 1:

# %%
plt.figure(figsize=(13, 7))
for target_quantile, target_quantile_result in adaptive_results.items():
    parameters, hist = target_quantile_result

    prior_clip_norms = [ np.mean([ value for _, value in norm_prior_clip["all"]]) for round, norm_prior_clip in hist.metrics_distributed_fit["norm_prior_clip"]]
    plt.plot(prior_clip_norms, label=f"Target quantile: {target_quantile}")


plt.xlabel("Round number")
plt.ylabel("Model L2 Norm")
plt.title("L2 Norm Clip Across Rounds")
plt.legend()
plt.show()

# %% [markdown]
# **Written Answer:**
#
# Out of the three models, the most considerable oscillations appears in the model with the target quantile of 0.875 which is probably caused by the fact that clipping bound is so high that not many updates are clipped. Unlike with the models with lower quantile where clipping happens less frequently smoothing out L2 norm, the model with the largest quantile does not have this smoothing/capping effect that frequently resulting in larger fluctuations in the L2 norm.

# %% [markdown]
# Part 2:

# %%
experiment_pairs = list(zip(exp_3_results.keys(), adaptive_results.keys()))

for clip_norm_val, adaptive_norm_val in experiment_pairs:
    clip_result = exp_3_results[clip_norm_val]
    adaptive_result = adaptive_results[adaptive_norm_val]

    clip_parameters, clip_hist = clip_result
    adaptive_parameters, adaptive_hist = adaptive_result

    clip_norms = [ np.mean([ value for _, value in norm_prior_clip["all"]]) for round, norm_prior_clip in clip_hist.metrics_distributed_fit["norm_prior_clip"]]
    target_quantile_norms = [ np.mean([ value for _, value in norm_prior_clip["all"]]) for round, norm_prior_clip in adaptive_hist.metrics_distributed_fit["norm_prior_clip"]]
    
    plt.figure(figsize=(13, 7))
    plt.plot(clip_norms, label=f"Clip norm: {clip_norm_val}")
    plt.plot(target_quantile_norms, label=f"Target quantile: {adaptive_norm_val}")

    plt.xlabel("Round number")
    plt.ylabel("Clipped L2 Norm")
    plt.title(f"L2 Norm Clip Across Rounds With Target Quantile {adaptive_norm_val} and Clip Norm {clip_norm_val}")
    plt.legend()
    plt.show()

# %% [markdown]
# **Written Answer:**
#
# The gap between the adaptive and fixed method for the models appears to be at the beginning of the training/ in earlier rounds. This can be the result of the adaptive method starting with lower clipping bounds and gradually increasing them as the training progresses.

# %% [markdown]
# Part 3:

# %%
for target_quantile, target_quantile_result in adaptive_results.items():
    parameters, hist = target_quantile_result

    prior_clip_norms = [ np.mean([ value for _, value in norm_prior_clip["all"]]) for round, norm_prior_clip in hist.metrics_distributed_fit["norm_prior_clip"]]
    prior_clip_norms.insert(0,0)
    cumulative_norm = list(itertools.accumulate(prior_clip_norms))
    accuracies = [accuracy for _, accuracy in hist.metrics_centralized["accuracy"]]

    plt.figure(figsize=(13, 7))
    plt.plot(cumulative_norm,accuracies)
    plt.xlabel("Cummulative L2 Norm")
    plt.ylabel("Model Test Accuracy")
    plt.title(f"Model Test Accuracy Against Cummulative Norm Over Rounds for Target Quantile {target_quantile}")
    plt.grid(True)
    plt.show()

# %% [markdown]
# # 4 Epsilon-delta Privacy

# %% [markdown]
# We are now ready to understand the full extent of the DPFedAvg fixed algorithm and the relation between its privacy guarantees and the accuracy of the final model.
#
# Before this, we should establish what a particular set of DP parameters implies for the level of privacy theoretically. The function below shall allow us to do just that while assuming a fixed number of rounds and clients per round. It adapts a function provided by TensorFlow privacy for DP-SGD, as we have established that DP-FedAvg and DP-SGD are equivalent when considering a mere reframing of samples as clients; it should provide sufficient accuracy for our purposes.

# %%
from tensorflow_privacy.privacy.analysis.compute_dp_sgd_privacy_lib import (
    compute_dp_sgd_privacy,
)
from contextlib import redirect_stdout
from io import StringIO


class NullIO(StringIO):
    """Custom IO interface to cut-out annoying messages."""

    def write(self, txt: str) -> None:
        """Implement custom empty write function."""
        # This function intentionally does nothing


def compute_fl_privacy(
    num_rounds: int = 25,
    noise_multiplier: float = 1.0,
    num_total_clients: int = num_total_clients,
    num_fit_clients: int = 4,
) -> float:
    """Compute the privacy bound `epsilon`."""
    with redirect_stdout(NullIO()):
        vals = compute_dp_sgd_privacy(
            n=num_total_clients,
            batch_size=num_fit_clients,
            noise_multiplier=noise_multiplier,
            epochs=num_rounds,
            delta=num_total_clients ** (-1),
        )
    return vals[0]

# %%
log(INFO, compute_fl_privacy(noise_multiplier=0.05))
log(INFO, compute_fl_privacy(noise_multiplier=1.0))
# Out:
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# INFO flwr 2025-02-15 23:40:35,969 | 3928211183.py:1 | 4363302.374442753
# INFO:flwr:4363302.374442753
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# INFO flwr 2025-02-15 23:40:35,988 | 3928211183.py:2 | 0.7541536967384
# INFO:flwr:0.7541536967384

# %% [markdown]
# **Question 7 (Part II ✅ | Part III/MPhil ✅):**
#
# (While this is a largely conceptual question, it does require you to provide a small amount of **code** and several **plots**. Answers to the purely conceptual components should contain **no more than 5 sentences**.)
#
# Using the function mentioned above, study the impact of different parameters on the privacy guarantees of DP-FedAvg as follows:
#
# 1. Draw a scatter plot with the epsilon value on the y-axis. While keeping all the other parameters constant to the above values, vary the noise multiplier from 0.05 to 2 using an increment of 0.05. Use the noise multiplier as the x-axis.
#
# 2. Draw a scatter plot with the epsilon value on the y-axis. While keeping all the other parameters constant to the above values, vary `num_rounds` between $2^0$ and $2^{15}$ increasing using all the powers of two in the interval. Use the `num_rounds` as the x-axis.
#
# 3. Draw a scatter plot with the epsilon value on the y-axis. While keeping all the other parameters constant to the above values, vary `num_fit_cliets` from $2^0$ to $2^{10}$ increasing using all the powers of two in the interval. Use the `num_fit_cliets` as x-axis.
#
# 4. Describe the trade-offs you see and how they relate to FL privacy. <!-- Then, given the lecture by Peter Kairouz, what do you think the implications of these trade-offs are upon the practicality of Differential Privacy in FL? --> Then, what do you think are the implications of these trade-offs upon the practicality of differential privacy in FL?

# %% [markdown]
# Armed with this theoretical understanding of the privacy budget, we can explore the performance implications of Differential Privacy upon DPFedAvgFixed. Note once more that the experiments we are running are small scale, as such you may find particularly high sensitivity to the `noise_multiplier` to be present.

# %% [markdown]
# ---
#
# **Question 7 Answer:**
#
# Part 1:

# %%
noise_multipliers = np.arange(0.05, 2.05, 0.05)
epsilon_noise_values = [compute_fl_privacy(noise_multiplier=noise_multiplier) for noise_multiplier in noise_multipliers]

plt.figure(figsize=(13, 7))
plt.scatter(noise_multipliers, epsilon_noise_values)
plt.xlabel("Noise Multiplier")
plt.ylabel("Epsilon Value")
plt.yscale('log')
plt.title("Epsilon Value Against Noise Multiplier")
plt.grid(True)
plt.show()
# Out:
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.

# %% [markdown]
# Part 2:

# %%
num_rounds_values = 2** np.arange(16)
epsilon_round_values = [compute_fl_privacy(num_rounds=num_rounds) for num_rounds in num_rounds_values]

plt.figure(figsize=(13, 7))
plt.scatter(num_rounds_values, epsilon_round_values)
plt.xlabel("Number of Rounds")
plt.ylabel("Epsilon Value")
plt.xscale('log', base=2)
plt.title("Epsilon Value Against Number of Rounds")
plt.grid(True)
plt.show()
# Out:
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# [    1     2     4     8    16    32    64   128   256   512  1024  2048
#   4096  8192 16384 32768]
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.

# %% [markdown]
# Part 3:

# %%
num_fit_client_values = 2** np.arange(11)
epsilon_client_values = [compute_fl_privacy(num_fit_clients=num_fit_clients) for num_fit_clients in num_fit_client_values]

plt.figure(figsize=(13, 7))
plt.scatter(num_fit_client_values, epsilon_client_values)
plt.xlabel("Number of Fit Clients")
plt.ylabel("Epsilon Value")
plt.xscale('log', base=2)
plt.title("Epsilon Value Against Number of Rounds")
plt.grid(True)
plt.show()
# Out:
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.

# %% [markdown]
# Part 4:
#
# The first plot shows that as the noise multiplier increases the epsilon value decreases with it resulting in an increased level of privacy. However, it is important to consider the effects increased noise has on the data and therefore on the accuracy of the model as too much noise might decrease the model's accuracy. On the second  and third plot we cans see that as the number of rounds/fit clients increases the epsilon value increases with it as both increase the  cumulative information that can be exploited such data transfer with rounds and particular clients participating in them. With these trade-offs the practicality of DP in FL might be more limited/ difficult to achieve as it is scaled, since to combat the privacy leakage of the increased rounds and fit clients we have to increase our noise multiplier which might result in a less accurate model.
#
# ---

# %% [markdown]
# **Question 8 (Part II ✅ | Part III/MPhil ✅):**
#
# (You need to provide the answer with **code** and **plots** for this question. A short written argumentation is recommended.)
#
# Using the results of the previous experiment, observe the impact that a given noise multiplier has on both performance and privacy when using a **fixed** norm bound.
#
# 1. Set a `noise_multiplier`$\in \{0.1\}$ while keeping all other parameters constant. Then run the FL simulation using the `DPFedAvgFixed` strategy from above.
#
# 2. Plot accuracy and compare the convergence curves against the results you have for the previous experiment with a multiplier of $0.05$ (`hist_clip_bound_4_noise_0_05`). _NOTE: it was done just after defining the aforementioned strategy._
#
# 3. Use the `compute_fl_privacy` function to compute the epsilon value of two noise levels mentioned above. How does the epsilon of a given noise level relate to the accuracy achieved by that model? Does the relationship between the two fit your expectations from the question above?

# %% [markdown]
# ---
#
# **Question 8 Answer:**
#
# Part 1:

# %%
parameters_0_1, hist_0_1 = run_dp_fixed_fl(4, noise_multiplier=0.1)
# Out:
# WARNING flwr 2025-02-16 01:03:31,164 | app.py:213 | Both server and strategy were provided, ignoring strategy
# WARNING:flwr:Both server and strategy were provided, ignoring strategy
# INFO flwr 2025-02-16 01:03:31,166 | app.py:149 | Starting Flower simulation, config: ServerConfig(num_rounds=30, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=30, round_timeout=None)
# INFO flwr 2025-02-16 01:03:31,184 | server_returns_parameters.py:81 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2025-02-16 01:03:31,186 | server_returns_parameters.py:273 | Using initial parameters provided by strategy
# INFO:flwr:Using initial parameters provided by strategy
# INFO flwr 2025-02-16 01:03:31,191 | server_returns_parameters.py:84 | Evaluating initial parameters
# INFO:flwr:Evaluating initial parameters
# 100%|██████████| 47/47 [00:01<00:00, 41.02it/s]
# INFO flwr 2025-02-16 01:03:32,483 | server_returns_parameters.py:87 | initial parameters (loss, other metrics): 194.37576580047607, {'accuracy': 0.004}
# INFO:flwr:initial parameters (loss, other metrics): 194.37576580047607, {'accuracy': 0.004}
# INFO flwr 2025-02-16 01:03:32,484 | server_returns_parameters.py:97 | FL starting
# INFO:flwr:FL starting
# INFO flwr 2025-02-16 01:03:32,490 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-16 01:03:32,491 | client_manager.py:68 | Sampled the following clients: ['1101', '2904', '2613', '3179']
# INFO:flwr:Sampled the following clients: ['1101', '2904', '2613', '3179']
# DEBUG flwr 2025-02-16 01:03:32,492 | server_returns_parameters.py:223 | fit_round 1: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 1: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-16 01:03:32,498 | client.py:51 | Creating client with cid: 1101
# INFO:flwr:Creating client with cid: 1101
# INFO flwr 2025-02-16 01:03:32,498 | client.py:51 | Creating client with cid: 2904
# INFO:flwr:Creating client with cid: 2904
# INFO flwr 2025-02-16 01:03:32,498 | client.py:51 | Creating client with cid: 2613
# INFO:flwr:Creating client with cid: 2613
# INFO flwr 2025-02-16 01:03:32,499 | client.py:51 | Creating client with cid: 3179
# INFO:flwr:Creating client with cid: 3179
# DEBUG flwr 2025-02-16 01:03:34,401 | server_returns_parameters.py:237 | fit_round 1 received 4 results and 0 failures
# DEBUG:flwr:fit_round 1 received 4 results and 0 failures
# INFO flwr 2025-02-16 01:03:34,410 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 173.71it/s]
# INFO flwr 2025-02-16 01:03:34,689 | server_returns_parameters.py:120 | fit progress: (1, 184.48762726783752, {'accuracy': 0.08333333333333333}, 2.1997154579730704)
# INFO:flwr:fit progress: (1, 184.48762726783752, {'accuracy': 0.08333333333333333}, 2.1997154579730704)
# INFO flwr 2025-02-16 01:03:34,690 | server_returns_parameters.py:171 | evaluate_round 1: no clients selected, cancel
# INFO:flwr:evaluate_round 1: no clients selected, cancel
# INFO flwr 2025-02-16 01:03:34,692 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-16 01:03:34,692 | client_manager.py:68 | Sampled the following clients: ['1418', '27', '1758', '410']
# INFO:flwr:Sampled the following clients: ['1418', '27', '1758', '410']
# DEBUG flwr 2025-02-16 01:03:34,693 | server_returns_parameters.py:223 | fit_round 2: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 2: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-16 01:03:34,694 | client.py:51 | Creating client with cid: 1418
# INFO:flwr:Creating client with cid: 1418
# INFO flwr 2025-02-16 01:03:34,695 | client.py:51 | Creating client with cid: 27
# INFO:flwr:Creating client with cid: 27
# INFO flwr 2025-02-16 01:03:34,695 | client.py:51 | Creating client with cid: 1758
# INFO:flwr:Creating client with cid: 1758
# INFO flwr 2025-02-16 01:03:34,695 | client.py:51 | Creating client with cid: 410
# INFO:flwr:Creating client with cid: 410
# DEBUG flwr 2025-02-16 01:03:36,680 | server_returns_parameters.py:237 | fit_round 2 received 4 results and 0 failures
# DEBUG:flwr:fit_round 2 received 4 results and 0 failures
# INFO flwr 2025-02-16 01:03:36,685 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 194.60it/s]
# INFO flwr 2025-02-16 01:03:36,935 | server_returns_parameters.py:120 | fit progress: (2, 177.1865439414978, {'accuracy': 0.07333333333333333}, 4.446053292020224)
# INFO:flwr:fit progress: (2, 177.1865439414978, {'accuracy': 0.07333333333333333}, 4.446053292020224)
# INFO flwr 2025-02-16 01:03:36,936 | server_returns_parameters.py:171 | evaluate_round 2: no clients selected, cancel
# INFO:flwr:evaluate_round 2: no clients selected, cancel
# INFO flwr 2025-02-16 01:03:36,939 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-16 01:03:36,940 | client_manager.py:68 | Sampled the following clients: ['2215', '1477', '3146', '993']
# INFO:flwr:Sampled the following clients: ['2215', '1477', '3146', '993']
# DEBUG flwr 2025-02-16 01:03:36,940 | server_returns_parameters.py:223 | fit_round 3: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 3: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-16 01:03:36,941 | client.py:51 | Creating client with cid: 2215
# INFO:flwr:Creating client with cid: 2215
# INFO flwr 2025-02-16 01:03:36,942 | client.py:51 | Creating client with cid: 1477
# INFO:flwr:Creating client with cid: 1477
# INFO flwr 2025-02-16 01:03:36,942 | client.py:51 | Creating client with cid: 3146
# INFO:flwr:Creating client with cid: 3146
# INFO flwr 2025-02-16 01:03:36,942 | client.py:51 | Creating client with cid: 993
# INFO:flwr:Creating client with cid: 993
# DEBUG flwr 2025-02-16 01:03:38,562 | server_returns_parameters.py:237 | fit_round 3 received 4 results and 0 failures
# DEBUG:flwr:fit_round 3 received 4 results and 0 failures
# INFO flwr 2025-02-16 01:03:38,568 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00,
| server_returns_parameters.py:237 | fit_round 9 received 4 results and 0 failures
# DEBUG:flwr:fit_round 9 received 4 results and 0 failures
# INFO flwr 2025-02-16 01:03:51,100 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 203.14it/s]
# INFO flwr 2025-02-16 01:03:51,340 | server_returns_parameters.py:120 | fit progress: (9, 236.2066249847412, {'accuracy': 0.08466666666666667}, 18.850657082977705)
# INFO:flwr:fit progress: (9, 236.2066249847412, {'accuracy': 0.08466666666666667}, 18.850657082977705)
# INFO flwr 2025-02-16 01:03:51,340 | server_returns_parameters.py:171 | evaluate_round 9: no clients selected, cancel
# INFO:flwr:evaluate_round 9: no clients selected, cancel
# INFO flwr 2025-02-16 01:03:51,348 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-16 01:03:51,349 | client_manager.py:68 | Sampled the following clients: ['2777', '82', '2583', '2652']
# INFO:flwr:Sampled the following clients: ['2777', '82', '2583', '2652']
# DEBUG flwr 2025-02-16 01:03:51,350 | server_returns_parameters.py:223 | fit_round 10: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 10: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-16 01:03:51,351 | client.py:51 | Creating client with cid: 2777
# INFO:flwr:Creating client with cid: 2777
# INFO flwr 2025-02-16 01:03:51,351 | client.py:51 | Creating client with cid: 82
# INFO:flwr:Creating client with cid: 82
# INFO flwr 2025-02-16 01:03:51,351 | client.py:51 | Creating client with cid: 2583
# INFO:flwr:Creating client with cid: 2583
# INFO flwr 2025-02-16 01:03:51,352 | client.py:51 | Creating client with cid: 2652
# INFO:flwr:Creating client with cid: 2652
# DEBUG flwr 2025-02-16 01:03:53,268 | server_returns_parameters.py:237 | fit_round 10 received 4 results and 0 failures
# DEBUG:flwr:fit_round 10 received 4 results and 0 failures
# INFO flwr 2025-02-16 01:03:53,275 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 183.93it/s]
# INFO flwr 2025-02-16 01:03:53,540 | server_returns_parameters.py:120 | fit progress: (10, 361.82479095458984, {'accuracy': 0.08333333333333333}, 21.051146000041626)
# INFO:flwr:fit progress: (10, 361.82479095458984, {'accuracy': 0.08333333333333333}, 21.051146000041626)
# INFO flwr 2025-02-16 01:03:53,541 | server_returns_parameters.py:171 | evaluate_round 10: no clients selected, cancel
# INFO:flwr:evaluate_round 10: no clients selected, cancel
# INFO flwr 2025-02-16 01:03:53,550 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-16 01:03:53,550 | client_manager.py:68 | Sampled the following clients: ['2511', '257', '2232', '1056']
# INFO:flwr:Sampled the following clients: ['2511', '257', '2232', '1056']
# DEBUG flwr 2025-02-16 01:03:53,551 | server_returns_parameters.py:223 | fit_round 11: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 11: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-16 01:03:53,552 | client.py:51 | Creating client with cid: 2511
# INFO:flwr:Creating client with cid: 2511
# INFO flwr 2025-02-16 01:03:53,553 | client.py:51 | Creating client with cid: 257
# INFO:flwr:Creating client with cid: 257
# INFO flwr 2025-02-16 01:03:53,553 | client.py:51 | Creating client with cid: 2232
# INFO:flwr:Creating client with cid: 2232
# INFO flwr 2025-02-16 01:03:53,554 | client.py:51 | Creating client with cid: 1056
# INFO:flwr:Creating client with cid: 1056
# DEBUG flwr 2025-02-16 01:03:55,444 | server_returns_parameters.py:237 | fit_round 11 received 4 results and 0 failures
# DEBUG:flwr:fit_round 11 received 4 results and 0 failures
# INFO flwr 2025-02-16 01:03:55,449 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 213.36it/s]
# INFO flwr 2025-02-16 01:03:55,677 | server_returns_parameters.py:120 | fit progress: (11, 244.85337162017822, {'accuracy': 0.08666666666666667}, 23.187758708023466)
# INFO:flwr:fit progress: (11, 244.85337162017822, {'accuracy': 0.08666666666666667}, 23.187758708023466)
# INFO flwr 2025-02-16 01:03:55,677 | server_returns_parameters.py:171 | evaluate_round 11: no clients selected, cancel
# INFO:flwr:evaluate_round 11: no clients selected, cancel
# INFO flwr 2025-02-16 01:03:55,687 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-16 01:03:55,688 | client_manager.py:68 | Sampled the following clients: ['225', '657', '1844', '1504']
# INFO:flwr:Sampled the following clients: ['225', '657', '1844', '1504']
# DEBUG flwr 2025-02-16 01:03:55,688 | server_returns_parameters.py:223 | fit_round 12: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 12: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-16 01:03:55,689 | client.py:51 | Creating client with cid: 225
# INFO:flwr:Creating client with cid: 225
# INFO flwr 2025-02-16 01:03:55,689 | client.py:51 | Creating client with cid: 657
# INFO:flwr:Creating client with cid: 657
# INFO flwr 2025-02-16 01:03:55,690 | client.py:51 | Creating client with cid: 1844
# INFO:flwr:Creating client with cid: 1844
# INFO flwr 2025-02-16 01:03:55,690 | client.py:51 | Creating client with cid: 1504
# INFO:flwr:Creating client with cid: 1504
# DEBUG flwr 2025-02-16 01:03:57,608 | server_returns_parameters.py:237 | fit_round 12 received 4 results and 0 failures
# DEBUG:flwr:fit_round 12 received 4 results and 0 failures
# INFO flwr 2025-02-16 01:03:57,613 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 201.37it/s]
# INFO flwr 2025-02-16 01:03:57,854 | server_returns_parameters.py:120 | fit progress: (12, 366.13111543655396, {'accuracy': 0.08333333333333333}, 25.365229708026163)
# INFO:flwr:fit progress: (12, 366.13111543655396, {'accuracy': 0.08333333333333333}, 25.365229708026163)
# INFO flwr 2025-02-16 01:03:57,855 | server_returns_parameters.py:171 | evaluate_round 12: no clients selected, cancel
# INFO:flwr:evaluate_round 12: no clients selected, cancel
# INFO flwr 2025-02-16 01:03:57,866 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-16 01:03:57,867 | client_manager.py:68 | Sampled the following clients: ['168', '2252', '2386', '1450']
# INFO:flwr:Sampled the following clients: ['168', '2252', '2386', '1450']
# DEBUG flwr 2025-02-16 01:03:57,867 | server_returns_parameters.py:223 | fit_round 13: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 13: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-16 01:03:57,868 | client.py:51 | Creating client with cid: 168
# INFO:flwr:Creating client with cid: 168
# INFO flwr 2025-02-16 01:03:57,869 | client.py:51 | Creating client with cid: 2252
# INFO:flwr:Creating client with cid: 2252
# INFO flwr 2025-02-16 01:03:57,869 | client.py:51 | Creating client with cid: 2386
# INFO:flwr:Creating client with cid: 2386
# INFO flwr 2025-02-16 01:03:57,870 | client.py:51 | Creating client with cid: 1450
# INFO:flwr:Creating client with cid: 1450
# DEBUG flwr 2025-02-16 01:03:59,989 | server_returns_parameters.py:237 | fit_round 13 received 4 results and 0 failures
# DEBUG:flwr:fit_round 13 received 4 results and 0 failures
# INFO flwr 2025-02-16 01:03:59,995 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 195.09it/s]
# INFO flwr 2025-02-16 01:04:00,243 | server_returns_parameters.py:120 | fit progress: (13, 268.93216133117676, {'accuracy': 0.126}, 27.754168167011812)
# INFO:flwr:fit progress: (13, 268.93216133117676, {'accuracy': 0.126}, 27.754168167011812)
# INFO flwr 2025-02-16 01:04:00,244 | server_returns_parameters.py:171 | evaluate_round 13: no clients selected, cancel
# INFO:flwr:evaluate_round 13: no clients selected, cancel
# INFO flwr 2025-02-16 01:04:00,255 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-16 01:04:00,256 | client_manager.py:68 | Sampled the following clients: ['1448', '982', '197', '1521']
# INFO:flwr:Sampled the following clients: ['1448', '982', '197', '1521']
# DEBUG flwr 2025-02-16 01:04:00,256 | server_returns_parameters.py:223 | fit_round 14: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 14: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-16 01:04:00,257 | client.py:51 | Creating client with cid: 1448
# INFO:flwr:Creating client with cid: 1448
# INFO flwr 2025-02-16 01:04:00,257 | client.py:51 | Creating client with cid: 982
# INFO:flwr:Creating client with cid: 982
# INFO flwr 2025-02-16 01:04:00,258 | client.py:51 | Creating client with cid: 197
# INFO:flwr:Creating client with cid: 197
# INFO flwr 2025-02-16 01:04:00,259 | client.py:51 | Creating client with cid: 1521
# INFO:flwr:Creating client with cid: 1521
# DEBUG flwr 2025-02-16 01:04:02,136 | server_returns_parameters.py:237 | fit_round 14 received 4 results and 0 failures
# DEBUG:flwr:fit_round 14 received 4 results and 0 failures
# INFO flwr 2025-02-16 01:04:02,143 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00,
| server_returns_parameters.py:171 | evaluate_round 22: no clients selected, cancel
# INFO:flwr:evaluate_round 22: no clients selected, cancel
# INFO flwr 2025-02-16 01:04:20,127 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-16 01:04:20,128 | client_manager.py:68 | Sampled the following clients: ['1306', '0', '2651', '2426']
# INFO:flwr:Sampled the following clients: ['1306', '0', '2651', '2426']
# DEBUG flwr 2025-02-16 01:04:20,129 | server_returns_parameters.py:223 | fit_round 23: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 23: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-16 01:04:20,130 | client.py:51 | Creating client with cid: 1306
# INFO:flwr:Creating client with cid: 1306
# INFO flwr 2025-02-16 01:04:20,131 | client.py:51 | Creating client with cid: 0
# INFO:flwr:Creating client with cid: 0
# INFO flwr 2025-02-16 01:04:20,131 | client.py:51 | Creating client with cid: 2651
# INFO:flwr:Creating client with cid: 2651
# INFO flwr 2025-02-16 01:04:20,131 | client.py:51 | Creating client with cid: 2426
# INFO:flwr:Creating client with cid: 2426
# DEBUG flwr 2025-02-16 01:04:21,756 | server_returns_parameters.py:237 | fit_round 23 received 4 results and 0 failures
# DEBUG:flwr:fit_round 23 received 4 results and 0 failures
# INFO flwr 2025-02-16 01:04:21,762 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 196.97it/s]
# INFO flwr 2025-02-16 01:04:22,008 | server_returns_parameters.py:120 | fit progress: (23, 330.6585502624512, {'accuracy': 0.14066666666666666}, 49.519205791992135)
# INFO:flwr:fit progress: (23, 330.6585502624512, {'accuracy': 0.14066666666666666}, 49.519205791992135)
# INFO flwr 2025-02-16 01:04:22,009 | server_returns_parameters.py:171 | evaluate_round 23: no clients selected, cancel
# INFO:flwr:evaluate_round 23: no clients selected, cancel
# INFO flwr 2025-02-16 01:04:22,027 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-16 01:04:22,028 | client_manager.py:68 | Sampled the following clients: ['1721', '2204', '3192', '1258']
# INFO:flwr:Sampled the following clients: ['1721', '2204', '3192', '1258']
# DEBUG flwr 2025-02-16 01:04:22,029 | server_returns_parameters.py:223 | fit_round 24: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 24: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-16 01:04:22,030 | client.py:51 | Creating client with cid: 1721
# INFO:flwr:Creating client with cid: 1721
# INFO flwr 2025-02-16 01:04:22,031 | client.py:51 | Creating client with cid: 2204
# INFO:flwr:Creating client with cid: 2204
# INFO flwr 2025-02-16 01:04:22,031 | client.py:51 | Creating client with cid: 3192
# INFO:flwr:Creating client with cid: 3192
# INFO flwr 2025-02-16 01:04:22,032 | client.py:51 | Creating client with cid: 1258
# INFO:flwr:Creating client with cid: 1258
# DEBUG flwr 2025-02-16 01:04:24,084 | server_returns_parameters.py:237 | fit_round 24 received 4 results and 0 failures
# DEBUG:flwr:fit_round 24 received 4 results and 0 failures
# INFO flwr 2025-02-16 01:04:24,090 | strategy.py:203 | Failures: []
# INFO:flwr:Failures: []
# 100%|██████████| 47/47 [00:00<00:00, 165.46it/s]
# INFO flwr 2025-02-16 01:04:24,383 | server_returns_parameters.py:120 | fit progress: (24, 168.21353673934937, {'accuracy': 0.07133333333333333}, 51.893554375041276)
# INFO:flwr:fit progress: (24, 168.21353673934937, {'accuracy': 0.07133333333333333}, 51.893554375041276)
# INFO flwr 2025-02-16 01:04:24,383 | server_returns_parameters.py:171 | evaluate_round 24: no clients selected, cancel
# INFO:flwr:evaluate_round 24: no clients selected, cancel
# INFO flwr 2025-02-16 01:04:24,403 | client_manager.py:43 | Sampling using None
# INFO:flwr:Sampling using None
# INFO flwr 2025-02-16 01:04:24,404 | client_manager.py:68 | Sampled the following clients: ['2176', '1230', '1374', '1154']
# INFO:flwr:Sampled the following clients: ['2176', '1230', '1374', '1154']
# DEBUG flwr 2025-02-16 01:04:24,405 | server_returns_parameters.py:223 | fit_round 25: strategy sampled 4 clients (out of 3224)
# DEBUG:flwr:fit_round 25: strategy sampled 4 clients (out of 3224)
# INFO flwr 2025-02-16 01:04:24,406 | client.py:51 | Creating client with cid: 2176
# INFO:flwr:Creating client with cid: 2176
# INFO flwr 2025-02-16 01:04:24,406 | client.py:51 | Creating client with cid: 1230
# INFO:flwr:Creating client with cid: 1230
# INFO flwr 2025-02-16 01:04:24,407 | client.py:51 | Creating client with cid: 1374
# INFO:flwr:Creating client with cid: 1374
# INFO flwr 2025-02-16 01:04:24,407 | client.py:51 | Creating client with cid: 1154
# INFO:flwr:Creating client with cid: 1154
# DEBUG flwr 2025-02-16 01:04:26,327 | server_returns_parameters.py:237 | fit_round 25 received 4 results and 0 failures
| app.py:254 | app_fit: metrics_centralized {'accuracy': [(0, 0.004), (1, 0.08333333333333333), (2, 0.07333333333333333), (3, 0.058), (4, 0.09666666666666666), (5, 0.07533333333333334), (6, 0.148), (7, 0.07066666666666667), (8, 0.09866666666666667), (9, 0.08466666666666667), (10, 0.08333333333333333), (11, 0.08666666666666667), (12, 0.08333333333333333), (13, 0.126), (14, 0.15066666666666667), (15, 0.20466666666666666), (16, 0.21133333333333335), (17, 0.22066666666666668), (18, 0.07666666666666666), (19, 0.048), (20, 0.10666666666666667), (21, 0.07866666666666666), (22, 0.158), (23, 0.14066666666666666), (24, 0.07133333333333333), (25, 0.07333333333333333), (26, 0.07066666666666667), (27, 0.06466666666666666), (28, 0.066), (29, 0.072), (30, 0.07733333333333334)]}
# INFO:flwr:app_fit: metrics_centralized {'accuracy': [(0, 0.004), (1, 0.08333333333333333), (2, 0.07333333333333333), (3, 0.058), (4, 0.09666666666666666), (5, 0.07533333333333334), (6, 0.148), (7, 0.07066666666666667), (8, 0.09866666666666667), (9, 0.08466666666666667), (10, 0.08333333333333333), (11, 0.08666666666666667), (12, 0.08333333333333333), (13, 0.126), (14, 0.15066666666666667), (15, 0.20466666666666666), (16, 0.21133333333333335), (17, 0.22066666666666668), (18, 0.07666666666666666), (19, 0.048), (20, 0.10666666666666667), (21, 0.07866666666666666), (22, 0.158), (23, 0.14066666666666666), (24, 0.07133333333333333), (25, 0.07333333333333333), (26, 0.07066666666666667), (27, 0.06466666666666666), (28, 0.066), (29, 0.072), (30, 0.07733333333333334)]}

# %% [markdown]
# Part 2:

# %%
accuracies_0_05 = [accuracy for _, accuracy in hist_clip_bound_4_noise_0_05.metrics_centralized["accuracy"]]
accuracies_0_1 = [accuracy for _, accuracy in hist_0_1.metrics_centralized["accuracy"]]

plt.figure(figsize=(13, 7))
plt.plot(accuracies_0_05, label="Noise Multiplier: 0.05")
plt.plot(accuracies_0_1, label="Noise Multiplier: 0.1")
plt.xlabel("Round number")
plt.ylabel("Model Accuracy")
plt.title("Model accuracy for different noise multipliers")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Part 3:

# %%
epsilon_0_05 = compute_fl_privacy(noise_multiplier=0.05)
epsilon_0_1 = compute_fl_privacy(noise_multiplier=0.1)
print(f"Epsilon value for noise multiplier 0.05: {epsilon_0_05}")
print(f"Epsilon value for noise multiplier 0.1: {epsilon_0_1}")
# Out:
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# WARNING:absl:`compute_dp_sgd_privacy` is deprecated. It does not account for doubling of sensitivity with microbatching, and assumes Poisson subsampling, which is rarely used in practice. Please use `compute_dp_sgd_privacy_statement`, which provides appropriate context for the guarantee. To compute epsilon under different assumptions than those in `compute_dp_sgd_privacy_statement`, call the `dp_accounting` libraries directly.
# Epsilon value for noise multiplier 0.05: 4363302.374442753
# Epsilon value for noise multiplier 0.1: 585233.9431437703

# %% [markdown]
# **Written Answer:**
#
# The plot clearly present the signifiant impact of noise multiplier on model accuracy. We can see that even a small increase in noise multiplier from 0.05 to 0.1 results in a significant decrease in model accuracy presenting their inverse relationship which was expected based on the results of the previous experiment. On the other hand we can also observe the small change in the noise multiplier does not only effect of the model accuracy greatly but the epsilon value as well hence increasing the privacy level. This shows the sensitivity that a FL system has to the noise multiplier and the trade-off between privacy and accuracy.

# %% [markdown]
# # End of Part I
#
# Continue to part 2.

# %% [markdown]
# (c) 2024 Alexandru-Andrei Iacob, Lorenzo Sani
